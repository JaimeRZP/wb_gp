# %% [markdown]
# # Setting up a latent function Gaussian Process
#
# Let us start by importing Turing.jl, the library we will use to write our statistical model and our GaussianProcess.jl package. \
# The rest of the imports will only be used to generate the data and plot.

# %%
using Turing
using Distances
using LinearAlgebra
using LimberJack

# %%
using Interpolations
using GaussianProcess
using Plots

# %% [markdown]
# ### 1. Get the Hz data
# This time we will apply a non-linear transformation to our data.

# %%
function CC()
    z = [
        0.07, 0.09, 0.12, 0.17, 0.179, 0.199, 0.2,
        0.27, 0.28, 0.352, 0.38, 0.3802, 0.4,
        0.4004, 0.4247, 0.44, 0.4497, 0.47, 0.4783,
        0.48, 0.51, 0.593, 0.6, 0.61, 0.68, 0.73,
        0.781, 0.875, 0.88, 0.9, 1.037, 1.3,
        1.363, 1.43, 1.53, 1.75, 1.965
    ]

    data = [
        69.0, 69.0, 68.6, 83.0, 75.0, 75.0, 72.9,
        77.0, 88.8, 83.0, 81.5, 83.0, 95.0, 77.0,
        87.1, 82.6, 92.8, 89.0, 80.9, 97.0, 90.4,
        104.0, 87.9, 97.3, 92.0, 97.3, 105.0,
        125.0, 90.0, 117.0, 154.0, 168.0, 160.0,
        177.0, 140.0, 202.0, 186.5
    ]

    err = [
        19.6, 12.0, 26.2, 8.0, 4.0, 5.0, 29.6,
        14.0, 36.6, 14.0, 1.9, 13.5, 17.0, 10.2,
        11.2, 7.8, 12.9, 23.0, 9.0, 62.0, 1.9,
        13.0, 6.1, 2.1, 8.0, 7.0, 12.0, 17.0,
        40.0, 23.0, 20.0, 17.0, 33.6, 18.0,
        14.0, 40.0, 50.4
    ]

    cov = zeros(length(z), length(z))
    for i in 1:length(z)
        cov[i, i] = err[i]^2
    end

    return (
        data_name = "CC",
        z = z,
        data = data,
        cov = cov
    )
end
# Out:
# CC (generic function with 1 method)

# %%
function BOSSDR12()
    z = [0.38, 0.51, 0.61]
    data = [81.2087, 90.9029, 98.9647]
    cov = [5.00049e+02 2.94536e+02 1.42011e+02; 2.94536e+02 7.02299e+02 4.32750e+02; 1.42011e+02 4.32750e+02 1.01718e+03]
    return (data_name = "BOSSDR12", z = z, data = data, cov = cov)
end
# Out:
# BOSSDR12 (generic function with 1 method)

# %%
cc = CC();
bossdr12 = BOSSDR12();

# %%
hubble_data  = [bossdr12.data; cc.data];
zh = [bossdr12.z; cc.z];

# %%
covariance = zeros(length(bossdr12.data)+ length(cc.data), length(bossdr12.data)+ length(cc.data));
for i in 1:length(bossdr12.data)
    for j in 1:length(bossdr12.data)
        covariance[i,j] = bossdr12.cov[i,j]
    end
end

for i in 1:length(cc.data)
    for j in 1:length(cc.data)
        covariance[i+length(bossdr12.data), j+length(bossdr12.data)] = cc.cov[i,j]
    end
end

# %%
zcont = range(0, 2.5, length=24);
cosmo1 = Cosmology();
H1 = cosmo1.cpar.h*100*Ez(cosmo1, zcont);

# %%
omegam = 0.3
omegab = 0.05
hc = 0.67
# Out:
# 0.67

# %% [markdown]
# ### 2. Check what our priors look like

# %%
function model_latent_GP(eta, l, v;  
                         X=zcont, data_x=zh, data_cov=covariance)
    # Dimensions of predictors .
    kernel = sqexp_cov_fn(X; eta=eta, l=l)
    cpar = CosmoPar(Ωm=omegam,  Ωb=omegab, h=hc)
    mean_hz = cpar.h*100*Ez(cpar, X)
    gp = latent_GP(mean_hz, v, kernel)
    y =  conditional(X, data_x, gp, sqexp_cov_fn;
                     eta=eta, l=l)
    return gp, y
end
# Out:
# model_latent_GP (generic function with 1 method)

# %%
N_samples = 100
gps=zeros(N_samples, 24)
ys=zeros(N_samples, 40)
for i in 1:10
    eta = rand(Uniform(0., 0.1))
    l = rand(Uniform(0.1, 3))
    v = rand(MvNormal(zeros(length(zcont)), ones(length(zcont))))
    gps[i, :], ys[i, :] = model_latent_GP(eta, l, v)
end

y_m, y_s = mean(ys, dims=1), std(ys, dims=1);
gp_m, gp_s = mean(gps, dims=1), std(gps, dims=1);

# %%
#plot(zh, hubble_data, label="Data", ms=2, seriestype=:scatter)
#zarr = range(0, 2.5, length=100);
# plot!(zcont, H1)
#plot!(zcont, vec(gp_m))
plot(zcont, vec(gp_m .- gp_s),  fillrange = vec(gp_m .+ gp_s), fillalpha=0.2, c=1)
#plot!(zcont, vec(gp_m .+ gp_s))

# %% [markdown]
# ### 3. Define our statistical model

# %%
@model function stats_model(y; X=zcont, data_x=zh, data_cov=covariance)
    # Priors.
    eta ~ Uniform(0.0, 0.1)
    l ~ Uniform(0.1, 3)
    v ~ MvNormal(zeros(length(X)), ones(length(X)))
    kernel = sqexp_cov_fn(X, eta=eta, l=l)
    cpar = CosmoPar(Ωm=omegam,  Ωb=omegab, h=hc)
    mean_hz = cpar.h*100*Ez(cpar, X)
    gp = latent_GP(mean_hz, v, kernel)
    m = conditional(X, data_x, gp, sqexp_cov_fn; eta=eta, l=l)
    y ~ MvNormal(m, data_cov)
end
# Out:
# stats_model (generic function with 2 methods)

# %% [markdown]
# ### 4. Sample the model

# %%
chain = sample(stats_model(hubble_data), NUTS(100, 0.65), 1000)
# Out:
# Sampling   0%|                                          |  ETA: N/A
# ┌ Info: Found initial step size
# │   ϵ = 1.6
# └ @ Turing.Inference /home/vis09/.julia/packages/Turing/wjl7M/src/inference/hmc.jl:192
# Sampling   0%|▎                                         |  ETA: 3:45:47
# Sampling   1%|▍                                         |  ETA: 1:52:52
# Sampling   1%|▋                                         |  ETA: 1:15:14
# Sampling   2%|▊                                         |  ETA: 0:56:26
# Sampling   2%|█                                         |  ETA: 0:45:07
# Sampling   3%|█▏                                        |  ETA: 0:37:45
# Sampling   3%|█▍                                        |  ETA: 0:32:20
# Sampling   4%|█▌                                        |  ETA: 0:28:17
# Sampling   4%|█▊                                        |  ETA: 0:25:11
# Sampling   5%|█▉                                        |  ETA: 0:22:36
# Sampling   5%|██▏                                       |  ETA: 0:20:37
# Sampling   5%|██▎                                       |  ETA: 0:18:51
# Sampling   6%|██▌                                       |  ETA: 0:17:41
# Sampling   6%|██▋                                       |  ETA: 0:16:22
# Sampling   7%|██▉                                       |  ETA: 0:15:17
# Sampling   7%|███                                       |  ETA: 0:14:18
# Sampling   8%|███▎                                      |  ETA: 0:13:26
# Sampling   8%|███▍                                      |  ETA: 0:12:53
# Sampling   9%|███▋                                      |  ETA: 0:12:18
# Sampling   9%|███▉                                      |  ETA: 0:11:39
# Sampling  10%|████                                      |  ETA: 0:11:13
# Sampling  10%|████▎                                     |  ETA: 0:10:43
# Sampling  10%|████▍                                     |  ETA: 0:10:20
# Sampling  11%|████▋                                     |  ETA: 0:09:57
# Sampling  11%|████▊                                     |  ETA: 0:09:40
# Sampling  12%|█████                                     |  ETA: 0:09:24
# Sampling  12%|█████▏                                    |  ETA: 0:09:06
# Sampling  13%|█████▍                                    |  ETA: 0:08:53
# Sampling  13%|█████▌                                    |  ETA: 0:08:38
# Sampling  14%|█████▊                                    |  ETA: 0:08:24
# Sampling  14%|█████▉                                    |  ETA: 0:08:10
# Sampling  15%|██████▏                                   |  ETA: 0:07:56
# Sampling  15%|██████▎                                   |  ETA: 0:07:43
# Sampling  15%|██████▌                                   |  ETA: 0:07:29
# Sampling  16%|██████▋                                   |  ETA: 0:07:17
# Sampling  16%|██████▉                                   |  ETA: 0:07:06
# Sampling  17%|███████▏                                  |  ETA: 0:06:55
# Sampling  17%|███████▎                                  |  ETA: 0:06:46
# Sampling  18%|███████▌                                  |  ETA: 0:06:36
# Sampling  18%|███████▋                                  |  ETA: 0:06:26
# Sampling  19%|███████▉                                  |  ETA: 0:06:19
# Sampling  19%|████████                                  |  ETA: 0:06:12
# Sampling  20%|████████▎                                 |  ETA: 0:06:04
# Sampling  20%|████████▍                                 |  ETA: 0:05:56
# Sampling  20%|████████▋                                 |  ETA: 0:05:48
# Sampling  21%|████████▊                                 |  ETA: 0:05:42
# Sampling  21%|█████████                                 |  ETA: 0:05:35
# Sampling  22%|█████████▏                                |  ETA: 0:05:28
# Sampling  22%|█████████▍                                |  ETA: 0:05:22
# Sampling  23%|█████████▌                                |  ETA: 0:05:17
# Sampling  23%|█████████▊                                |  ETA: 0:05:11
# Sampling  24%|█████████▉                                |  ETA: 0:05:06
# Sampling  24%|██████████▏                               |  ETA: 0:05:05
# Sampling  25%|██████████▎                               |  ETA: 0:05:01
# Sampling  25%|██████████▌                               |  ETA: 0:04:55
# Sampling  25%|██████████▊                               |  ETA: 0:04:51
# Sampling  26%|██████████▉                               |  ETA: 0:04:46
# Sampling  26%|███████████▏                              |  ETA: 0:04:41
# Sampling  27%|███████████▎                              |  ETA: 0:04:37
# Sampling  27%|███████████▌                              |  ETA: 0:04:35
# Sampling  28%|███████████▋                              |  ETA: 0:04:31
# Sampling  28%|███████████▉                              |  ETA: 0:04:28
# Sampling  29%|████████████                              |  ETA: 0:04:25
# Sampling  29%|████████████▎                             |  ETA: 0:04:20
# Sampling  30%|████████████▍                             |  ETA: 0:04:15
# Sampling  30%|████████████▋                             |  ETA: 0:04:11
# Sampling  30%|████████████▊                             |  ETA: 0:04:08
# Sampling  31%|█████████████                             |  ETA: 0:04:03
# Sampling  31%|█████████████▏                            |  ETA: 0:04:01
# Sampling  32%|█████████████▍                            |  ETA: 0:04:00
# Sampling  32%|█████████████▌                            |  ETA: 0:03:57
# Sampling  33%|█████████████▊                            |  ETA: 0:03:54
# Sampling  33%|█████████████▉                            |  ETA: 0:03:51
# Sampling  34%|██████████████▏                           |  ETA: 0:03:49
# Sampling  34%|██████████████▍                           |  ETA: 0:03:46
# Sampling  35%|██████████████▌                           |  ETA: 0:03:43
# Sampling  35%|██████████████▊                           |  ETA: 0:03:40
# Sampling  35%|██████████████▉                           |  ETA: 0:03:37
# Sampling  36%|███████████████▏                          |  ETA: 0:03:34
# Sampling  36%|███████████████▎                          |  ETA: 0:03:32
# Sampling  37%|███████████████▌                          |  ETA: 0:03:30
# Sampling  37%|███████████████▋                          |  ETA: 0:03:29
# Sampling  38%|███████████████▉                          |  ETA: 0:03:27
# Sampling  38%|████████████████                          |  ETA: 0:03:27
# Sampling  39%|████████████████▎                         |  ETA: 0:03:25
# Sampling  39%|████████████████▍                         |  ETA: 0:03:23
# Sampling  40%|████████████████▋                         |  ETA: 0:03:21
# Sampling  40%|████████████████▊                         |  ETA: 0:03:19
# Sampling  40%|█████████████████                         |  ETA: 0:03:16
# Sampling  41%|█████████████████▏                        |  ETA: 0:03:14
# Sampling  41%|█████████████████▍                        |  ETA: 0:03:11
# Sampling  42%|█████████████████▋                        |  ETA: 0:03:09
# Sampling  42%|█████████████████▊                        |  ETA: 0:03:07
# Sampling  43%|██████████████████                        |  ETA: 0:03:05
# Sampling  43%|██████████████████▏                       |  ETA: 0:03:02
# Sampling  44%|██████████████████▍                       |  ETA: 0:02:59
# Sampling  44%|██████████████████▌                       |  ETA: 0:02:58
# Sampling  45%|██████████████████▊                       |  ETA: 0:02:57
# Sampling  45%|██████████████████▉                       |  ETA: 0:02:54
# Sampling  45%|███████████████████▏                      |  ETA: 0:02:52
# Sampling  46%|███████████████████▎                      |  ETA: 0:02:49
# Sampling  46%|███████████████████▌                      |  ETA: 0:02:48
# Sampling  47%|███████████████████▋                      |  ETA: 0:02:46
# Sampling  47%|███████████████████▉                      |  ETA: 0:02:44
# Sampling  48%|████████████████████                      |  ETA: 0:02:43
# Sampling  48%|████████████████████▎                     |  ETA: 0:02:41
# Sampling  49%|████████████████████▍                     |  ETA: 0:02:39
# Sampling  49%|████████████████████▋                     |  ETA: 0:02:37
# Sampling  50%|████████████████████▊                     |  ETA: 0:02:35
# Sampling  50%|█████████████████████                     |  ETA: 0:02:34
# Sampling  50%|█████████████████████▎                    |  ETA: 0:02:32
# Sampling  51%|█████████████████████▍                    |  ETA: 0:02:30
# Sampling  51%|█████████████████████▋                    |  ETA: 0:02:28
# Sampling  52%|█████████████████████▊                    |  ETA: 0:02:26
# Sampling  52%|██████████████████████                    |  ETA: 0:02:24
# Sampling  53%|██████████████████████▏                   |  ETA: 0:02:22
# Sampling  53%|██████████████████████▍                   |  ETA: 0:02:20
# Sampling  54%|██████████████████████▌                   |  ETA: 0:02:18
# Sampling  54%|██████████████████████▊                   |  ETA: 0:02:16
# Sampling  55%|██████████████████████▉                   |  ETA: 0:02:15
# Sampling  55%|███████████████████████▏                  |  ETA: 0:02:13
# Sampling  55%|███████████████████████▎                  |  ETA: 0:02:11
# Sampling  56%|███████████████████████▌                  |  ETA: 0:02:10
# Sampling  56%|███████████████████████▋                  |  ETA: 0:02:08
# Sampling  57%|███████████████████████▉                  |  ETA: 0:02:07
# Sampling  57%|████████████████████████                  |  ETA: 0:02:06
# Sampling  58%|████████████████████████▎                 |  ETA: 0:02:04
# Sampling  58%|████████████████████████▍                 |  ETA: 0:02:03
# Sampling  59%|████████████████████████▋                 |  ETA: 0:02:01
# Sampling  59%|████████████████████████▉                 |  ETA: 0:01:59
# Sampling  60%|█████████████████████████                 |  ETA: 0:01:58
# Sampling  60%|█████████████████████████▎                |  ETA: 0:01:56
# Sampling  60%|█████████████████████████▍                |  ETA: 0:01:55
# Sampling  61%|█████████████████████████▋                |  ETA: 0:01:53
# Sampling  61%|█████████████████████████▊                |  ETA: 0:01:52
# Sampling  62%|██████████████████████████                |  ETA: 0:01:50
# Sampling  62%|██████████████████████████▏               |  ETA: 0:01:49
# Sampling  63%|██████████████████████████▍               |  ETA: 0:01:47
# Sampling  63%|██████████████████████████▌               |  ETA: 0:01:45
# Sampling  64%|██████████████████████████▊               |  ETA: 0:01:44
# Sampling  64%|██████████████████████████▉               |  ETA: 0:01:42
# Sampling  65%|███████████████████████████▏              |  ETA: 0:01:40
# Sampling  65%|███████████████████████████▎              |  ETA: 0:01:39
# Sampling  65%|███████████████████████████▌              |  ETA: 0:01:37
# Sampling  66%|███████████████████████████▋              |  ETA: 0:01:36
# Sampling  66%|███████████████████████████▉              |  ETA: 0:01:34
# Sampling  67%|████████████████████████████▏             |  ETA: 0:01:33
# Sampling  67%|████████████████████████████▎             |  ETA: 0:01:32
# Sampling  68%|████████████████████████████▌             |  ETA: 0:01:30
# Sampling  68%|████████████████████████████▋             |  ETA: 0:01:29
# Sampling  69%|████████████████████████████▉             |  ETA: 0:01:28
# Sampling  69%|█████████████████████████████             |  ETA: 0:01:26
# Sampling  70%|█████████████████████████████▎            |  ETA: 0:01:25
# Sampling  70%|█████████████████████████████▍            |  ETA: 0:01:24
# Sampling  70%|█████████████████████████████▋            |  ETA: 0:01:22
# Sampling  71%|█████████████████████████████▊            |  ETA: 0:01:21
# Sampling  71%|██████████████████████████████            |  ETA: 0:01:19
# Sampling  72%|██████████████████████████████▏           |  ETA: 0:01:18
# Sampling  72%|██████████████████████████████▍           |  ETA: 0:01:16
# Sampling  73%|██████████████████████████████▌           |  ETA: 0:01:15
# Sampling  73%|██████████████████████████████▊           |  ETA: 0:01:14
# Sampling  74%|██████████████████████████████▉           |  ETA: 0:01:12
# Sampling  74%|███████████████████████████████▏          |  ETA: 0:01:11
# Sampling  75%|███████████████████████████████▎          |  ETA: 0:01:10
# Sampling  75%|███████████████████████████████▌          |  ETA: 0:01:08
# Sampling  75%|███████████████████████████████▊          |  ETA: 0:01:07
# Sampling  76%|███████████████████████████████▉          |  ETA: 0:01:06
# Sampling  76%|████████████████████████████████▏         |  ETA: 0:01:05
# Sampling  77%|████████████████████████████████▎         |  ETA: 0:01:03
# Sampling  77%|████████████████████████████████▌         |  ETA: 0:01:02
# Sampling  78%|████████████████████████████████▋         |  ETA: 0:01:01
# Sampling  78%|████████████████████████████████▉         |  ETA: 0:01:00
# Sampling  79%|█████████████████████████████████         |  ETA: 0:00:59
# Sampling  79%|█████████████████████████████████▎        |  ETA: 0:00:57
# Sampling  80%|█████████████████████████████████▍        |  ETA: 0:00:56
# Sampling  80%|█████████████████████████████████▋        |  ETA: 0:00:55
# Sampling  80%|█████████████████████████████████▊        |  ETA: 0:00:54
# Sampling  81%|██████████████████████████████████        |  ETA: 0:00:53
# Sampling  81%|██████████████████████████████████▏       |  ETA: 0:00:51
# Sampling  82%|██████████████████████████████████▍       |  ETA: 0:00:50
# Sampling  82%|██████████████████████████████████▌       |  ETA: 0:00:49
# Sampling  83%|██████████████████████████████████▊       |  ETA: 0:00:48
# Sampling  83%|██████████████████████████████████▉       |  ETA: 0:00:46
# Sampling  84%|███████████████████████████████████▏      |  ETA: 0:00:45
# Sampling  84%|███████████████████████████████████▍      |  ETA: 0:00:44
# Sampling  85%|███████████████████████████████████▌      |  ETA: 0:00:43
# Sampling  85%|███████████████████████████████████▊      |  ETA: 0:00:42
# Sampling  85%|███████████████████████████████████▉      |  ETA: 0:00:41
# Sampling  86%|████████████████████████████████████▏     |  ETA: 0:00:39
# Sampling  86%|████████████████████████████████████▎     |  ETA: 0:00:38
# Sampling  87%|████████████████████████████████████▌     |  ETA: 0:00:37
# Sampling  87%|████████████████████████████████████▋     |  ETA: 0:00:35
# Sampling  88%|████████████████████████████████████▉     |  ETA: 0:00:34
# Sampling  88%|█████████████████████████████████████     |  ETA: 0:00:33
# Sampling  89%|█████████████████████████████████████▎    |  ETA: 0:00:31
# Sampling  89%|█████████████████████████████████████▍    |  ETA: 0:00:30
# Sampling  90%|█████████████████████████████████████▋    |  ETA: 0:00:29
# Sampling  90%|█████████████████████████████████████▊    |  ETA: 0:00:28
# Sampling  90%|██████████████████████████████████████    |  ETA: 0:00:26
# Sampling  91%|██████████████████████████████████████▏   |  ETA: 0:00:25
# Sampling  91%|██████████████████████████████████████▍   |  ETA: 0:00:24
# Sampling  92%|██████████████████████████████████████▋   |  ETA: 0:00:23
# Sampling  92%|██████████████████████████████████████▊   |  ETA: 0:00:21
# Sampling  93%|███████████████████████████████████████   |  ETA: 0:00:20
# Sampling  93%|███████████████████████████████████████▏  |  ETA: 0:00:19
# Sampling  94%|███████████████████████████████████████▍  |  ETA: 0:00:17
# Sampling  94%|███████████████████████████████████████▌  |  ETA: 0:00:16
# Sampling  95%|███████████████████████████████████████▊  |  ETA: 0:00:15
# Sampling  95%|███████████████████████████████████████▉  |  ETA: 0:00:14
# Sampling  95%|████████████████████████████████████████▏ |  ETA: 0:00:13
# Sampling  96%|████████████████████████████████████████▎ |  ETA: 0:00:11
# Sampling  96%|████████████████████████████████████████▌ |  ETA: 0:00:10
# Sampling  97%|████████████████████████████████████████▋ |  ETA: 0:00:09
# Sampling  97%|████████████████████████████████████████▉ |  ETA: 0:00:08
# Sampling  98%|█████████████████████████████████████████ |  ETA: 0:00:06
# Sampling  98%|█████████████████████████████████████████▎|  ETA: 0:00:05
# Sampling  99%|█████████████████████████████████████████▍|  ETA: 0:00:04
# Sampling  99%|█████████████████████████████████████████▋|  ETA: 0:00:03
# Sampling 100%|█████████████████████████████████████████▊|  ETA: 0:00:01
# Sampling 100%|██████████████████████████████████████████| Time: 0:04:38
# Sampling 100%|██████████████████████████████████████████| Time: 0:04:39
# Chains MCMC chain (1000×38×1 Array{Float64, 3}):
#
# Iterations        = 101:1:1100
# Number of chains  = 1
# Samples per chain = 1000
# Wall duration     = 282.0 seconds
# Compute duration  = 282.0 seconds
# parameters        = eta, l, v[1], v[2], v[3], v[4], v[5], v[6], v[7], v[8], v[9], v[10], v[11], v[12], v[13], v[14], v[15], v[16], v[17], v[18], v[19], v[20], v[21], v[22], v[23], v[24]
# internals         = lp, n_steps, is_accept, acceptance_rate, log_density, hamiltonian_energy, hamiltonian_energy_error, max_hamiltonian_energy_error, tree_depth, numerical_error, step_size, nom_step_size
#
# Summary Statistics
#   parameters      mean       std   naive_se      mcse         ess      rhat    ⋯
#       Symbol   Float64   Float64    Float64   Float64     Float64   Float64    ⋯
#
#          eta    0.0563    0.0262     0.0008    0.0010    870.2229    0.9997    ⋯
#            l    1.4745    0.7653     0.0242    0.0230    986.1196    0.9990    ⋯
#         v[1]    0.2721    0.9754     0.0308    0.0410    756.6510    1.0026    ⋯
#         v[2]    0.0305    0.9424     0.0298    0.0318    977.9714    1.0004    ⋯
#         v[3]    0.0726    1.0371     0.0328    0.0319    969.3396    1.0009    ⋯
#         v[4]    0.0364    1.0110     0.0320    0.0318    852.9020    0.9999    ⋯
#         v[5]    0.0210    0.9418     0.0298    0.0291   1035.4424    0.9991    ⋯
#         v[6]    0.0974    0.9535     0.0302    0.0284    867.5785    0.9999    ⋯
#         v[7]    0.0577    0.9878     0.0312    0.0342    835.3832    1.0016    ⋯
#         v[8]   -0.0332    0.9695     0.0307    0.0341    840.6454    1.0002    ⋯
#         v[9]   -0.0041    1.0576     0.0334    0.0210   1208.8846    0.9993    ⋯
#        v[10]    0.0002    0.9623     0.0304    0.0314    926.5527    0.9996    ⋯
#        v[11]   -0.0427    1.0116     0.0320    0.0357    957.3281    1.0003    ⋯
#        v[12]    0.0039    1.0429     0.0330    0.0309    875.1805    1.0036    ⋯
#        v[13]   -0.0098    0.9889     0.0313    0.0330    825.5628    0.9998    ⋯
#        v[14]    0.0016    1.0302     0.0326    0.0322    929.7176    0.9999    ⋯
#        v[15]    0.0370    0.9808     0.0310    0.0338    919.2358    0.9990    ⋯
#       ⋮           ⋮         ⋮         ⋮          ⋮          ⋮          ⋮       ⋱
#                                                      1 column and 9 rows omitted
#
# Quantiles
#   parameters      2.5%     25.0%     50.0%     75.0%     97.5%
#       Symbol   Float64   Float64   Float64   Float64   Float64
#
#          eta    0.0086    0.0359    0.0579    0.0784    0.0980
#            l    0.1694    0.8785    1.4417    2.0401    2.9037
#         v[1]   -1.6816   -0.3358    0.2758    0.9134    2.1226
#         v[2]   -1.8417   -0.6237    0.0533    0.6907    1.9825
#         v[3]   -2.0067   -0.6294    0.0519    0.8269    2.0200
#         v[4]   -1.9929   -0.6570   -0.0198    0.6963    2.0338
#         v[5]   -1.9255   -0.5802    0.0384    0.6062    1.8885
#         v[6]   -1.8079   -0.5344    0.0967    0.7663    2.1047
#         v[7]   -1.8455   -0.6363    0.0565    0.7238    2.0431
#         v[8]   -2.0114   -0.6662   -0.0111    0.6341    1.8539
#         v[9]   -2.1949   -0.7039    0.0138    0.7097    1.9304
#        v[10]   -1.8979   -0.6539   -0.0178    0.6308    1.8970
#        v[11]   -1.9621   -0.7390   -0.0757    0.6494    1.9567
#        v[12]   -2.1013   -0.6999    0.0073    0.7001    1.9444
#        v[13]   -1.9358   -0.7071   -0.0130    0.6329    1.9392
#        v[14]   -2.0199   -0.7208    0.0030    0.7071    2.0285
#        v[15]   -1.9181   -0.5799    0.0726    0.7105    1.9634
#       ⋮           ⋮         ⋮         ⋮         ⋮         ⋮
#                                                   9 rows omitted

# %% [markdown]
# ### 5. Check how our posteriors look like

# %%
eta_p = group(chain, :eta).value.data[:, :, 1];
l_p = group(chain, :l).value.data[:, :, 1];
v_p = group(chain, :v).value.data[:, :, 1];

# %%
println(length(eta_p))
# Out:
# 1000

# %%
N_samples2 = length(eta_p)
gps2=zeros(N_samples2, 24)
ys2=zeros(N_samples2, 100)
for i in 1:N_samples2
    gps2[i, :], ys2[i, :] = model_latent_GP(eta_p[i], l_p[i], v_p[i, :];
                                                data_x=LinRange(0, 7, 100))
end

y_m2, y_s2 = mean(ys2, dims=1), std(ys2, dims=1);
gp_m2, gp_s2 = mean(gps2, dims=1), std(gps2, dims=1);

# %%
plot(zh, hubble_data, label="Data", ms=2, seriestype=:scatter)
#plot!(zcont, H1, label="LCDM")
plot!(LinRange(0, 7, 100), vec(y_m2))
plot!(LinRange(0, 7, 100), vec(y_m2 .- y_s2),  fillrange = vec(y_m2 .+ y_s2), fillalpha=0.2, c=1)
#plot!(zcont, vec(y_m2 .+ y_s2))

# %%
plot(zh, hubble_data, label="Data", ms=2, seriestype=:scatter)
#plot!(zcont, H1, label="LCDM")
plot!(zcont, vec(gp_m2))
plot!(zcont, vec(gp_m2 .- gp_s2),  fillrange = vec(gp_m2 .+ gp_s2), fillalpha=0.2, c=1)
#plot!(zcont, vec(y_m2 .+ y_s2))
