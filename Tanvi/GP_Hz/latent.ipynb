# %% [markdown]
# # Setting up a latent function Gaussian Process
#
# Let us start by importing Turing.jl, the library we will use to write our statistical model and our GaussianProcess.jl package. \
# The rest of the imports will only be used to generate the data and plot.

# %%
using Turing
using Distances
using LinearAlgebra
using LimberJack

# %%
using Interpolations
using GaussianProcess
using Plots

# %% [markdown]
# ### 1. Get the Hz data
# This time we will apply a non-linear transformation to our data.

# %%
function CC()
    z = [
        0.07, 0.09, 0.12, 0.17, 0.179, 0.199, 0.2,
        0.27, 0.28, 0.352, 0.38, 0.3802, 0.4,
        0.4004, 0.4247, 0.44, 0.4497, 0.47, 0.4783,
        0.48, 0.51, 0.593, 0.6, 0.61, 0.68, 0.73,
        0.781, 0.875, 0.88, 0.9, 1.037, 1.3,
        1.363, 1.43, 1.53, 1.75, 1.965
    ]

    data = [
        69.0, 69.0, 68.6, 83.0, 75.0, 75.0, 72.9,
        77.0, 88.8, 83.0, 81.5, 83.0, 95.0, 77.0,
        87.1, 82.6, 92.8, 89.0, 80.9, 97.0, 90.4,
        104.0, 87.9, 97.3, 92.0, 97.3, 105.0,
        125.0, 90.0, 117.0, 154.0, 168.0, 160.0,
        177.0, 140.0, 202.0, 186.5
    ]

    err = [
        19.6, 12.0, 26.2, 8.0, 4.0, 5.0, 29.6,
        14.0, 36.6, 14.0, 1.9, 13.5, 17.0, 10.2,
        11.2, 7.8, 12.9, 23.0, 9.0, 62.0, 1.9,
        13.0, 6.1, 2.1, 8.0, 7.0, 12.0, 17.0,
        40.0, 23.0, 20.0, 17.0, 33.6, 18.0,
        14.0, 40.0, 50.4
    ]

    cov = zeros(length(z), length(z))
    for i in 1:length(z)
        cov[i, i] = err[i]^2
    end

    return (
        data_name = "CC",
        z = z,
        data = data,
        cov = cov
    )
end
# Out:
# CC (generic function with 1 method)

# %%
function BOSSDR12()
    z = [0.38, 0.51, 0.61]
    data = [81.2087, 90.9029, 98.9647]
    cov = [5.00049e+02 2.94536e+02 1.42011e+02; 2.94536e+02 7.02299e+02 4.32750e+02; 1.42011e+02 4.32750e+02 1.01718e+03]
    return (data_name = "BOSSDR12", z = z, data = data, cov = cov)
end
# Out:
# BOSSDR12 (generic function with 1 method)

# %%
cc = CC();
bossdr12 = BOSSDR12();

# %%
hubble_data  = [bossdr12.data; cc.data];
zh = [bossdr12.z; cc.z];

# %%
covariance = zeros(length(bossdr12.data)+ length(cc.data), length(bossdr12.data)+ length(cc.data));
for i in 1:length(bossdr12.data)
    for j in 1:length(bossdr12.data)
        covariance[i,j] = bossdr12.cov[i,j]
    end
end

for i in 1:length(cc.data)
    for j in 1:length(cc.data)
        covariance[i+length(bossdr12.data), j+length(bossdr12.data)] = cc.cov[i,j]
    end
end

# %%
zcont = range(0, 2.5, length=24);
cosmo1 = Cosmology();
H1 = cosmo1.cpar.h*100*Ez(cosmo1, zcont);

# %%
omegam = 0.3
omegab = 0.05
hc = 0.67
# Out:
# 0.67

# %% [markdown]
# ### 2. Check what our priors look like

# %%
function model_latent_GP(eta, l, v;  
                         X=zcont, data_x=zh, data_cov=covariance)
    # Dimensions of predictors .
    kernel = sqexp_cov_fn(X; eta=eta, l=l)
    cpar = CosmoPar(Ωm=omegam,  Ωb=omegab, h=hc)
    mean_hz = cpar.h*100*Ez(cpar, X)
    gp = latent_GP(mean_hz, v, kernel)
    y =  conditional(X, data_x, gp, sqexp_cov_fn;
                     eta=eta, l=l)
    return gp, y
end
# Out:
# model_latent_GP (generic function with 1 method)

# %%
N_samples = 100
gps=zeros(N_samples, 24)
ys=zeros(N_samples, 40)
for i in 1:N_samples
    eta = 200*rand(Uniform(0., 0.1))
    l = 0.02*rand(Uniform(0.1, 3))
    v = rand(MvNormal(zeros(length(zcont)), ones(length(zcont))))
    gps[i, :], ys[i, :] = model_latent_GP(eta, l, v)
end

y_m, y_s = mean(ys, dims=1), std(ys, dims=1);
gp_m, gp_s = mean(gps, dims=1), std(gps, dims=1);

# %%
plot(zh, hubble_data, label="Data", ms=2, seriestype=:scatter)
#plot!(zcont, H1)
plot!(zcont, vec(gp_m), label="GP mean")
plot!(zcont, vec(gp_m .- gp_s),  fillrange = vec(gp_m .+ gp_s), fillalpha=0.2, c=1, label="GP standard deviation")

# %%
plot(zh, hubble_data, label="Data", ms=2, seriestype=:scatter)
#plot!(zcont, H1)
plot!(zh, vec(y_m), label="y mean")
plot!(zh, vec(y_m .- y_s),  fillrange = vec(y_m .+ y_s), fillalpha=0.2, c=1, label="y standard deviation")

# %% [markdown]
# ### 3. Define our statistical model

# %%
@model function stats_model(y; X=zcont, data_x=zh, data_cov=covariance)
    # Priors.
    eta ~ 200*Uniform(0.0, 0.1)
    l ~ 0.02*Uniform(0.1, 3)
    v ~ MvNormal(zeros(length(X)), ones(length(X)))
    kernel = sqexp_cov_fn(X, eta=eta, l=l)
    cpar = CosmoPar(Ωm=omegam,  Ωb=omegab, h=hc)
    mean_hz = cpar.h*100*Ez(cpar, X)
    gp = latent_GP(mean_hz, v, kernel)
    m = conditional(X, data_x, gp, sqexp_cov_fn; eta=eta, l=l)
    y ~ MvNormal(m, data_cov)
end
# Out:
# stats_model (generic function with 2 methods)

# %% [markdown]
# ### 4. Sample the model

# %%
chain = sample(stats_model(hubble_data), NUTS(100, 0.65), 1000)
# Out:
# Sampling   0%|                                          |  ETA: N/A
# ┌ Info: Found initial step size
# │   ϵ = 0.8
# └ @ Turing.Inference /home/vis09/.julia/packages/Turing/wjl7M/src/inference/hmc.jl:192
# Sampling   0%|▎                                         |  ETA: 2:40:41
# Sampling   1%|▍                                         |  ETA: 1:21:11
# Sampling   1%|▋                                         |  ETA: 0:54:09
# Sampling   2%|▊                                         |  ETA: 0:40:41
# Sampling   2%|█                                         |  ETA: 0:32:41
# Sampling   3%|█▏                                        |  ETA: 0:27:17
# Sampling   3%|█▍                                        |  ETA: 0:23:22
# Sampling   4%|█▌                                        |  ETA: 0:20:30
# Sampling   4%|█▊                                        |  ETA: 0:18:14
# Sampling   5%|█▉                                        |  ETA: 0:16:31
# Sampling   5%|██▏                                       |  ETA: 0:15:03
# Sampling   5%|██▎                                       |  ETA: 0:13:48
# Sampling   6%|██▌                                       |  ETA: 0:12:46
# Sampling   6%|██▋                                       |  ETA: 0:11:53
# Sampling   7%|██▉                                       |  ETA: 0:11:06
# Sampling   7%|███                                       |  ETA: 0:10:26
# Sampling   8%|███▎                                      |  ETA: 0:09:49
# Sampling   8%|███▍                                      |  ETA: 0:09:15
# Sampling   9%|███▋                                      |  ETA: 0:08:46
# Sampling   9%|███▉                                      |  ETA: 0:08:19
# Sampling  10%|████                                      |  ETA: 0:07:56
# Sampling  10%|████▎                                     |  ETA: 0:07:34
# Sampling  10%|████▍                                     |  ETA: 0:07:14
# Sampling  11%|████▋                                     |  ETA: 0:06:55
# Sampling  11%|████▊                                     |  ETA: 0:06:38
# Sampling  12%|█████                                     |  ETA: 0:06:22
# Sampling  12%|█████▏                                    |  ETA: 0:06:07
# Sampling  13%|█████▍                                    |  ETA: 0:05:53
# Sampling  13%|█████▌                                    |  ETA: 0:05:40
# Sampling  14%|█████▊                                    |  ETA: 0:05:28
# Sampling  14%|█████▉                                    |  ETA: 0:05:17
# Sampling  15%|██████▏                                   |  ETA: 0:05:06
# Sampling  15%|██████▎                                   |  ETA: 0:04:56
# Sampling  15%|██████▌                                   |  ETA: 0:04:47
# Sampling  16%|██████▋                                   |  ETA: 0:04:38
# Sampling  16%|██████▉                                   |  ETA: 0:04:30
# Sampling  17%|███████▏                                  |  ETA: 0:04:22
# Sampling  17%|███████▎                                  |  ETA: 0:04:15
# Sampling  18%|███████▌                                  |  ETA: 0:04:07
# Sampling  18%|███████▋                                  |  ETA: 0:04:01
# Sampling  19%|███████▉                                  |  ETA: 0:03:54
# Sampling  19%|████████                                  |  ETA: 0:03:48
# Sampling  20%|████████▎                                 |  ETA: 0:03:43
# Sampling  20%|████████▍                                 |  ETA: 0:03:37
# Sampling  20%|████████▋                                 |  ETA: 0:03:32
# Sampling  21%|████████▊                                 |  ETA: 0:03:27
# Sampling  21%|█████████                                 |  ETA: 0:03:22
# Sampling  22%|█████████▏                                |  ETA: 0:03:17
# Sampling  22%|█████████▍                                |  ETA: 0:03:12
# Sampling  23%|█████████▌                                |  ETA: 0:03:08
# Sampling  23%|█████████▊                                |  ETA: 0:03:04
# Sampling  24%|█████████▉                                |  ETA: 0:03:00
# Sampling  24%|██████████▏                               |  ETA: 0:02:56
# Sampling  25%|██████████▎                               |  ETA: 0:02:52
# Sampling  25%|██████████▌                               |  ETA: 0:02:48
# Sampling  25%|██████████▊                               |  ETA: 0:02:45
# Sampling  26%|██████████▉                               |  ETA: 0:02:42
# Sampling  26%|███████████▏                              |  ETA: 0:02:38
# Sampling  27%|███████████▎                              |  ETA: 0:02:35
# Sampling  27%|███████████▌                              |  ETA: 0:02:32
# Sampling  28%|███████████▋                              |  ETA: 0:02:30
# Sampling  28%|███████████▉                              |  ETA: 0:02:27
# Sampling  29%|████████████                              |  ETA: 0:02:24
# Sampling  29%|████████████▎                             |  ETA: 0:02:21
# Sampling  30%|████████████▍                             |  ETA: 0:02:19
# Sampling  30%|████████████▋                             |  ETA: 0:02:16
# Sampling  30%|████████████▊                             |  ETA: 0:02:14
# Sampling  31%|█████████████                             |  ETA: 0:02:11
# Sampling  31%|█████████████▏                            |  ETA: 0:02:09
# Sampling  32%|█████████████▍                            |  ETA: 0:02:07
# Sampling  32%|█████████████▌                            |  ETA: 0:02:04
# Sampling  33%|█████████████▊                            |  ETA: 0:02:02
# Sampling  33%|█████████████▉                            |  ETA: 0:02:00
# Sampling  34%|██████████████▏                           |  ETA: 0:01:58
# Sampling  34%|██████████████▍                           |  ETA: 0:01:56
# Sampling  35%|██████████████▌                           |  ETA: 0:01:54
# Sampling  35%|██████████████▊                           |  ETA: 0:01:52
# Sampling  35%|██████████████▉                           |  ETA: 0:01:50
# Sampling  36%|███████████████▏                          |  ETA: 0:01:49
# Sampling  36%|███████████████▎                          |  ETA: 0:01:47
# Sampling  37%|███████████████▌                          |  ETA: 0:01:45
# Sampling  37%|███████████████▋                          |  ETA: 0:01:43
# Sampling  38%|███████████████▉                          |  ETA: 0:01:42
# Sampling  38%|████████████████                          |  ETA: 0:01:40
# Sampling  39%|████████████████▎                         |  ETA: 0:01:38
# Sampling  39%|████████████████▍                         |  ETA: 0:01:37
# Sampling  40%|████████████████▋                         |  ETA: 0:01:35
# Sampling  40%|████████████████▊                         |  ETA: 0:01:34
# Sampling  40%|█████████████████                         |  ETA: 0:01:32
# Sampling  41%|█████████████████▏                        |  ETA: 0:01:31
# Sampling  41%|█████████████████▍                        |  ETA: 0:01:30
# Sampling  42%|█████████████████▋                        |  ETA: 0:01:28
# Sampling  42%|█████████████████▊                        |  ETA: 0:01:28
# Sampling  43%|██████████████████                        |  ETA: 0:01:27
# Sampling  43%|██████████████████▏                       |  ETA: 0:01:25
# Sampling  44%|██████████████████▍                       |  ETA: 0:01:24
# Sampling  44%|██████████████████▌                       |  ETA: 0:01:23
# Sampling  45%|██████████████████▊                       |  ETA: 0:01:21
# Sampling  45%|██████████████████▉                       |  ETA: 0:01:20
# Sampling  45%|███████████████████▏                      |  ETA: 0:01:19
# Sampling  46%|███████████████████▎                      |  ETA: 0:01:18
# Sampling  46%|███████████████████▌                      |  ETA: 0:01:17
# Sampling  47%|███████████████████▋                      |  ETA: 0:01:15
# Sampling  47%|███████████████████▉                      |  ETA: 0:01:14
# Sampling  48%|████████████████████                      |  ETA: 0:01:13
# Sampling  48%|████████████████████▎                     |  ETA: 0:01:12
# Sampling  49%|████████████████████▍                     |  ETA: 0:01:11
# Sampling  49%|████████████████████▋                     |  ETA: 0:01:10
# Sampling  50%|████████████████████▊                     |  ETA: 0:01:09
# Sampling  50%|█████████████████████                     |  ETA: 0:01:08
# Sampling  50%|█████████████████████▎                    |  ETA: 0:01:07
# Sampling  51%|█████████████████████▍                    |  ETA: 0:01:06
# Sampling  51%|█████████████████████▋                    |  ETA: 0:01:05
# Sampling  52%|█████████████████████▊                    |  ETA: 0:01:04
# Sampling  52%|██████████████████████                    |  ETA: 0:01:03
# Sampling  53%|██████████████████████▏                   |  ETA: 0:01:02
# Sampling  53%|██████████████████████▍                   |  ETA: 0:01:01
# Sampling  54%|██████████████████████▌                   |  ETA: 0:01:00
# Sampling  54%|██████████████████████▊                   |  ETA: 0:00:59
# Sampling  55%|██████████████████████▉                   |  ETA: 0:00:58
# Sampling  55%|███████████████████████▏                  |  ETA: 0:00:57
# Sampling  55%|███████████████████████▎                  |  ETA: 0:00:57
# Sampling  56%|███████████████████████▌                  |  ETA: 0:00:56
# Sampling  56%|███████████████████████▋                  |  ETA: 0:00:55
# Sampling  57%|███████████████████████▉                  |  ETA: 0:00:54
# Sampling  57%|████████████████████████                  |  ETA: 0:00:53
# Sampling  58%|████████████████████████▎                 |  ETA: 0:00:52
# Sampling  58%|████████████████████████▍                 |  ETA: 0:00:51
# Sampling  59%|████████████████████████▋                 |  ETA: 0:00:51
# Sampling  59%|████████████████████████▉                 |  ETA: 0:00:50
# Sampling  60%|█████████████████████████                 |  ETA: 0:00:49
# Sampling  60%|█████████████████████████▎                |  ETA: 0:00:48
# Sampling  60%|█████████████████████████▍                |  ETA: 0:00:47
# Sampling  61%|█████████████████████████▋                |  ETA: 0:00:47
# Sampling  61%|█████████████████████████▊                |  ETA: 0:00:46
# Sampling  62%|██████████████████████████                |  ETA: 0:00:45
# Sampling  62%|██████████████████████████▏               |  ETA: 0:00:44
# Sampling  63%|██████████████████████████▍               |  ETA: 0:00:44
# Sampling  63%|██████████████████████████▌               |  ETA: 0:00:43
# Sampling  64%|██████████████████████████▊               |  ETA: 0:00:42
# Sampling  64%|██████████████████████████▉               |  ETA: 0:00:41
# Sampling  65%|███████████████████████████▏              |  ETA: 0:00:41
# Sampling  65%|███████████████████████████▎              |  ETA: 0:00:40
# Sampling  65%|███████████████████████████▌              |  ETA: 0:00:39
# Sampling  66%|███████████████████████████▋              |  ETA: 0:00:39
# Sampling  66%|███████████████████████████▉              |  ETA: 0:00:38
# Sampling  67%|████████████████████████████▏             |  ETA: 0:00:37
# Sampling  67%|████████████████████████████▎             |  ETA: 0:00:37
# Sampling  68%|████████████████████████████▌             |  ETA: 0:00:36
# Sampling  68%|████████████████████████████▋             |  ETA: 0:00:35
# Sampling  69%|████████████████████████████▉             |  ETA: 0:00:35
# Sampling  69%|█████████████████████████████             |  ETA: 0:00:34
# Sampling  70%|█████████████████████████████▎            |  ETA: 0:00:33
# Sampling  70%|█████████████████████████████▍            |  ETA: 0:00:33
# Sampling  70%|█████████████████████████████▋            |  ETA: 0:00:32
# Sampling  71%|█████████████████████████████▊            |  ETA: 0:00:32
# Sampling  71%|██████████████████████████████            |  ETA: 0:00:31
# Sampling  72%|██████████████████████████████▏           |  ETA: 0:00:30
# Sampling  72%|██████████████████████████████▍           |  ETA: 0:00:30
# Sampling  73%|██████████████████████████████▌           |  ETA: 0:00:29
# Sampling  73%|██████████████████████████████▊           |  ETA: 0:00:28
# Sampling  74%|██████████████████████████████▉           |  ETA: 0:00:28
# Sampling  74%|███████████████████████████████▏          |  ETA: 0:00:27
# Sampling  75%|███████████████████████████████▎          |  ETA: 0:00:27
# Sampling  75%|███████████████████████████████▌          |  ETA: 0:00:26
# Sampling  75%|███████████████████████████████▊          |  ETA: 0:00:26
# Sampling  76%|███████████████████████████████▉          |  ETA: 0:00:25
# Sampling  76%|████████████████████████████████▏         |  ETA: 0:00:24
# Sampling  77%|████████████████████████████████▎         |  ETA: 0:00:24
# Sampling  77%|████████████████████████████████▌         |  ETA: 0:00:23
# Sampling  78%|████████████████████████████████▋         |  ETA: 0:00:23
# Sampling  78%|████████████████████████████████▉         |  ETA: 0:00:22
# Sampling  79%|█████████████████████████████████         |  ETA: 0:00:22
# Sampling  79%|█████████████████████████████████▎        |  ETA: 0:00:21
# Sampling  80%|█████████████████████████████████▍        |  ETA: 0:00:21
# Sampling  80%|█████████████████████████████████▋        |  ETA: 0:00:20
# Sampling  80%|█████████████████████████████████▊        |  ETA: 0:00:20
# Sampling  81%|██████████████████████████████████        |  ETA: 0:00:19
# Sampling  81%|██████████████████████████████████▏       |  ETA: 0:00:19
# Sampling  82%|██████████████████████████████████▍       |  ETA: 0:00:18
# Sampling  82%|██████████████████████████████████▌       |  ETA: 0:00:18
# Sampling  83%|██████████████████████████████████▊       |  ETA: 0:00:17
# Sampling  83%|██████████████████████████████████▉       |  ETA: 0:00:17
# Sampling  84%|███████████████████████████████████▏      |  ETA: 0:00:16
# Sampling  84%|███████████████████████████████████▍      |  ETA: 0:00:16
# Sampling  85%|███████████████████████████████████▌      |  ETA: 0:00:15
# Sampling  85%|███████████████████████████████████▊      |  ETA: 0:00:15
# Sampling  85%|███████████████████████████████████▉      |  ETA: 0:00:14
# Sampling  86%|████████████████████████████████████▏     |  ETA: 0:00:14
# Sampling  86%|████████████████████████████████████▎     |  ETA: 0:00:13
# Sampling  87%|████████████████████████████████████▌     |  ETA: 0:00:13
# Sampling  87%|████████████████████████████████████▋     |  ETA: 0:00:12
# Sampling  88%|████████████████████████████████████▉     |  ETA: 0:00:12
# Sampling  88%|█████████████████████████████████████     |  ETA: 0:00:11
# Sampling  89%|█████████████████████████████████████▎    |  ETA: 0:00:11
# Sampling  89%|█████████████████████████████████████▍    |  ETA: 0:00:10
# Sampling  90%|█████████████████████████████████████▋    |  ETA: 0:00:10
# Sampling  90%|█████████████████████████████████████▊    |  ETA: 0:00:09
# Sampling  90%|██████████████████████████████████████    |  ETA: 0:00:09
# Sampling  91%|██████████████████████████████████████▏   |  ETA: 0:00:08
# Sampling  91%|██████████████████████████████████████▍   |  ETA: 0:00:08
# Sampling  92%|██████████████████████████████████████▋   |  ETA: 0:00:08
# Sampling  92%|██████████████████████████████████████▊   |  ETA: 0:00:07
# Sampling  93%|███████████████████████████████████████   |  ETA: 0:00:07
# Sampling  93%|███████████████████████████████████████▏  |  ETA: 0:00:06
# Sampling  94%|███████████████████████████████████████▍  |  ETA: 0:00:06
# Sampling  94%|███████████████████████████████████████▌  |  ETA: 0:00:05
# Sampling  95%|███████████████████████████████████████▊  |  ETA: 0:00:05
# Sampling  95%|███████████████████████████████████████▉  |  ETA: 0:00:05
# Sampling  95%|████████████████████████████████████████▏ |  ETA: 0:00:04
# Sampling  96%|████████████████████████████████████████▎ |  ETA: 0:00:04
# Sampling  96%|████████████████████████████████████████▌ |  ETA: 0:00:03
# Sampling  97%|████████████████████████████████████████▋ |  ETA: 0:00:03
# Sampling  97%|████████████████████████████████████████▉ |  ETA: 0:00:02
# Sampling  98%|█████████████████████████████████████████ |  ETA: 0:00:02
# Sampling  98%|█████████████████████████████████████████▎|  ETA: 0:00:02
# Sampling  99%|█████████████████████████████████████████▍|  ETA: 0:00:01
# Sampling  99%|█████████████████████████████████████████▋|  ETA: 0:00:01
# Sampling 100%|█████████████████████████████████████████▊|  ETA: 0:00:00
# Sampling 100%|██████████████████████████████████████████| Time: 0:01:28
# Sampling 100%|██████████████████████████████████████████| Time: 0:01:28
# Chains MCMC chain (1000×38×1 Array{Float64, 3}):
#
# Iterations        = 101:1:1100
# Number of chains  = 1
# Samples per chain = 1000
# Wall duration     = 88.6 seconds
# Compute duration  = 88.6 seconds
# parameters        = eta, l, v[1], v[2], v[3], v[4], v[5], v[6], v[7], v[8], v[9], v[10], v[11], v[12], v[13], v[14], v[15], v[16], v[17], v[18], v[19], v[20], v[21], v[22], v[23], v[24]
# internals         = lp, n_steps, is_accept, acceptance_rate, log_density, hamiltonian_energy, hamiltonian_energy_error, max_hamiltonian_energy_error, tree_depth, numerical_error, step_size, nom_step_size
#
# Summary Statistics
#   parameters      mean       std   naive_se      mcse         ess      rhat    ⋯
#       Symbol   Float64   Float64    Float64   Float64     Float64   Float64    ⋯
#
#          eta    7.8161    5.3919     0.1705    0.3109    385.2440    1.0058    ⋯
#            l    0.0337    0.0159     0.0005    0.0006    420.7840    0.9990    ⋯
#         v[1]    0.1851    0.8724     0.0276    0.0230   1447.5855    0.9990    ⋯
#         v[2]    0.2767    0.8349     0.0264    0.0267   1144.7910    1.0008    ⋯
#         v[3]    0.0619    0.8808     0.0279    0.0181   1409.8441    0.9995    ⋯
#         v[4]    0.2063    0.7636     0.0241    0.0242    910.7815    1.0005    ⋯
#         v[5]    0.4587    0.8045     0.0254    0.0216   1598.1332    0.9993    ⋯
#         v[6]    0.3029    0.8727     0.0276    0.0233   1320.9376    1.0016    ⋯
#         v[7]    0.0342    1.0088     0.0319    0.0238   1901.6150    0.9992    ⋯
#         v[8]    0.0959    0.9332     0.0295    0.0289   1337.8123    1.0010    ⋯
#         v[9]    0.2101    0.9642     0.0305    0.0228   1316.3744    0.9998    ⋯
#        v[10]    0.1974    0.9917     0.0314    0.0258   1290.3849    0.9999    ⋯
#        v[11]    0.1859    1.0184     0.0322    0.0259   1413.3046    1.0028    ⋯
#        v[12]    0.1092    0.9513     0.0301    0.0255   1663.9259    0.9993    ⋯
#        v[13]    0.1467    0.9679     0.0306    0.0251   1255.8657    0.9991    ⋯
#        v[14]   -0.0601    1.0149     0.0321    0.0251   1269.6079    0.9992    ⋯
#        v[15]   -0.0798    1.0413     0.0329    0.0277   1431.5554    0.9997    ⋯
#       ⋮           ⋮         ⋮         ⋮          ⋮          ⋮          ⋮       ⋱
#                                                      1 column and 9 rows omitted
#
# Quantiles
#   parameters      2.5%     25.0%     50.0%     75.0%     97.5%
#       Symbol   Float64   Float64   Float64   Float64   Float64
#
#          eta    0.4016    3.1794    6.7346   11.8826   18.2251
#            l    0.0052    0.0208    0.0339    0.0484    0.0581
#         v[1]   -1.4814   -0.3903    0.1522    0.7799    1.9026
#         v[2]   -1.3431   -0.2714    0.2779    0.8256    2.0180
#         v[3]   -1.7042   -0.5288    0.1143    0.6596    1.7492
#         v[4]   -1.2883   -0.3014    0.1998    0.7137    1.6609
#         v[5]   -1.0320   -0.1499    0.4499    0.9826    2.1275
#         v[6]   -1.5195   -0.2706    0.3662    0.8565    1.9416
#         v[7]   -2.0565   -0.5638    0.0139    0.6634    2.0242
#         v[8]   -1.8117   -0.5956    0.0915    0.7534    1.8600
#         v[9]   -1.6950   -0.4510    0.2033    0.8615    1.9781
#        v[10]   -1.7646   -0.4848    0.1885    0.8847    2.1214
#        v[11]   -1.7274   -0.4952    0.1547    0.8621    2.2676
#        v[12]   -1.7605   -0.4886    0.0444    0.7398    2.0173
#        v[13]   -1.7296   -0.5294    0.1165    0.8157    2.0592
#        v[14]   -2.0060   -0.6992   -0.0354    0.5890    1.9952
#        v[15]   -2.0077   -0.8464   -0.0774    0.6494    1.8931
#       ⋮           ⋮         ⋮         ⋮         ⋮         ⋮
#                                                   9 rows omitted

# %% [markdown]
# ### 5. Check how our posteriors look like

# %%
eta_p = group(chain, :eta).value.data[:, :, 1];
l_p = group(chain, :l).value.data[:, :, 1];
v_p = group(chain, :v).value.data[:, :, 1];

# %%
println(length(v_p))
# Out:
# 24000

# %%
N_samples2 = length(eta_p)
gps2=zeros(N_samples2, 24)
ys2=zeros(N_samples2, 100)
for i in 1:N_samples2
    gps2[i, :], ys2[i, :] = model_latent_GP(eta_p[i], l_p[i], v_p[i, :];
                                                data_x=LinRange(0, 2.3, 100))
end

y_m2, y_s2 = mean(ys2, dims=1), std(ys2, dims=1);
gp_m2, gp_s2 = mean(gps2, dims=1), std(gps2, dims=1);

# %%
println(y_m2)
# Out:
# [67.52003427043289 69.00071998819777 69.95431073564598 70.58497004301468 71.09571681102547 71.64166930883502 72.31467971017433 73.14202246318382 74.09107824837366 75.09126723756464 76.07526621124279 77.01426607168655 77.92092027371827 78.82667424161042 79.7633278285509 80.76121715503137 81.84751296002952 83.03207877536833 84.29631942144313 85.60498610634468 86.93113765162033 88.26509974774262 89.60075930077888 90.92442142931108 92.22453952895914 93.50570180655514 94.78190049822012 96.05632535059003 97.31790285167938 98.56133685422243 99.80195190159245 101.0637068469183 102.35837593855963 103.6857163850901 105.05059916268412 106.46648652251544 107.93719884997984 109.44555312333631 110.96972219553054 112.50606760652268 114.06580997851187 115.65158756976176 117.25015981790587 118.85209410805476 120.46676391725926 122.10760942970695 123.76921635586064 125.43215015666438 127.08989479996171 128.75792497353618 130.45147135469384 132.16594773102068 133.88910854001017 135.6239664393224 137.38422603166842 139.16746832103962 140.94836691782214 142.70564448311865 144.44465256244564 146.18287901689126 147.92169839421013 149.64834504872908 151.3645900326033 153.09586126707913 154.86363636701404 156.66106394751202 158.46827578579348 160.28383495518705 162.12460770027388 163.99607097507294 165.88178013449786 167.7708129851717 169.68083571254945 171.63801069975847 173.64035545642184 175.65820327173506 177.67085901304006 179.68505643788976 181.71084079087316 183.73766921771153 185.7527825991662 187.77497708158995 189.8472287146115 191.99038118434524 194.17939060220448 196.37219697138335 198.5463916193589 200.69471011082123 202.80131876487476 204.85352345332748 206.88350845265498 208.97444120925823 211.2031200265875 213.5769898093394 216.03104289407557 218.47054566329567 220.79995275270826 222.9306481377659 224.8174292060627 226.53283174189454]

# %%
plot(zh, hubble_data, label="Data", ms=2, seriestype=:scatter)
plot!(zcont, H1, label="LCDM", lc=:black)
plot!(LinRange(0, 2.3, 100), vec(y_m2), label="Y mean")
plot!(LinRange(0, 2.3, 100), vec(y_m2 .- y_s2),  fillrange = vec(y_m2 .+ y_s2), fillalpha=0.2, c=1, label="Y standard deviation")

# %%
plot(zh, hubble_data, label="Data", ms=2, seriestype=:scatter)
plot!(zcont, H1, label="LCDM", lc=:black)
plot!(zcont, vec(gp_m2), label="GP mean")
plot!(zcont, vec(gp_m2 .- gp_s2),  fillrange = vec(gp_m2 .+ gp_s2), fillalpha=0.2, c=1, label="GP standard deviation")
