# %% [markdown]
# # Setting up a latent function Gaussian Process for H(z)

# %%
# import set 
using Turing
using Distances
using LinearAlgebra
using LimberJack
using Interpolations
using GaussianProcess
using Plots
using QuadGK
using BlockDiagonals

# %% [markdown]
# ### Collate data

# %%
# setting a cosmology for the fake data 
cosmo1 = Cosmology();
rd_fid = 99.0792;

# %% [markdown]
# #### Generate fake data

# %%
# hz data
function fakedata_hz()
z  = sort(2.5 .* rand(30)) # random array of 30 z values sorted ascending (0 - 2.5)
data  = cosmo1.cpar.h*100*Ez(cosmo1, z)
err = 0.1 .* data
cov = zeros(length(z), length(z))
    for i in 1:length(z)
        cov[i, i] = err[i]^2
    end
    return (data_name = "fakedata_hz", z = z, data = data, cov = cov)
end

# chi data
function fakedata_dm()
    z = sort(2.5 .* rand(300))
    data = cosmo1.chi(z)
    err = 0.1 .* data
    cov = zeros(length(z), length(z))
    for i in 1:length(z)
        cov[i, i] = err[i]^2
    end
    return (data_name = "fakedata_dm", z = z, data = data, cov = cov)
end

# fs8 data
function fakedata_fs8()
    z = sort([[0.01, 0.02, 0.07] ; (2.5 .* rand(3))])
    data = fs8(cosmo1, z)
    err = 0.1 .* data
    cov = zeros(length(z), length(z))
    for i in 1:length(z)
        cov[i, i] = err[i]^2
    end
    return(data_name = "fakedata_fs8", z = z, data = data, cov = cov)
end

# aiso data
function fakedata_aiso()
z  = sort(2.5 .* rand(20)) # random array of 30 z values sorted ascending (0 - 2.5)
dvz_cb = ((z .* LimberJack.CLIGHT_HMPC) .* ((cosmo1.chi(z)) .^ 2)) ./ (cosmo1.cpar.h .* 100 .* Ez(cosmo1, z))
data = (dvz_cb .^ (1/3)) ./ rd_fid
err = 0.1 .* data
cov = zeros(length(z), length(z))
    for i in 1:length(z)
        cov[i, i] = err[i]^2
    end
    return (data_name = "fakedata_aiso", z = z, data = data, cov = cov)
end

# aap data
function fakedata_aap()
    z = [0.01, 0.02, 0.07, 0.32, 0.54, 1.5, 2.4]
    data = LimberJack.CLIGHT_HMPC ./ (cosmo1.cpar.h .* 100 .* Ez(cosmo1, z) .* (cosmo1.chi(z)))
    err = 0.1 .* data
    cov = zeros(length(z), length(z))
    for i in 1:length(z)
        cov[i, i] = err[i]^2
    end
    return (data_name = "fakedata_aap", z = z, data = data, cov = cov)
end

fakedatahz = fakedata_hz();
fakedatadm = fakedata_dm();
fakedatafs8 = fakedata_fs8();
fakedataaap = fakedata_aap();
fakedataaiso = fakedata_aiso();

# %% [markdown]
# #### Putting Hz, Dm and fs8 data together

# %%
# fake data
data_obs  = [fakedataaiso.data; fakedataaap.data; fakedatafs8.data];
z_obs = [fakedataaiso.z; fakedataaap.z; fakedatafs8.z];
covariance_obs = BlockDiagonal([fakedataaiso.cov, fakedataaap.cov, fakedatafs8.cov]);

# errors
aiso_err = 0.1 .* fakedataaiso.data;
aap_err = 0.1 .* fakedataaap.data;
fs8_err = 0.1 .* fakedatafs8.data;

# %% [markdown]
# ### Functions for hz, chi and fs8

# %%
# outputs are arrays, not interpolators
function hz_from_ez(zarr, h0, ez)
    ez_itp = LinearInterpolation(zarr, ez, extrapolation_bc=Line())
    hz = ez_itp(zarr) .* (h0*100)
    #hzi = linear_interpolation(zarr, hz, extrapolation_bc=Line())
    return hz
end

function dm_from_ez(zarr, h0, ez)
    chis = similar(ez)
    ez_itp = LinearInterpolation(zarr, ez, extrapolation_bc=Line())

    for i in 1:length(zarr)
        zz = zarr[i]
        chis[i] = quadgk(z -> 1.0/ez_itp(z), 0.0, zz, rtol=1E-5)[1]
        chis[i] *= LimberJack.CLIGHT_HMPC / h0
    end
    return chis
end


function fs8_from_ez(zarr, Ωm, σ8, h0, ez, cosmo_type)
    # initialising
    nz = length(zarr)
    z_max = maximum(zarr)
    x = log.(1 .+ zarr)
    a = @.(1/(1+zarr))
    dx = x[2]-x[1]
    
    aa = reverse(a)
    ee = reverse(ez)
    dd = zeros(cosmo_type, nz)
    yy = zeros(cosmo_type, nz)
    dd[1] = aa[1]
    yy[1] = aa[1]^3*ee[end]
    
    for i in 1:(nz-1)
        A0 = -1.5 * Ωm / (aa[i]*ee[i])
        B0 = -1. / (aa[i]^2*ee[i])
        A1 = -1.5 * Ωm / (aa[i+1]*ee[i+1])
        B1 = -1. / (aa[i+1]^2*ee[i+1])
        yy[i+1] = (1+0.5*dx^2*A0*B0)*yy[i] + 0.5*(A0+A1)*dx*dd[i]
        dd[i+1] = 0.5*(B0+B1)*dx*yy[i] + (1+0.5*dx^2*A0*B0)*dd[i]
    end
    
    y = reverse(yy)
    d = reverse(dd)

    fs8zi =  -σ8 .* y./ (a.^2 .*ez.*d[1])
                                
                        
    return fs8zi
end
# Out:
# fs8_from_ez (generic function with 1 method)

# %%
function dh(zarr, h0, ez)
    dhz = LimberJack.CLIGHT_HMPC ./ (hz_from_ez(zarr, h0, ez))
    return dhz
end

function dv(zarr, h0, ez)
    dvz_cbrt = zarr .* dh(zarr, h0, ez) .* ((dm_from_ez(zarr, h0, ez)) .^ 2)
    dvz = dvz_cbrt .^ (1/3)
    return dvz
end

function a_ap(zarr, h0, ez)
  numer = dh(zarr, h0, ez) ./ dm_from_ez(zarr, h0, ez)
  return numer 
end

function a_iso(zarr, h0, rd, ez)
    numer = dv(zarr, h0, ez) ./ rd
    return numer 
end
# Out:
# a_iso (generic function with 1 method)

# %%
z_integ1 = max.(cosmo1.settings.zs, 1e-12);
ez_test = Ez(cosmo1, z_integ1);

# %%
p1 = plot(fakedataaiso.z, fakedataaiso.data, yerr=aiso_err, seriestype=:scatter,title="aiso(z)", legend=false)
p2 = plot(fakedataaap.z, fakedataaap.data, yerr=aap_err, seriestype=:scatter, title="aap(z)", legend=false)
p3 = plot(fakedatafs8.z, fakedatafs8.data, yerr=fs8_err, seriestype=:scatter, title="fs8(z)", legend=false)

plot!(p1, z_integ1, a_iso(z_integ1, cosmo1.cpar.h, rd_fid, ez_test), color=:black)
plot!(p2, z_integ1, a_ap(z_integ1, cosmo1.cpar.h, ez_test), color=:black)
plot!(p3, z_integ1, fs8_from_ez(z_integ1, cosmo1.cpar.Ωm, cosmo1.cpar.σ8, cosmo1.cpar.h, ez_test, eltype(ez_test)), color=:black)

plot(p1, p2, p3, layout=(1,3), size=(900,300))

# %% [markdown]
# ## LCDM analysis

# %%
@model function LCDM_model(data, data_cov)
    # Priors
    omegam_pr ~ Uniform(0.1, 0.5)
    h0_pr ~ Uniform(0.6, 0.8)
    s8_pr ~ Uniform(0.6, 0.9)
    rd_pr ~ Uniform(90,110)

    # Create cosmology
    cosmo_pr = LimberJack.Cosmology(Ωm=cosmo1.cpar.Ωm, Ωb=cosmo1.cpar.Ωb, h=cosmo1.cpar.h, σ8=s8_pr);
    
    # Model predictions
    ez_model = Ez(cosmo_pr, z_integ1)
    dv_rd_model = a_iso(z_integ1, h0_pr, rd_pr, ez_model) 
    dh_dm_model = a_ap(z_integ1, h0_pr, ez_model)
    fs8_model = fs8_from_ez(z_integ1, omegam_pr, s8_pr, h0_pr, ez_model, eltype(ez_model))

    # Create interpolators
    dvrd_itp = LinearInterpolation(z_integ1, dv_rd_model, extrapolation_bc=Line())
    dhdm_itp = LinearInterpolation(z_integ1, dh_dm_model, extrapolation_bc=Line())
    fs8_itp = LinearInterpolation(z_integ1, fs8_model, extrapolation_bc=Line())

    dvrd_theory := dvrd_itp(fakedataaiso.z)
    dhdm_theory := dhdm_itp(fakedataaap.z)
    fs8_theory := fs8_itp(fakedatafs8.z)

    theory = [dvrd_theory;dhdm_theory;fs8_theory]

    # Likelihood
    data ~ MvNormal(theory, data_cov)
end
# Out:
# LCDM_model (generic function with 2 methods)

# %%
cond_LCDM_model = LCDM_model(data_obs, covariance_obs)
chain_LCDM = sample(cond_LCDM_model, NUTS(20, 0.65), 100)
# Out:
# Sampling   0%|                                          |  ETA: N/A
# ┌ Info: Found initial step size
# │   ϵ = 0.2
# └ @ Turing.Inference /Users/vis/.julia/packages/Turing/QN7BL/src/mcmc/hmc.jl:212
# Sampling   1%|▍                                         |  ETA: 0:03:35
# Sampling   2%|▊                                         |  ETA: 0:01:50
# Sampling   2%|█                                         |  ETA: 0:01:14
# Sampling   3%|█▍                                        |  ETA: 0:00:56
# Sampling   4%|█▊                                        |  ETA: 0:00:45
# Sampling   5%|██▏                                       |  ETA: 0:00:39
# Sampling   6%|██▌                                       |  ETA: 0:00:34
# Sampling   7%|██▊                                       |  ETA: 0:00:30
# Sampling   8%|███▏                                      |  ETA: 0:00:36
# Sampling   8%|███▌                                      |  ETA: 0:00:34
# Sampling   9%|███▉                                      |  ETA: 0:00:32
# Sampling  10%|████▎                                     |  ETA: 0:00:30
# Sampling  11%|████▌                                     |  ETA: 0:00:29
# Sampling  12%|████▉                                     |  ETA: 0:00:27
# Sampling  12%|█████▎                                    |  ETA: 0:00:31
# Sampling  13%|█████▋                                    |  ETA: 0:00:30
# Sampling  14%|██████                                    |  ETA: 0:00:28
# Sampling  15%|██████▎                                   |  ETA: 0:00:27
# Sampling  16%|██████▋                                   |  ETA: 0:00:27
# Sampling  17%|███████                                   |  ETA: 0:00:25
# Sampling  18%|███████▍                                  |  ETA: 0:00:25
# Sampling  18%|███████▊                                  |  ETA: 0:00:23
# Sampling  19%|████████                                  |  ETA: 0:00:22
# Sampling  20%|████████▍                                 |  ETA: 0:00:22
# Sampling  21%|████████▊                                 |  ETA: 0:00:22
# Sampling  22%|█████████▏                                |  ETA: 0:00:21
# Sampling  22%|█████████▌                                |  ETA: 0:00:20
# Sampling  23%|█████████▊                                |  ETA: 0:00:20
# Sampling  24%|██████████▏                               |  ETA: 0:00:19
# Sampling  25%|██████████▌                               |  ETA: 0:00:19
# Sampling  26%|██████████▉                               |  ETA: 0:00:18
# Sampling  27%|███████████▎                              |  ETA: 0:00:18
# Sampling  28%|███████████▌                              |  ETA: 0:00:17
# Sampling  28%|███████████▉                              |  ETA: 0:00:17
# Sampling  29%|████████████▎                             |  ETA: 0:00:17
# Sampling  30%|████████████▋                             |  ETA: 0:00:17
# Sampling  31%|█████████████                             |  ETA: 0:00:17
# Sampling  32%|█████████████▎                            |  ETA: 0:00:16
# Sampling  32%|█████████████▋                            |  ETA: 0:00:16
# Sampling  33%|██████████████                            |  ETA: 0:00:16
# Sampling  34%|██████████████▍                           |  ETA: 0:00:15
# Sampling  35%|██████████████▊                           |  ETA: 0:00:15
# Sampling  36%|███████████████                           |  ETA: 0:00:15
# Sampling  37%|███████████████▍                          |  ETA: 0:00:15
# Sampling  38%|███████████████▊                          |  ETA: 0:00:15
# Sampling  38%|████████████████▏                         |  ETA: 0:00:14
# Sampling  39%|████████████████▌                         |  ETA: 0:00:14
# Sampling  40%|████████████████▊                         |  ETA: 0:00:14
# Sampling  41%|█████████████████▏                        |  ETA: 0:00:14
# Sampling  42%|█████████████████▌                        |  ETA: 0:00:14
# Sampling  42%|█████████████████▉                        |  ETA: 0:00:14
# Sampling  43%|██████████████████▎                       |  ETA: 0:00:13
# Sampling  44%|██████████████████▌                       |  ETA: 0:00:13
# Sampling  45%|██████████████████▉                       |  ETA: 0:00:13
# Sampling  46%|███████████████████▎                      |  ETA: 0:00:13
# Sampling  47%|███████████████████▋                      |  ETA: 0:00:12
# Sampling  48%|████████████████████                      |  ETA: 0:00:12
# Sampling  48%|████████████████████▎                     |  ETA: 0:00:12
# Sampling  49%|████████████████████▋                     |  ETA: 0:00:12
# Sampling  50%|█████████████████████                     |  ETA: 0:00:11
# Sampling  51%|█████████████████████▍                    |  ETA: 0:00:11
# Sampling  52%|█████████████████████▊                    |  ETA: 0:00:11
# Sampling  52%|██████████████████████                    |  ETA: 0:00:11
# Sampling  53%|██████████████████████▍                   |  ETA: 0:00:11
# Sampling  54%|██████████████████████▊                   |  ETA: 0:00:10
# Sampling  55%|███████████████████████▏                  |  ETA: 0:00:10
# Sampling  56%|███████████████████████▌                  |  ETA: 0:00:10
# Sampling  57%|███████████████████████▊                  |  ETA: 0:00:10
# Sampling  57%|████████████████████████▏                 |  ETA: 0:00:10
# Sampling  58%|████████████████████████▌                 |  ETA: 0:00:09
# Sampling  59%|████████████████████████▉                 |  ETA: 0:00:09
# Sampling  60%|█████████████████████████▎                |  ETA: 0:00:09
# Sampling  61%|█████████████████████████▌                |  ETA: 0:00:09
# Sampling  62%|█████████████████████████▉                |  ETA: 0:00:09
# Sampling  62%|██████████████████████████▎               |  ETA: 0:00:08
# Sampling  63%|██████████████████████████▋               |  ETA: 0:00:08
# Sampling  64%|███████████████████████████               |  ETA: 0:00:08
# Sampling  65%|███████████████████████████▎              |  ETA: 0:00:08
# Sampling  66%|███████████████████████████▋              |  ETA: 0:00:08
# Sampling  67%|████████████████████████████              |  ETA: 0:00:07
# Sampling  68%|████████████████████████████▍             |  ETA: 0:00:07
# Sampling  68%|████████████████████████████▊             |  ETA: 0:00:07
# Sampling  69%|█████████████████████████████             |  ETA: 0:00:07
# Sampling  70%|█████████████████████████████▍            |  ETA: 0:00:07
# Sampling  71%|█████████████████████████████▊            |  ETA: 0:00:06
# Sampling  72%|██████████████████████████████▏           |  ETA: 0:00:06
# Sampling  72%|██████████████████████████████▌           |  ETA: 0:00:06
# Sampling  73%|██████████████████████████████▊           |  ETA: 0:00:06
# Sampling  74%|███████████████████████████████▏          |  ETA: 0:00:06
# Sampling  75%|███████████████████████████████▌          |  ETA: 0:00:06
# Sampling  76%|███████████████████████████████▉          |  ETA: 0:00:05
# Sampling  77%|████████████████████████████████▎         |  ETA: 0:00:05
# Sampling  78%|████████████████████████████████▌         |  ETA: 0:00:05
# Sampling  78%|████████████████████████████████▉         |  ETA: 0:00:05
# Sampling  79%|█████████████████████████████████▎        |  ETA: 0:00:04
# Sampling  80%|█████████████████████████████████▋        |  ETA: 0:00:04
# Sampling  81%|██████████████████████████████████        |  ETA: 0:00:04
# Sampling  82%|██████████████████████████████████▎       |  ETA: 0:00:04
# Sampling  82%|██████████████████████████████████▋       |  ETA: 0:00:04
# Sampling  83%|███████████████████████████████████       |  ETA: 0:00:04
# Sampling  84%|███████████████████████████████████▍      |  ETA: 0:00:03
# Sampling  85%|███████████████████████████████████▊      |  ETA: 0:00:03
# Sampling  86%|████████████████████████████████████      |  ETA: 0:00:03
# Sampling  87%|████████████████████████████████████▍     |  ETA: 0:00:03
# Sampling  88%|████████████████████████████████████▊     |  ETA: 0:00:03
# Sampling  88%|█████████████████████████████████████▏    |  ETA: 0:00:02
# Sampling  89%|█████████████████████████████████████▌    |  ETA: 0:00:02
# Sampling  90%|█████████████████████████████████████▊    |  ETA: 0:00:02
# Sampling  91%|██████████████████████████████████████▏   |  ETA: 0:00:02
# Sampling  92%|██████████████████████████████████████▌   |  ETA: 0:00:02
# Sampling  92%|██████████████████████████████████████▉   |  ETA: 0:00:02
# Sampling  93%|███████████████████████████████████████▎  |  ETA: 0:00:01
# Sampling  94%|███████████████████████████████████████▌  |  ETA: 0:00:01
# Sampling  95%|███████████████████████████████████████▉  |  ETA: 0:00:01
# Sampling  96%|████████████████████████████████████████▎ |  ETA: 0:00:01
# Sampling  97%|████████████████████████████████████████▋ |  ETA: 0:00:01
# Sampling  98%|█████████████████████████████████████████ |  ETA: 0:00:01
# Sampling  98%|█████████████████████████████████████████▎|  ETA: 0:00:00
# Sampling  99%|█████████████████████████████████████████▋|  ETA: 0:00:00
# Sampling 100%|██████████████████████████████████████████| Time: 0:00:21
# Sampling 100%|██████████████████████████████████████████| Time: 0:00:21
# Chains MCMC chain (100×49×1 Array{Float64, 3}):
#
# Iterations        = 21:1:120
# Number of chains  = 1
# Samples per chain = 100
# Wall duration     = 22.04 seconds
# Compute duration  = 22.04 seconds
# parameters        = omegam_pr, h0_pr, s8_pr, rd_pr, dvrd_theory[1], dvrd_theory[2], dvrd_theory[3], dvrd_theory[4], dvrd_theory[5], dvrd_theory[6], dvrd_theory[7], dvrd_theory[8], dvrd_theory[9], dvrd_theory[10], dvrd_theory[11], dvrd_theory[12], dvrd_theory[13], dvrd_theory[14], dvrd_theory[15], dvrd_theory[16], dvrd_theory[17], dvrd_theory[18], dvrd_theory[19], dvrd_theory[20], dhdm_theory[1], dhdm_theory[2], dhdm_theory[3], dhdm_theory[4], dhdm_theory[5], dhdm_theory[6], dhdm_theory[7], fs8_theory[1], fs8_theory[2], fs8_theory[3], fs8_theory[4], fs8_theory[5], fs8_theory[6]
# internals         = lp, n_steps, is_accept, acceptance_rate, log_density, hamiltonian_energy, hamiltonian_energy_error, max_hamiltonian_energy_error, tree_depth, numerical_error, step_size, nom_step_size
#
# Summary Statistics
#        parameters      mean       std      mcse   ess_bulk   ess_tail      rha ⋯
#            Symbol   Float64   Float64   Float64    Float64    Float64   Float6 ⋯
#
#         omegam_pr    0.3059    0.0176    0.0022    72.2831    78.3393    0.993 ⋯
#             h0_pr    0.6706    0.0400    0.0067    37.5659    30.8992    1.033 ⋯
#             s8_pr    0.7952    0.0578    0.0076    56.5423    58.9391    0.993 ⋯
#             rd_pr   99.6984    5.7144    0.9493    34.6489    21.0246    1.026 ⋯
#    dvrd_theory[1]    0.7857    0.0163    0.0015   109.3434    51.1207    1.004 ⋯
#    dvrd_theory[2]    2.1875    0.0454    0.0042   109.3434    51.1207    1.003 ⋯
#    dvrd_theory[3]    2.3356    0.0484    0.0045   109.3434    51.1207    1.003 ⋯
#    dvrd_theory[4]    2.4006    0.0498    0.0046   109.3434    51.1207    1.003 ⋯
#    dvrd_theory[5]    3.4131    0.0708    0.0066   109.3434    51.1207    1.003 ⋯
#    dvrd_theory[6]    4.5936    0.0953    0.0089   109.3434    51.1207    1.003 ⋯
#    dvrd_theory[7]    4.7564    0.0986    0.0092   109.3434    51.1207    1.003 ⋯
#    dvrd_theory[8]    6.5607    0.1361    0.0126   109.3434    51.1207    1.004 ⋯
#    dvrd_theory[9]    6.7224    0.1394    0.0130   109.3434    51.1207    1.003 ⋯
#   dvrd_theory[10]    7.3958    0.1534    0.0143   109.3434    51.1207    1.004 ⋯
#   dvrd_theory[11]    8.0352    0.1666    0.0155   109.3434    51.1207    1.002 ⋯
#   dvrd_theory[12]    8.2721    0.1715    0.0159   109.3434    51.1207    1.004 ⋯
#   dvrd_theory[13]    8.5040    0.1764    0.0164   109.3434    51.1207    1.004 ⋯
#          ⋮             ⋮         ⋮         ⋮         ⋮          ⋮          ⋮   ⋱
#                                                    2 columns and 20 rows omitted
#
# Quantiles
#        parameters      2.5%     25.0%     50.0%      75.0%      97.5%
#            Symbol   Float64   Float64   Float64    Float64    Float64
#
#         omegam_pr    0.2808    0.2941    0.3035     0.3159     0.3490
#             h0_pr    0.6091    0.6363    0.6715     0.6983     0.7428
#             s8_pr    0.6623    0.7619    0.8024     0.8398     0.8810
#             rd_pr   90.1617   95.2180   99.4430   103.8404   109.6934
#    dvrd_theory[1]    0.7534    0.7751    0.7882     0.7967     0.8185
#    dvrd_theory[2]    2.0977    2.1580    2.1944     2.2181     2.2788
#    dvrd_theory[3]    2.2397    2.3041    2.3429     2.3683     2.4330
#    dvrd_theory[4]    2.3020    2.3682    2.4082     2.4342     2.5008
#    dvrd_theory[5]    3.2730    3.3671    3.4239     3.4609     3.5556
#    dvrd_theory[6]    4.4049    4.5316    4.6081     4.6579     4.7853
#    dvrd_theory[7]    4.5611    4.6922    4.7714     4.8230     4.9549
#    dvrd_theory[8]    6.2913    6.4722    6.5815     6.6526     6.8345
#    dvrd_theory[9]    6.4463    6.6317    6.7436     6.8165     7.0029
#   dvrd_theory[10]    7.0921    7.2960    7.4192     7.4994     7.7044
#   dvrd_theory[11]    7.7052    7.9268    8.0606     8.1477     8.3705
#   dvrd_theory[12]    7.9324    8.1605    8.2982     8.3879     8.6173
#   dvrd_theory[13]    8.1548    8.3893    8.5309     8.6231     8.8589
#          ⋮             ⋮         ⋮         ⋮         ⋮          ⋮
#                                                         20 rows omitted

# %%
# lcdm chains
hzdata_lcdm = group(chain_LCDM, :dvrd_theory).value.data[:,:,1];
chidata_lcdm = group(chain_LCDM, :dhdm_theory).value.data[:,:,1];
fs8data_lcdm = group(chain_LCDM, :fs8_theory).value.data[:,:,1];

# mean and standard deviation - lcdm
hz_lcdm_m, hz_lcdm_s = mean(hzdata_lcdm, dims=1), std(hzdata_lcdm, dims=1); 
dm_lcdm_m, dm_lcdm_s = mean(chidata_lcdm, dims=1), std(chidata_lcdm, dims=1); 
fs8_lcdm_m, fs8_lcdm_s = mean(fs8data_lcdm, dims=1), std(fs8data_lcdm, dims=1);

# %%
plot(fakedataaiso.z, fakedataaiso.data, yerr=aiso_err, label="Data a_iso", ms=2, seriestype=:scatter)
plot!(fakedataaiso.z, vec(hz_lcdm_m), label=" a_iso LCDM mean")
plot!(fakedataaiso.z, vec(hz_lcdm_m .- hz_lcdm_s),  fillrange = vec(hz_lcdm_m .+ hz_lcdm_s), fillalpha=0.2, c=1, label="a_iso LCDM standard deviation")

# %%
plot(fakedataaap.z, fakedataaap.data, yerr=aap_err, label="Data a_ap", ms=2, seriestype=:scatter)
plot!(fakedataaap.z, vec(dm_lcdm_m), label="a_ap LCDM mean")
plot!(fakedataaap.z, vec(dm_lcdm_m .- dm_lcdm_s),  fillrange = vec(dm_lcdm_m .+ dm_lcdm_s), fillalpha=0.2, c=1, label="a_ap LCDM standard deviation")

# %%
plot(fakedatafs8.z, fakedatafs8.data, yerr=fs8_err, label="Data fs8", ms=2, seriestype=:scatter)
plot!(fakedatafs8.z, vec(fs8_lcdm_m), label="fs8 lcdm")
plot!(fakedatafs8.z, vec(fs8_lcdm_m .- fs8_lcdm_s),  fillrange = vec(fs8_lcdm_m .+ fs8_lcdm_s), fillalpha=0.2, c=1, label="fs8 lcdm standard deviation")

# %% [markdown]
# ## GP modelling - priors

# %%
zlat = range(0, 3.0, length=30); # latent variable space
z_integ2 = cosmo1.settings.zs; # integral variable space
z_integ = max.(z_integ2, 1e-12);

# %%
function model_latent_GP(eta, l, v; omega_m=cosmo1.cpar.Ωm, sigma_8=cosmo1.cpar.σ8, h_0 = cosmo1.cpar.h,
                         x=zlat, z=z_obs, data_cov=covariance_obs)
    # Dimensions of predictors .
    kernel = sqexp_cov_fn(x; eta=eta, l=l)
    cpar = CosmoPar(Ωm=omega_m,  Ωb=cosmo1.cpar.Ωb, h=h_0, σ8=sigma_8)
    mean_ex = Ez(cpar, x)
    # a latent GP is carried out using a Wiener filter
    ex = latent_GP(mean_ex, v, kernel)
    # transforms hx from x space to z space
    ez =  conditional(x, z, ex, sqexp_cov_fn;
                     eta=eta, l=l)
    return ex, ez
end
# Out:
# model_latent_GP (generic function with 1 method)

# %% [markdown]
# hx is the GP realisation of the hubble parameter. hz transforms hx from the latent space to another parameter space (integral or observation).

# %%
N_samples = 100
# data parameter space conditional
exs1=zeros(N_samples, 30) #latent variable chain
ezs1=zeros(N_samples, length(z_obs)) #observed variable chain
# pick 100 random hyperparameter combinations, and compute the GP realisation of them in both latent and conditional space.
for i in 1:N_samples
    v = rand(MvNormal(zeros(length(zlat)), ones(length(zlat))))
    exs1[i, :], ezs1[i, :] = model_latent_GP(0.1, 0.3, v)
end
y_m1, y_s1 = mean(ezs1, dims=1), std(ezs1, dims=1); #observed space
gp_m1, gp_s1 = mean(exs1, dims=1), std(exs1, dims=1); #latent space

# %%
# integral parameter space conditional
exs2=zeros(N_samples, length(zlat))
ezs2=zeros(N_samples, length(z_integ))
hz_pr=zeros(N_samples, length(z_integ))
dm_pr=zeros(N_samples, length(z_integ))
fs8_pr=zeros(N_samples, length(z_integ))

for i in 1:N_samples
    v = rand(MvNormal(zeros(length(zlat)), ones(length(zlat))))
    h_pr = rand(Uniform(0.6, 0.8))
    s8_pr = rand(Uniform(0.7, 0.9))
    omegam_pr = rand(Uniform(0.25,0.35))
    r_pr = rand(Uniform(90,110))
    exs2[i, :], ezs2[i, :] = model_latent_GP(0.1, 0.3, v; z=z_integ, sigma_8=s8_pr)
    hz_pr[i, :] = a_iso(z_integ, h_pr, r_pr, ezs2[i, :])
    dm_pr[i, :] = a_ap(z_integ, h_pr, ezs2[i, :])
    fs8_pr[i, :] = fs8_from_ez(z_integ, omegam_pr, s8_pr, h_pr, ezs2[i, :], eltype(ezs2[i, :]))
end

y_m2, y_s2 = mean(ezs2, dims=1), std(ezs2, dims=1); #integral space
gp_m2, gp_s2 = mean(exs2, dims=1), std(exs2, dims=1); #latent space

hz_m2, hz_s2 = mean(hz_pr, dims=1), std(hz_pr, dims=1); 
chi_m2, chi_s2 = mean(dm_pr, dims=1), std(dm_pr, dims=1);
fs8_m2, fs8_s2 = mean(fs8_pr, dims=1), std(fs8_pr, dims=1);

# %%
# prior model predictions
hz_itp2 = LinearInterpolation(z_integ, vec(hz_m2), extrapolation_bc=Line());
dm_itp2 = LinearInterpolation(z_integ, vec(chi_m2), extrapolation_bc=Line());
fs8_itp2 = LinearInterpolation(z_integ, vec(fs8_m2), extrapolation_bc=Line());

# %%
# integral space hz plot
plot(fakedataaiso.z, fakedataaiso.data, yerr=aiso_err, label="Data hz", ms=2, seriestype=:scatter)
plot!(z_integ, vec(hz_m2), label="hz mean")
plot!(z_integ, vec(hz_m2 .- hz_s2),  fillrange = vec(hz_m2 .+ hz_s2), fillalpha=0.2, c=1, label="hz standard deviation")

# %%
# plotting chi data 
plot(fakedataaap.z, fakedataaap.data, yerr=aap_err, label="Data chi", ms=2, seriestype=:scatter)
plot!(z_integ, vec(chi_m2), label="chi mean")
plot!(z_integ, vec(chi_m2 .- chi_s2),  fillrange = vec(chi_m2 .+ chi_s2), fillalpha=0.2, c=1, label="chi standard deviation")

# %%
# plotting fs8 data 
plot(fakedatafs8.z, fakedatafs8.data, yerr=fs8_err, label="Data fs8", ms=2, seriestype=:scatter)
plot!(z_integ, vec(fs8_m2), label="fs8 mean")
plot!(z_integ, vec(fs8_m2 .- fs8_s2),  fillrange = vec(fs8_m2 .+ fs8_s2), fillalpha=0.2, c=1, label="fs8 standard deviation")

# %% [markdown]
# ## GP modelling - posteriors

# %%
@model function stats_model(y; int_grid=z_integ, X=zlat, data_x=z_obs, data_cov=covariance_obs)
    # Priors, parameters
    eta2 = 2
    l2 = 0.3
    v_po ~ MvNormal(zeros(length(X)), ones(length(X)))
    omegam_po ~ Uniform(0.25, 0.35)
    s8_po ~ Uniform(0.7, 0.9)
    h_po ~ Uniform(0.6, 0.8)
    r_po ~ Uniform(90,110)

    kernel = sqexp_cov_fn(X, eta=eta2, l=l2)
    cpar = CosmoPar(Ωm=cosmo1.cpar.Ωm, Ωb=cosmo1.cpar.Ωb, h=cosmo1.cpar.h, σ8=s8_po)
    mean_ez = Ez(cpar, X)
    ez_latent = latent_GP(mean_ez, v_po, kernel)
    ez_gp = conditional(X, int_grid, ez_latent, sqexp_cov_fn; eta=eta2, l=l2) # converting from latent space to integral space
    
    # sampling over parameters
    #hz = a_iso(int_grid, h_po, r_po, ez_gp);
    chi = a_ap(int_grid, h_po, ez_gp);
    fs8 = fs8_from_ez(int_grid, omegam_po, s8_po, h_po, ez_gp, eltype(ez_gp));

    #hz_interp = LinearInterpolation(int_grid, hz, extrapolation_bc=Line())
    chi_interp = LinearInterpolation(int_grid, chi, extrapolation_bc=Line())
    fs8_interp = LinearInterpolation(int_grid, fs8, extrapolation_bc=Line())

    #hdata := hz_interp(fakedataaiso.z)
    hdata := fakedataaiso.data
    chidata := chi_interp(fakedataaap.z)
    fs8data := fs8_interp(fakedatafs8.z)
    datay = [hdata;chidata;fs8data]

    y ~ MvNormal(datay, data_cov) # FIGURE THIS OUT

end
# Out:
# stats_model (generic function with 2 methods)

# %%
chain_gp = sample(stats_model(data_obs), NUTS(5, 0.65), 25)
# Out:
# Sampling   0%|                                          |  ETA: N/A
# ┌ Info: Found initial step size
# │   ϵ = 0.025
# └ @ Turing.Inference /Users/vis/.julia/packages/Turing/QN7BL/src/mcmc/hmc.jl:212
# Sampling   3%|█▍                                        |  ETA: 0:01:03
# Sampling   7%|██▊                                       |  ETA: 0:00:31
# Sampling  10%|████▎                                     |  ETA: 0:00:22
# Sampling  13%|█████▋                                    |  ETA: 0:00:20
# Sampling  17%|███████                                   |  ETA: 0:00:16
# Sampling  20%|████████▍                                 |  ETA: 0:00:16
# Sampling  23%|█████████▊                                |  ETA: 0:00:16
# Sampling  27%|███████████▎                              |  ETA: 0:00:18
# Sampling  30%|████████████▋                             |  ETA: 0:00:19
# Sampling  33%|██████████████                            |  ETA: 0:00:18
# Sampling  37%|███████████████▍                          |  ETA: 0:00:17
# Sampling  40%|████████████████▊                         |  ETA: 0:00:16
# Sampling  43%|██████████████████▎                       |  ETA: 0:00:16
# Sampling  47%|███████████████████▋                      |  ETA: 0:00:15
# Sampling  50%|█████████████████████                     |  ETA: 0:00:14
# Sampling  53%|██████████████████████▍                   |  ETA: 0:00:13
# Sampling  57%|███████████████████████▊                  |  ETA: 0:00:12
# Sampling  60%|█████████████████████████▎                |  ETA: 0:00:11
# Sampling  63%|██████████████████████████▋               |  ETA: 0:00:10
# Sampling  67%|████████████████████████████              |  ETA: 0:00:10
# Sampling  70%|█████████████████████████████▍            |  ETA: 0:00:09
# Sampling  73%|██████████████████████████████▊           |  ETA: 0:00:08
# Sampling  77%|████████████████████████████████▎         |  ETA: 0:00:07
# Sampling  80%|█████████████████████████████████▋        |  ETA: 0:00:06
# Sampling  83%|███████████████████████████████████       |  ETA: 0:00:05
# Sampling  87%|████████████████████████████████████▍     |  ETA: 0:00:04
# Sampling  90%|█████████████████████████████████████▊    |  ETA: 0:00:03
# Sampling  93%|███████████████████████████████████████▎  |  ETA: 0:00:02
# Sampling  97%|████████████████████████████████████████▋ |  ETA: 0:00:01
# Sampling 100%|██████████████████████████████████████████| Time: 0:00:31
# Sampling 100%|██████████████████████████████████████████| Time: 0:00:31
# Chains MCMC chain (25×79×1 Array{Float64, 3}):
#
# Iterations        = 6:1:30
# Number of chains  = 1
# Samples per chain = 25
# Wall duration     = 31.14 seconds
# Compute duration  = 31.14 seconds
# parameters        = v_po[1], v_po[2], v_po[3], v_po[4], v_po[5], v_po[6], v_po[7], v_po[8], v_po[9], v_po[10], v_po[11], v_po[12], v_po[13], v_po[14], v_po[15], v_po[16], v_po[17], v_po[18], v_po[19], v_po[20], v_po[21], v_po[22], v_po[23], v_po[24], v_po[25], v_po[26], v_po[27], v_po[28], v_po[29], v_po[30], omegam_po, s8_po, h_po, r_po, hdata[1], hdata[2], hdata[3], hdata[4], hdata[5], hdata[6], hdata[7], hdata[8], hdata[9], hdata[10], hdata[11], hdata[12], hdata[13], hdata[14], hdata[15], hdata[16], hdata[17], hdata[18], hdata[19], hdata[20], chidata[1], chidata[2], chidata[3], chidata[4], chidata[5], chidata[6], chidata[7], fs8data[1], fs8data[2], fs8data[3], fs8data[4], fs8data[5], fs8data[6]
# internals         = lp, n_steps, is_accept, acceptance_rate, log_density, hamiltonian_energy, hamiltonian_energy_error, max_hamiltonian_energy_error, tree_depth, numerical_error, step_size, nom_step_size
#
# Summary Statistics
#   parameters      mean       std      mcse   ess_bulk   ess_tail      rhat   e ⋯
#       Symbol   Float64   Float64   Float64    Float64    Float64   Float64     ⋯
#
#      v_po[1]    0.0307    0.0915    0.0340     6.8928    24.3069    1.2018     ⋯
#      v_po[2]    0.0812    0.2855    0.0496    33.1251    12.0304    1.4059     ⋯
#      v_po[3]    0.1619    0.8512    0.1479    33.1251    29.2431    0.9821     ⋯
#      v_po[4]   -0.1752    0.9723    0.1689    33.1251    33.1251    0.9958     ⋯
#      v_po[5]    0.0471    1.1642    0.2280    22.3742    33.1251    1.0659     ⋯
#      v_po[6]    0.1156    1.0434    0.1813    33.1251    33.1251    0.9754     ⋯
#      v_po[7]    0.0733    1.0180    0.2001    26.4503    10.3080    1.1761     ⋯
#      v_po[8]   -0.0507    0.7449    0.1389    31.3676    33.1251    0.9839     ⋯
#      v_po[9]   -0.0156    0.8946    0.1572    33.1251    14.0177    0.9808     ⋯
#     v_po[10]    0.5369    0.8702    0.1956    22.4717    24.3380    0.9736     ⋯
#     v_po[11]   -0.2503    0.7797    0.1921    17.4934    15.5294    0.9923     ⋯
#     v_po[12]   -0.2604    0.5372    0.0933    33.1251    24.3380    0.9631     ⋯
#     v_po[13]   -0.0385    1.0812    0.2057    25.2341    13.1817    1.2282     ⋯
#     v_po[14]    0.0189    0.7882    0.1690    15.9811    18.0684    1.0684     ⋯
#     v_po[15]    0.2620    1.1276    0.1959    28.3300    13.1271    1.0305     ⋯
#     v_po[16]    0.3933    1.4656    0.2547    33.1251    15.5294    0.9920     ⋯
#     v_po[17]   -0.0015    0.9114    0.1689    24.6959    24.3069    1.0131     ⋯
#       ⋮           ⋮         ⋮         ⋮         ⋮          ⋮          ⋮        ⋱
#                                                     1 column and 50 rows omitted
#
# Quantiles
#   parameters      2.5%     25.0%     50.0%     75.0%     97.5%
#       Symbol   Float64   Float64   Float64   Float64   Float64
#
#      v_po[1]   -0.1311   -0.0142    0.0234    0.0596    0.2035
#      v_po[2]   -0.3629   -0.0960    0.0745    0.1911    0.6377
#      v_po[3]   -1.3617   -0.5139    0.2292    0.8878    1.3337
#      v_po[4]   -1.8216   -1.0859   -0.0254    0.4869    1.2872
#      v_po[5]   -1.8958   -0.6691    0.0498    0.3457    2.3378
#      v_po[6]   -2.0809   -0.3465    0.3672    0.6940    1.7012
#      v_po[7]   -1.5216   -0.7471    0.2437    0.7385    1.7518
#      v_po[8]   -1.1924   -0.5241   -0.0675    0.3702    1.2488
#      v_po[9]   -1.3989   -0.6146    0.0324    0.3667    1.8806
#     v_po[10]   -0.7024   -0.0856    0.4476    1.1763    2.1002
#     v_po[11]   -1.4603   -0.7965   -0.3839    0.5231    0.9328
#     v_po[12]   -1.2819   -0.5609   -0.2813    0.0876    0.6303
#     v_po[13]   -1.9850   -0.6340   -0.1966    0.3493    2.0570
#     v_po[14]   -1.3153   -0.4893   -0.0813    0.6620    1.2789
#     v_po[15]   -1.7894   -0.5705    0.1534    1.1861    1.9561
#     v_po[16]   -2.1868   -0.6388    0.0102    1.8446    2.4101
#     v_po[17]   -1.3119   -0.8877    0.1430    0.7308    1.3813
#       ⋮           ⋮         ⋮         ⋮         ⋮         ⋮
#                                                  50 rows omitted

# %%
hdata_p = group(chain_gp, :hdata).value.data[:,:,1];
chidata_p =  group(chain_gp, :chidata).value.data[:,:,1];
fs8data_p =  group(chain_gp, :fs8data).value.data[:,:,1];

# %%
v_p = group(chain_gp, :v_po).value.data[:, :, 1];
omegam_p = group(chain_gp, :omegam_po).value.data[:, :, 1];
s8_p = group(chain_gp, :s8_po).value.data[:, :, 1];

# %%
hpmean, hps = mean(hdata_p, dims=1), std(hdata_p, dims=1);
chipmean, chips = mean(chidata_p, dims=1), std(chidata_p, dims=1);
fs8pmean, fs8ps = mean(fs8data_p, dims=1), std(fs8data_p, dims=1);

# %%
plot(fakedataaiso.z, fakedataaiso.data, yerr=aiso_err, label="Data hz", ms=2, seriestype=:scatter)
plot!(fakedataaiso.z, vec(hpmean), label="hz GP mean")
plot!(fakedataaiso.z, vec(hpmean .- hps),  fillrange = vec(hpmean .+ hps), fillalpha=0.2, c=1, label="GP standard deviation")

# %%
plot(fakedataaap.z, fakedataaap.data, yerr=aap_err, label="Data chi", ms=2, seriestype=:scatter)
plot!(fakedataaap.z, vec(chipmean), label="chi mean")
plot!(fakedataaap.z, vec(chipmean .- chips),  fillrange = vec(chipmean .+ chips), fillalpha=0.2, c=1, label="chi standard deviation")

# %%
plot(fakedatafs8.z, fakedatafs8.data, yerr=fs8_err, label="Data fs8", ms=2, seriestype=:scatter)
plot!(fakedatafs8.z, vec(fs8pmean), label="fs8 mean")
plot!(fakedatafs8.z, vec(fs8pmean .- fs8ps),  fillrange = vec(fs8pmean .+ fs8ps), fillalpha=0.2, c=1, label="fs8 standard deviation")

# %%
plot(fakedatafs8.z, fakedatafs8.data, yerr=fs8_err, label="Data fs8", ms=2, seriestype=:scatter)
plot!(fakedatafs8.z, vec(fs8pmean), label="fs8 mean")
plot!(fakedatafs8.z, vec(fs8pmean .- fs8ps),  fillrange = vec(fs8pmean .+ fs8ps), fillalpha=0.2, c=1, label="fs8 gp standard deviation")
plot!(fakedatafs8.z, vec(fs8_lcdm_m), label="fs8 lcdm")
plot!(fakedatafs8.z, vec(fs8_lcdm_m .- fs8_lcdm_s),  fillrange = vec(fs8_lcdm_m .+ fs8_lcdm_s), fillalpha=0.2, c=4, label="fs8 lcdm standard deviation")
