# %% [markdown]
# # Setting up a latent function Gaussian Process for H(z)

# %%
# import set 
using Turing
using Distances
using LinearAlgebra
using LimberJack
using Interpolations
using GaussianProcess
using Plots
using QuadGK
using BlockDiagonals
# Out:
#     CondaPkg Found dependencies: /Users/vis/.julia/packages/CondaPkg/0UqYV/CondaPkg.toml
#     CondaPkg Found dependencies: /Users/vis/.julia/packages/PythonCall/mkWc2/CondaPkg.toml
#     CondaPkg Found dependencies: /Users/vis/.julia/packages/IJulia/y8YGF/CondaPkg.toml
#     CondaPkg Initialising pixi
#              │ /Users/vis/.julia/artifacts/d2fecc2a9fa3eac2108d3e4d9d155e6ff5dfd0b2/bin/pixi
#              │ init
#              │ --format pixi
#              └ /Users/vis/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/.CondaPkg
# ✔ Created /Users/vis/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/.CondaPkg/pixi.toml
#     CondaPkg Wrote /Users/vis/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/.CondaPkg/pixi.toml
#              │ [dependencies]
#              │ openssl = ">=3, <3.6"
#              │ jupyter_kernel_test = "*"
#              │ jupyter_client = "*"
#              │
#              │     [dependencies.python]
#              │     channel = "conda-forge"
#              │     build = "*cp*"
#              │     version = ">=3.9,<4"
#              │
#              │ [project]
#              │ name = ".CondaPkg"
#              │ platforms = ["osx-arm64"]
#              │ channels = ["conda-forge"]
#              │ channel-priority = "strict"
#              └ description = "automatically generated by CondaPkg.jl"
#     CondaPkg Installing packages
#              │ /Users/vis/.julia/artifacts/d2fecc2a9fa3eac2108d3e4d9d155e6ff5dfd0b2/bin/pixi
#              │ install
#              └ --manifest-path /Users/vis/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/.CondaPkg/pixi.toml
# ✔ The default environment has been installed.

# %% [markdown]
# ### Collate data

# %%
# setting a cosmology for the fake data, all fiducial cosmo parameters 
cosmo1 = Cosmology();
rd_fid = 99.0792;

# assumed parameter distributions
omegam_dist = Uniform(0.1, 0.5);
h0_dist = Uniform(0.6, 0.8);
s8_dist = Uniform(0.6, 0.9);
rd_dist = Uniform(90, 110);
M_dist = Uniform(0.0, 1.0);

# %% [markdown]
# #### Generate fake data

# %%
# hz data
function fakedata_hz()
z  = sort(2.5 .* rand(30)) # random array of 30 z values sorted ascending (0 - 2.5)
data  = cosmo1.cpar.h*100*Ez(cosmo1, z)
err = 0.1 .* data
cov = zeros(length(z), length(z))
    for i in 1:length(z)
        cov[i, i] = err[i]^2
    end
    return (data_name = "fakedata_hz", z = z, data = data, cov = cov)
end

# chi data
function fakedata_dm()
    z = sort(2.5 .* rand(300))
    data = cosmo1.chi(z)
    err = 0.1 .* data
    cov = zeros(length(z), length(z))
    for i in 1:length(z)
        cov[i, i] = err[i]^2
    end
    return (data_name = "fakedata_dm", z = z, data = data, cov = cov)
end

# fs8 data
function fakedata_fs8()
    z = sort([[0.01, 0.02, 0.07] ; (2.5 .* rand(20))])
    data = fs8(cosmo1, z)
    err = 0.1 .* data
    cov = zeros(length(z), length(z))
    for i in 1:length(z)
        cov[i, i] = err[i]^2
    end
    return(data_name = "fakedata_fs8", z = z, data = data, cov = cov)
end

# aiso data
function fakedata_aiso()
z  = sort(2.5 .* rand(20)) 
dvz_cb = ((z .* LimberJack.CLIGHT_HMPC) .* ((cosmo1.chi(z)) .^ 2)) ./ (cosmo1.cpar.h .* 100 .* Ez(cosmo1, z))
data = (dvz_cb .^ (1/3)) ./ rd_fid
err = 0.1 .* data
cov = zeros(length(z), length(z))
    for i in 1:length(z)
        cov[i, i] = err[i]^2
    end
    return (data_name = "fakedata_aiso", z = z, data = data, cov = cov)
end

# aap data
function fakedata_aap()
    z = sort([[0.01, 0.02, 0.03, 0.05, 0.06, 0.07] ; (2.5 .* rand(15))])
    data = LimberJack.CLIGHT_HMPC ./ (cosmo1.cpar.h .* 100 .* Ez(cosmo1, z) .* (cosmo1.chi(z)))
    err = 0.1 .* data
    cov = zeros(length(z), length(z))
    for i in 1:length(z)
        cov[i, i] = err[i]^2
    end
    return (data_name = "fakedata_aap", z = z, data = data, cov = cov)
end

# supernovae data
function fakedata_mu()
    z = sort([[0.01, 0.02, 0.05, 0.09] ; (2.5 .* rand(7))])
    d_lum = (1 .+ z) .* (cosmo1.chi(z))
    data = 5 .* log10.(d_lum) .+ 25 .+ 0.5
    err = 0.1 .* data
    cov = zeros(length(z), length(z))
    for i in 1:length(z)
        cov[i, i] = err[i]^2
    end
    return (data_name = "fakedata_mu", z = z, data = data, cov = cov)
end



fakedatahz = fakedata_hz();
fakedatadm = fakedata_dm();
fakedatafs8 = fakedata_fs8();
fakedataaap = fakedata_aap();
fakedataaiso = fakedata_aiso();
fakedatamu = fakedata_mu();

# %% [markdown]
# #### Putting Hz, Dm and fs8 data together

# %%
# fake data
data_obs  = [fakedatahz.data; fakedataaiso.data; fakedataaap.data; fakedatafs8.data; fakedatamu.data];
z_obs = [fakedatahz.z; fakedataaiso.z; fakedataaap.z; fakedatafs8.z; fakedatamu.z];
covariance_obs = BlockDiagonal([fakedatahz.cov, fakedataaiso.cov, fakedataaap.cov, fakedatafs8.cov, fakedatamu.cov]);

# correlation matrix
function cov_to_cor(covariance)
    std_devs = sqrt.(diag(covariance))
    return covariance ./ (std_devs * std_devs')
end

correlation_obs = cov_to_cor(covariance_obs)

# # derived covariance
# function corr_to_cov(correlation, scale)

# errors
hz_err = 0.1 .* fakedatahz.data;
aiso_err = 0.1 .* fakedataaiso.data;
aap_err = 0.1 .* fakedataaap.data;
fs8_err = 0.1 .* fakedatafs8.data;
mu_err = 0.1 .* fakedatamu.data;

# %% [markdown]
# ### Functions for hz, chi and fs8

# %%
# outputs are arrays, not interpolators
function hz_from_ez(zarr, h0, ez)
    ez_itp = LinearInterpolation(zarr, ez, extrapolation_bc=Line())
    hz = ez_itp(zarr) .* (h0*100)
    #hzi = linear_interpolation(zarr, hz, extrapolation_bc=Line())
    return hz
end

function dm_from_ez(zarr, h0, ez)
    chis = similar(ez)
    ez_itp = LinearInterpolation(zarr, ez, extrapolation_bc=Line())

    for i in 1:length(zarr)
        zz = zarr[i]
        chis[i] = quadgk(z -> 1.0/ez_itp(z), 0.0, zz, rtol=1E-5)[1]
        chis[i] *= LimberJack.CLIGHT_HMPC / h0
    end
    return chis
end


function fs8_from_ez(zarr, Ωm, σ8, h0, ez, cosmo_type)
    # initialising
    nz = length(zarr)
    z_max = maximum(zarr)
    x = log.(1 .+ zarr)
    a = @.(1/(1+zarr))
    dx = x[2]-x[1]
    
    aa = reverse(a)
    ee = reverse(ez)
    dd = zeros(cosmo_type, nz)
    yy = zeros(cosmo_type, nz)
    dd[1] = aa[1]
    yy[1] = aa[1]^3*ee[end]
    
    for i in 1:(nz-1)
        A0 = -1.5 * Ωm / (aa[i]*ee[i])
        B0 = -1. / (aa[i]^2*ee[i])
        A1 = -1.5 * Ωm / (aa[i+1]*ee[i+1])
        B1 = -1. / (aa[i+1]^2*ee[i+1])
        yy[i+1] = (1+0.5*dx^2*A0*B0)*yy[i] + 0.5*(A0+A1)*dx*dd[i]
        dd[i+1] = 0.5*(B0+B1)*dx*yy[i] + (1+0.5*dx^2*A0*B0)*dd[i]
    end
    
    y = reverse(yy)
    d = reverse(dd)

    fs8zi =  -σ8 .* y./ (a.^2 .*ez.*d[1])
                                
                        
    return fs8zi
end


function dh(zarr, h0, ez)
    dhz = LimberJack.CLIGHT_HMPC ./ (hz_from_ez(zarr, h0, ez))
    return dhz
end

function dv(zarr, h0, ez)
    dvz_cbrt = zarr .* dh(zarr, h0, ez) .* ((dm_from_ez(zarr, h0, ez)) .^ 2)
    dvz = dvz_cbrt .^ (1/3)
    return dvz
end

function a_ap(zarr, h0, ez)
  numer = dh(zarr, h0, ez) ./ dm_from_ez(zarr, h0, ez)
  return numer 
end

function a_iso(zarr, h0, rd, ez)
    numer = dv(zarr, h0, ez) ./ rd
    return numer 
end

function d_lum(zarr, h0, ez)
    dlz = (1 .+ zarr) .* dm_from_ez(zarr, h0, ez)
    return dlz
end

function mu(zarr, h0, M, ez)
    muz = 5 .* log10.(d_lum(zarr, h0, ez)) .+ 25 .+ M
    return muz
end
# Out:
# mu (generic function with 1 method)

# %%
#z_integ1 = max.(cosmo1.settings.zs, 1e-12);
z_integ1 = cosmo1.settings.zs;
ez_test = Ez(cosmo1, z_integ1);

# %%
p0 = plot(fakedatahz.z, fakedatahz.data, yerr=hz_err, seriestype=:scatter,title="H(z)", legend=false)
p1 = plot(fakedataaiso.z, fakedataaiso.data, yerr=aiso_err, seriestype=:scatter,title="aiso(z)", legend=false)
p2 = plot(fakedataaap.z, fakedataaap.data, yerr=aap_err, seriestype=:scatter, title="aap(z)", legend=false)
p3 = plot(fakedatafs8.z, fakedatafs8.data, yerr=fs8_err, seriestype=:scatter, title="fs8(z)", legend=false)
p4 = plot(fakedatamu.z, fakedatamu.data, yerr=mu_err, seriestype=:scatter, title="mu(z)", legend=false)

plot!(p0, z_integ1, hz_from_ez(z_integ1, cosmo1.cpar.h, ez_test), color=:black)
plot!(p1, z_integ1, a_iso(z_integ1, cosmo1.cpar.h, rd_fid, ez_test), color=:black)
plot!(p2, z_integ1, a_ap(z_integ1, cosmo1.cpar.h, ez_test), color=:black)
plot!(p3, z_integ1, fs8_from_ez(z_integ1, cosmo1.cpar.Ωm, cosmo1.cpar.σ8, cosmo1.cpar.h, ez_test, eltype(ez_test)), color=:black)
plot!(p4, z_integ1, mu(z_integ1, cosmo1.cpar.h, 0.5, ez_test), color=:black)

plot(p0, p1, p2, p3, p4, layout=(2,3), size=(900,600))

# %% [markdown]
# ## LCDM analysis

# %%
@model function LCDM_model(data, data_cov)
    # Priors
    omegam_pr ~ omegam_dist
    h0_pr ~ h0_dist
    s8_pr ~ s8_dist
    rd_pr ~ rd_dist
    M_pr ~ M_dist

    # Create cosmology
    cosmo_pr = LimberJack.Cosmology(Ωm=cosmo1.cpar.Ωm, Ωb=cosmo1.cpar.Ωb, h=cosmo1.cpar.h, σ8=s8_pr);
    
    # Model predictions
    ez_model = Ez(cosmo_pr, z_integ1)
    hz_model = hz_from_ez(z_integ1, h0_pr, ez_model)
    dv_rd_model = a_iso(z_integ1, h0_pr, rd_pr, ez_model) 
    dh_dm_model = a_ap(z_integ1, h0_pr, ez_model)
    fs8_model = fs8_from_ez(z_integ1, omegam_pr, s8_pr, h0_pr, ez_model, eltype(ez_model))
    mu_model = mu(z_integ1, h0_pr, M_pr, ez_model)

    # Create interpolators
    hz_itp = LinearInterpolation(z_integ1, hz_model, extrapolation_bc=Line())
    dvrd_itp = LinearInterpolation(z_integ1, dv_rd_model, extrapolation_bc=Line())
    dhdm_itp = LinearInterpolation(z_integ1, dh_dm_model, extrapolation_bc=Line())
    fs8_itp = LinearInterpolation(z_integ1, fs8_model, extrapolation_bc=Line())
    mu_itp = LinearInterpolation(z_integ1, mu_model, extrapolation_bc=Line())

    hz_theory := hz_itp(fakedatahz.z)
    dvrd_theory := dvrd_itp(fakedataaiso.z)
    dhdm_theory := dhdm_itp(fakedataaap.z)
    fs8_theory := fs8_itp(fakedatafs8.z)
    mu_theory := mu_itp(fakedatamu.z)

    theory = [hz_theory; dvrd_theory; dhdm_theory; fs8_theory; mu_theory]

    # Likelihood
    data ~ MvNormal(theory, data_cov)
end
# Out:
# LCDM_model (generic function with 2 methods)

# %%
cond_LCDM_model = LCDM_model(data_obs, covariance_obs)
chain_LCDM = sample(cond_LCDM_model, NUTS(20, 0.65), 100)
# Out:
# Sampling   0%|                                          |  ETA: N/A
# ┌ Warning: failed to find valid initial parameters in 10 tries; consider providing explicit initial parameters using the `initial_params` keyword
# └ @ Turing.Inference /Users/vis/.julia/packages/Turing/QN7BL/src/mcmc/hmc.jl:192
# Sampling 100%|██████████████████████████████████████████| Time: 0:01:14
# InterruptException:
#
#
#
# Stacktrace:
#
#   [1] _block_indices(B::BlockDiagonal{Float64, Adjoint{Float64, Matrix{Float64}}}, i::Int64, j::Int64)
#
#     @ BlockDiagonals ~/.julia/packages/BlockDiagonals/lfczO/src/blockdiagonal.jl:164
#
#   [2] getindex
#
#     @ ~/.julia/packages/BlockDiagonals/lfczO/src/blockdiagonal.jl:152 [inlined]
#
#   [3] generic_trimatdiv!(C::Vector{Float64}, uploc::Char, isunitc::Char, tfun::typeof(identity), A::BlockDiagonal{Float64, Adjoint{Float64, Matrix{Float64}}}, B::Vector{Float64})
#
#     @ LinearAlgebra /opt/homebrew/Cellar/julia/1.11.7_1/share/julia/stdlib/v1.11/LinearAlgebra/src/triangular.jl:1459
#
#   [4] _ldiv!
#
#     @ /opt/homebrew/Cellar/julia/1.11.7_1/share/julia/stdlib/v1.11/LinearAlgebra/src/triangular.jl:966 [inlined]
#
#   [5] ldiv!
#
#     @ /opt/homebrew/Cellar/julia/1.11.7_1/share/julia/stdlib/v1.11/LinearAlgebra/src/triangular.jl:959 [inlined]
#
#   [6] \
#
#     @ /opt/homebrew/Cellar/julia/1.11.7_1/share/julia/stdlib/v1.11/LinearAlgebra/src/triangular.jl:1721 [inlined]
#
#   [7] invquad(a::PDMats.PDMat{Float64, BlockDiagonal{Float64, Matrix{Float64}}}, x::Vector{Float64})
#
#     @ PDMats ~/.julia/packages/PDMats/cb4LS/src/pdmat.jl:205
#
#   [8] sqmahal(d::MvNormal{Float64, PDMats.PDMat{Float64, BlockDiagonal{Float64, Matrix{Float64}}}, Vector{Float64}}, x::Vector{Float64})
#
#     @ Distributions ~/.julia/packages/Distributions/psM3H/src/multivariate/mvnormal.jl:262
#
#   [9] _logpdf
#
#     @ ~/.julia/packages/Distributions/psM3H/src/multivariate/mvnormal.jl:139 [inlined]
#
#  [10] logpdf
#
#     @ ~/.julia/packages/Distributions/psM3H/src/common.jl:269 [inlined]
#
#  [11] loglikelihood
#
#     @ ~/.julia/packages/Distributions/psM3H/src/common.jl:465 [inlined]
#
#  [12] observe
#
#     @ ~/.julia/packages/DynamicPPL/MjWTB/src/context_implementations.jl:272 [inlined]
#
#  [13] observe
#
#     @ ~/.julia/packages/DynamicPPL/MjWTB/src/context_implementations.jl:269 [inlined]
#
#  [14] tilde_observe
#
#     @ ~/.julia/packages/DynamicPPL/MjWTB/src/context_implementations.jl:164 [inlined]
#
#  [15] tilde_observe
#
#     @ ~/.julia/packages/DynamicPPL/MjWTB/src/context_implementations.jl:162 [inlined]
#
#  [16] tilde_observe
#
#     @ ~/.julia/packages/DynamicPPL/MjWTB/src/context_implementations.jl:157 [inlined]
#
#  [17] tilde_observe!!
#
#     @ ~/.julia/packages/DynamicPPL/MjWTB/src/context_implementations.jl:213 [inlined]
#
#  [18] tilde_observe!!(context::DynamicPPL.SamplingContext{DynamicPPL.SampleFromUniform, DynamicPPL.DefaultContext, Random.TaskLocalRNG}, right::MvNormal{Float64, PDMats.PDMat{Float64, BlockDiagonal{Float64, Matrix{Float64}}}, Vector{Float64}}, left::Vector{Float64}, vname::AbstractPPL.VarName{:data, typeof(identity)}, vi::DynamicPPL.TypedVarInfo{@NamedTuple{omegam_pr::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_pr, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_pr, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h0_pr::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h0_pr, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h0_pr, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_pr::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_pr, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_pr, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, rd_pr::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:rd_pr, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:rd_pr, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, M_pr::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:M_pr, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:M_pr, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64})
#
#     @ DynamicPPL ~/.julia/packages/DynamicPPL/MjWTB/src/context_implementations.jl:200
#
#  [19] macro expansion
#
#     @ ~/.julia/packages/DynamicPPL/MjWTB/src/compiler.jl:579 [inlined]
#
#  [20] LCDM_model(__model__::DynamicPPL.Model{typeof(LCDM_model), (:data, :data_cov), (), (), Tuple{Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, Tuple{}, DynamicPPL.DefaultContext}, __varinfo__::DynamicPPL.TypedVarInfo{@NamedTuple{omegam_pr::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_pr, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_pr, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h0_pr::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h0_pr, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h0_pr, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_pr::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_pr, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_pr, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, rd_pr::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:rd_pr, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:rd_pr, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, M_pr::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:M_pr, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:M_pr, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, __context__::DynamicPPL.SamplingContext{DynamicPPL.SampleFromUniform, DynamicPPL.DefaultContext, Random.TaskLocalRNG}, data::Vector{Float64}, data_cov::BlockDiagonal{Float64, Matrix{Float64}})
#
#     @ Main ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X20sZmlsZQ==.jl:36
#
#  [21] _evaluate!!
#
#     @ ~/.julia/packages/DynamicPPL/MjWTB/src/model.jl:973 [inlined]
#
#  [22] evaluate_threadunsafe!!
#
#     @ ~/.julia/packages/DynamicPPL/MjWTB/src/model.jl:946 [inlined]
#
#  [23] evaluate!!
#
#     @ ~/.julia/packages/DynamicPPL/MjWTB/src/model.jl:894 [inlined]
#
#  [24] evaluate!! (repeats 2 times)
#
#     @ ~/.julia/packages/DynamicPPL/MjWTB/src/model.jl:905 [inlined]
#
#  [25] initialstep(rng::Random.TaskLocalRNG, model::DynamicPPL.Model{typeof(LCDM_model), (:data, :data_cov), (), (), Tuple{Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, Tuple{}, DynamicPPL.DefaultContext}, spl::DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, vi_original::DynamicPPL.TypedVarInfo{@NamedTuple{omegam_pr::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_pr, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_pr, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h0_pr::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h0_pr, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h0_pr, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_pr::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_pr, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_pr, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, rd_pr::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:rd_pr, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:rd_pr, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, M_pr::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:M_pr, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:M_pr, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}; initial_params::Nothing, nadapts::Int64, kwargs::@Kwargs{})
#
#     @ Turing.Inference ~/.julia/packages/Turing/QN7BL/src/mcmc/hmc.jl:196
#
#  [26] step(rng::Random.TaskLocalRNG, model::DynamicPPL.Model{typeof(LCDM_model), (:data, :data_cov), (), (), Tuple{Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, Tuple{}, DynamicPPL.DefaultContext}, spl::DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}; initial_params::Nothing, kwargs::@Kwargs{nadapts::Int64})
#
#     @ DynamicPPL ~/.julia/packages/DynamicPPL/MjWTB/src/sampler.jl:116
#
#  [27] macro expansion
#
#     @ ~/.julia/packages/AbstractMCMC/1gucv/src/sample.jl:0 [inlined]
#
#  [28] (::AbstractMCMC.var"#29#30"{Nothing, Int64, Int64, Int64, UnionAll, Nothing, @Kwargs{nadapts::Int64}, Random.TaskLocalRNG, DynamicPPL.Model{typeof(LCDM_model), (:data, :data_cov), (), (), Tuple{Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, Tuple{}, DynamicPPL.DefaultContext}, DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, Int64, Float64, Int64, Int64})()
#
#     @ AbstractMCMC ~/.julia/packages/AbstractMCMC/1gucv/src/logging.jl:134
#
#  [29] with_logstate(f::AbstractMCMC.var"#29#30"{Nothing, Int64, Int64, Int64, UnionAll, Nothing, @Kwargs{nadapts::Int64}, Random.TaskLocalRNG, DynamicPPL.Model{typeof(LCDM_model), (:data, :data_cov), (), (), Tuple{Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, Tuple{}, DynamicPPL.DefaultContext}, DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, Int64, Float64, Int64, Int64}, logstate::Base.CoreLogging.LogState)
#
#     @ Base.CoreLogging ./logging/logging.jl:524
#
#  [30] with_logger(f::Function, logger::LoggingExtras.TeeLogger{Tuple{LoggingExtras.EarlyFilteredLogger{TerminalLoggers.TerminalLogger, AbstractMCMC.var"#1#3"{Module}}, LoggingExtras.EarlyFilteredLogger{Base.CoreLogging.SimpleLogger, AbstractMCMC.var"#2#4"{Module}}}})
#
#     @ Base.CoreLogging ./logging/logging.jl:635
#
#  [31] with_progresslogger(f::Function, _module::Module, logger::Base.CoreLogging.SimpleLogger)
#
#     @ AbstractMCMC ~/.julia/packages/AbstractMCMC/1gucv/src/logging.jl:157
#
#  [32] macro expansion
#
#     @ ~/.julia/packages/AbstractMCMC/1gucv/src/logging.jl:133 [inlined]
#
#  [33] mcmcsample(rng::Random.TaskLocalRNG, model::DynamicPPL.Model{typeof(LCDM_model), (:data, :data_cov), (), (), Tuple{Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, Tuple{}, DynamicPPL.DefaultContext}, sampler::DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, N::Int64; progress::Bool, progressname::String, callback::Nothing, num_warmup::Int64, discard_initial::Int64, thinning::Int64, chain_type::Type, initial_state::Nothing, kwargs::@Kwargs{nadapts::Int64})
#
#     @ AbstractMCMC ~/.julia/packages/AbstractMCMC/1gucv/src/sample.jl:168
#
#  [34] sample(rng::Random.TaskLocalRNG, model::DynamicPPL.Model{typeof(LCDM_model), (:data, :data_cov), (), (), Tuple{Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, Tuple{}, DynamicPPL.DefaultContext}, sampler::DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, N::Int64; chain_type::Type, resume_from::Nothing, initial_state::Nothing, progress::Bool, nadapts::Int64, discard_adapt::Bool, discard_initial::Int64, kwargs::@Kwargs{})
#
#     @ Turing.Inference ~/.julia/packages/Turing/QN7BL/src/mcmc/hmc.jl:123
#
#  [35] sample
#
#     @ ~/.julia/packages/Turing/QN7BL/src/mcmc/hmc.jl:92 [inlined]
#
#  [36] #sample#4
#
#     @ ~/.julia/packages/Turing/QN7BL/src/mcmc/Inference.jl:276 [inlined]
#
#  [37] sample
#
#     @ ~/.julia/packages/Turing/QN7BL/src/mcmc/Inference.jl:267 [inlined]
#
#  [38] #sample#3
#
#     @ ~/.julia/packages/Turing/QN7BL/src/mcmc/Inference.jl:264 [inlined]
#
#  [39] sample(model::DynamicPPL.Model{typeof(LCDM_model), (:data, :data_cov), (), (), Tuple{Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, Tuple{}, DynamicPPL.DefaultContext}, alg::NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}, N::Int64)
#
#     @ Turing.Inference ~/.julia/packages/Turing/QN7BL/src/mcmc/Inference.jl:258
#
#  [40] eval
#
#     @ ./boot.jl:430 [inlined]
#
#  [41] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#
#     @ Base ./loading.jl:2734
#
#  [42] #invokelatest#2
#
#     @ ./essentials.jl:1055 [inlined]
#
#  [43] invokelatest
#
#     @ ./essentials.jl:1052 [inlined]
#
#  [44] (::VSCodeServer.var"#217#218"{VSCodeServer.NotebookRunCellArguments, String})()
#
#     @ VSCodeServer ~/.vscode/extensions/julialang.language-julia-1.158.2/scripts/packages/VSCodeServer/src/serve_notebook.jl:24
#
#  [45] withpath(f::VSCodeServer.var"#217#218"{VSCodeServer.NotebookRunCellArguments, String}, path::String)
#
#     @ VSCodeServer ~/.vscode/extensions/julialang.language-julia-1.158.2/scripts/packages/VSCodeServer/src/repl.jl:278
#
#  [46] notebook_runcell_request(conn::VSCodeServer.JSONRPC.JSONRPCEndpoint{Base.PipeEndpoint, Base.PipeEndpoint, VSCodeServer.JSON.Serializations.StandardSerialization}, params::VSCodeServer.NotebookRunCellArguments, token::VSCodeServer.CancellationTokens.CancellationToken)
#
#     @ VSCodeServer ~/.vscode/extensions/julialang.language-julia-1.158.2/scripts/packages/VSCodeServer/src/serve_notebook.jl:13
#
#  [47] dispatch_msg(x::VSCodeServer.JSONRPC.JSONRPCEndpoint{Base.PipeEndpoint, Base.PipeEndpoint, VSCodeServer.JSON.Serializations.StandardSerialization}, dispatcher::VSCodeServer.JSONRPC.MsgDispatcher, msg::VSCodeServer.JSONRPC.Request)
#
#     @ VSCodeServer.JSONRPC ~/.vscode/extensions/julialang.language-julia-1.158.2/scripts/packages/JSONRPC/src/typed.jl:68
#
#  [48] serve_notebook(pipename::String, debugger_pipename::String, outputchannel_logger::Base.CoreLogging.SimpleLogger; error_handler::var"#9#14"{String})
#
#     @ VSCodeServer ~/.vscode/extensions/julialang.language-julia-1.158.2/scripts/packages/VSCodeServer/src/serve_notebook.jl:147
#
#  [49] top-level scope
#
#     @ ~/.vscode/extensions/julialang.language-julia-1.158.2/scripts/notebook/notebook.jl:28

# %%
# lcdm chains
hzdata_lcdm = group(chain_LCDM, :hz_theory).value.data[:,:,1];
aisodata_lcdm = group(chain_LCDM, :dvrd_theory).value.data[:,:,1];
aapdata_lcdm = group(chain_LCDM, :dhdm_theory).value.data[:,:,1];
fs8data_lcdm = group(chain_LCDM, :fs8_theory).value.data[:,:,1];
mudata_lcdm = group(chain_LCDM, :mu_theory).value.data[:,:,1];

# mean and standard deviation - lcdm
hz_lcdm_m, hz_lcdm_s = mean(hzdata_lcdm, dims=1), std(hzdata_lcdm, dims=1); 
aiso_lcdm_m, aiso_lcdm_s = mean(aisodata_lcdm, dims=1), std(aisodata_lcdm, dims=1);
aap_lcdm_m, aap_lcdm_s = mean(aapdata_lcdm, dims=1), std(aapdata_lcdm, dims=1); 
fs8_lcdm_m, fs8_lcdm_s = mean(fs8data_lcdm, dims=1), std(fs8data_lcdm, dims=1); 
mu_lcdm_m, mu_lcdm_s = mean(mudata_lcdm, dims=1), std(mudata_lcdm, dims=1);
# Out:
# UndefVarError: `chain_LCDM` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X22sZmlsZQ==.jl:1

# %%
plot(fakedatahz.z, fakedatahz.data, yerr=hz_err, label="Data H(z)", ms=2, seriestype=:scatter)
plot!(fakedatahz.z, vec(hz_lcdm_m), label=" H(z) LCDM mean")
plot!(fakedatahz.z, vec(hz_lcdm_m .- hz_lcdm_s),  fillrange = vec(hz_lcdm_m .+ hz_lcdm_s), fillalpha=0.2, c=1, label="H(z) LCDM standard deviation")
# Out:
# UndefVarError: `hz_lcdm_m` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X23sZmlsZQ==.jl:2

# %%
plot(fakedataaiso.z, fakedataaiso.data, yerr=aiso_err, label="Data a_iso", ms=2, seriestype=:scatter)
plot!(fakedataaiso.z, vec(aiso_lcdm_m), label=" a_iso LCDM mean")
plot!(fakedataaiso.z, vec(aiso_lcdm_m .- aiso_lcdm_s),  fillrange = vec(aiso_lcdm_m .+ aiso_lcdm_s), fillalpha=0.2, c=1, label="a_iso LCDM standard deviation")
# Out:
# UndefVarError: `aiso_lcdm_m` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X24sZmlsZQ==.jl:2

# %%
plot(fakedataaap.z, fakedataaap.data, yerr=aap_err, label="Data a_ap", ms=2, seriestype=:scatter)
plot!(fakedataaap.z, vec(aap_lcdm_m), label="a_ap LCDM mean")
plot!(fakedataaap.z, vec(aap_lcdm_m .- aap_lcdm_s),  fillrange = vec(aap_lcdm_m .+ aap_lcdm_s), fillalpha=0.2, c=1, label="a_ap LCDM standard deviation")
# Out:
# UndefVarError: `aap_lcdm_m` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X25sZmlsZQ==.jl:2

# %%
plot(fakedatafs8.z, fakedatafs8.data, yerr=fs8_err, label="Data fs8", ms=2, seriestype=:scatter)
plot!(fakedatafs8.z, vec(fs8_lcdm_m), label="fs8 lcdm")
plot!(fakedatafs8.z, vec(fs8_lcdm_m .- fs8_lcdm_s),  fillrange = vec(fs8_lcdm_m .+ fs8_lcdm_s), fillalpha=0.2, c=1, label="fs8 lcdm standard deviation")
# Out:
# UndefVarError: `fs8_lcdm_m` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X26sZmlsZQ==.jl:2

# %%
plot(fakedatamu.z, fakedatamu.data, yerr=mu_err, label="Data mu", ms=2, seriestype=:scatter)
plot!(fakedatamu.z, vec(mu_lcdm_m), label="mu lcdm")
plot!(fakedatamu.z, vec(mu_lcdm_m .- mu_lcdm_s),  fillrange = vec(mu_lcdm_m .+ mu_lcdm_s), fillalpha=0.2, c=1, label="mu lcdm standard deviation")
# Out:
# UndefVarError: `mu_lcdm_m` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X30sZmlsZQ==.jl:2

# %% [markdown]
# ## GP modelling - priors

# %%
zlat = range(0, 3.0, length=30); # latent variable space
z_integ = cosmo1.settings.zs; # integral variable space

# %%
function model_latent_GP(eta, l, v; omega_m=cosmo1.cpar.Ωm, sigma_8=cosmo1.cpar.σ8, h_0 = cosmo1.cpar.h,
                         x=zlat, z=z_obs, data_cov=covariance_obs)
    # Dimensions of predictors .
    kernel = sqexp_cov_fn(x; eta=eta, l=l)
    cpar = CosmoPar(Ωm=omega_m,  Ωb=cosmo1.cpar.Ωb, h=h_0, σ8=sigma_8)
    mean_ex = Ez(cpar, x)
    # a latent GP is carried out using a Wiener filter
    ex = latent_GP(mean_ex, v, kernel)
    # transforms hx from x space to z space
    ez =  conditional(x, z, ex, sqexp_cov_fn;
                     eta=eta, l=l)
    return ex, ez
end
# Out:
# model_latent_GP (generic function with 1 method)

# %% [markdown]
# hx is the GP realisation of the hubble parameter. hz transforms hx from the latent space to another parameter space (integral or observation).

# %%
N_samples = 100
# data parameter space conditional
exs1=zeros(N_samples, 30) #latent variable chain
ezs1=zeros(N_samples, length(z_obs)) #observed variable chain
# pick 100 random hyperparameter combinations, and compute the GP realisation of them in both latent and conditional space.
for i in 1:N_samples
    v = rand(MvNormal(zeros(length(zlat)), ones(length(zlat))))
    exs1[i, :], ezs1[i, :] = model_latent_GP(0.1, 0.3, v)
end
y_m1, y_s1 = mean(ezs1, dims=1), std(ezs1, dims=1); #observed space
gp_m1, gp_s1 = mean(exs1, dims=1), std(exs1, dims=1); #latent space

# %%
# integral parameter space conditional
exs2=zeros(N_samples, length(zlat))
ezs2=zeros(N_samples, length(z_integ))
hz_pr=zeros(N_samples, length(z_integ))
aiso_pr=zeros(N_samples, length(z_integ))
aap_pr=zeros(N_samples, length(z_integ))
fs8_pr=zeros(N_samples, length(z_integ))
mu_pr=zeros(N_samples, length(z_integ))

for i in 1:N_samples
    v = rand(MvNormal(zeros(length(zlat)), ones(length(zlat))))
    h_pr = rand(h_dist)
    s8_pr = rand(s8_dist)
    omegam_pr = rand(omegam_dist)
    rd_pr = rand(rd_dist)
    M_pr = rand(M_dist)

    exs2[i, :], ezs2[i, :] = model_latent_GP(0.1, 0.3, v; z=z_integ, sigma_8=s8_pr)
    hz_pr[i, :] = hz_from_ez(z_integ, h_pr, ezs2[i, :])
    aiso_pr[i, :] = a_iso(z_integ, h_pr, rd_pr, ezs2[i, :])
    aap_pr[i, :] = a_ap(z_integ, h_pr, ezs2[i, :])
    fs8_pr[i, :] = fs8_from_ez(z_integ, omegam_pr, s8_pr, h_pr, ezs2[i, :], eltype(ezs2[i, :]))
    mu_pr[i, :] = super(z_integ, h_pr, M_pr, ezs2[i, :])
end

y_m2, y_s2 = mean(ezs2, dims=1), std(ezs2, dims=1); #integral space
gp_m2, gp_s2 = mean(exs2, dims=1), std(exs2, dims=1); #latent space

hz_m2, hz_s2 = mean(hz_pr, dims=1), std(hz_pr, dims=1); 
aiso_m2, aiso_s2 = mean(aiso_pr, dims=1), std(aiso_pr, dims=1); 
aap_m2, aap_s2 = mean(aap_pr, dims=1), std(aap_pr, dims=1);
fs8_m2, fs8_s2 = mean(fs8_pr, dims=1), std(fs8_pr, dims=1);
mu_m2, mu_s2 = mean(mu_pr, dims=1), std(mu_pr, dims=1);
# Out:
# UndefVarError: `h_dist` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X36sZmlsZQ==.jl:12

# %%
# prior model predictions
hz_itp2 = LinearInterpolation(z_integ, vec(hz_m2), extrapolation_bc=Line());
aiso_itp2 = LinearInterpolation(z_integ, vec(aiso_m2), extrapolation_bc=Line());
aap_itp2 = LinearInterpolation(z_integ, vec(aap_m2), extrapolation_bc=Line());
fs8_itp2 = LinearInterpolation(z_integ, vec(fs8_m2), extrapolation_bc=Line());
mu_itp2 = LinearInterpolation(z_integ, vec(mu_m2), extrapolation_bc=Line());
# Out:
# UndefVarError: `hz_m2` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X40sZmlsZQ==.jl:1

# %%
# integral space hz plot
plot(fakedatahz.z, fakedatahz.data, yerr=hz_err, label="Data hz", ms=2, seriestype=:scatter)
plot!(z_integ, vec(hz_m2), label="hz mean")
plot!(z_integ, vec(hz_m2 .- hz_s2),  fillrange = vec(hz_m2 .+ hz_s2), fillalpha=0.2, c=1, label="hz standard deviation")
# Out:
# UndefVarError: `hz_m2` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X41sZmlsZQ==.jl:3

# %%
# integral space aiso plot
plot(fakedataaiso.z, fakedataaiso.data, yerr=aiso_err, label="Data a_iso", ms=2, seriestype=:scatter)
plot!(z_integ, vec(aiso_m2), label="a_iso mean")
plot!(z_integ, vec(aiso_m2 .- aiso_s2),  fillrange = vec(aiso_m2 .+ aiso_s2), fillalpha=0.2, c=1, label="a_iso standard deviation")
# Out:
# UndefVarError: `aiso_m2` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X42sZmlsZQ==.jl:3

# %%
# plotting chi data 
plot(fakedataaap.z, fakedataaap.data, yerr=aap_err, label="Data a_ap", ms=2, seriestype=:scatter)
plot!(z_integ, vec(aap_m2), label="a_ap mean")
plot!(z_integ, vec(aap_m2 .- aap_s2),  fillrange = vec(aap_m2 .+ aap_s2), fillalpha=0.2, c=1, label="a_ap standard deviation")
# Out:
# UndefVarError: `aap_m2` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X43sZmlsZQ==.jl:3

# %%
# plotting fs8 data 
plot(fakedatafs8.z, fakedatafs8.data, yerr=fs8_err, label="Data fs8", ms=2, seriestype=:scatter)
plot!(z_integ, vec(fs8_m2), label="fs8 mean")
plot!(z_integ, vec(fs8_m2 .- fs8_s2),  fillrange = vec(fs8_m2 .+ fs8_s2), fillalpha=0.2, c=1, label="fs8 standard deviation")
# Out:
# UndefVarError: `fs8_m2` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X44sZmlsZQ==.jl:3

# %%
# plotting supernovae data 
plot(fakedatasup.z, fakedatasup.data, yerr=sup_err, label="Data mu", ms=2, seriestype=:scatter)
plot!(z_integ, vec(mu_m2), label="mu mean")
plot!(z_integ, vec(mu_m2 .- mu_s2),  fillrange = vec(mu_m2 .+ mu_s2), fillalpha=0.2, c=1, label="mu standard deviation")
# Out:
# UndefVarError: `sup_err` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X45sZmlsZQ==.jl:2

# %% [markdown]
# ## GP modelling - posteriors

# %%
@model function stats_model(y; int_grid=z_integ, X=zlat, data_x=z_obs, data_cov=covariance_obs)
    # Priors, parameters
    eta2 = 2
    l2 = 0.3
    v_po ~ MvNormal(zeros(length(X)), ones(length(X)))
    omegam_po ~ omegam_dist
    s8_po ~ s8_dist
    h_po ~ h_dist
    r_po ~ rd_dist
    M_po ~ M_dist
    
    kernel = sqexp_cov_fn(X, eta=eta2, l=l2)
    cpar = CosmoPar(Ωm=cosmo1.cpar.Ωm, Ωb=cosmo1.cpar.Ωb, h=cosmo1.cpar.h, σ8=s8_po)
    mean_ez = Ez(cpar, X)
    ez_latent = latent_GP(mean_ez, v_po, kernel)
    ez_gp = conditional(X, int_grid, ez_latent, sqexp_cov_fn; eta=eta2, l=l2) # converting from latent space to integral space
    
    # sampling over parameters
    hz = hz_from_ez(int_grid, h_po, ez_gp);
    #aiso = a_iso(int_grid, h_po, r_po, ez_gp);
    aap = a_ap(int_grid, h_po, ez_gp);
    fs8 = fs8_from_ez(int_grid, omegam_po, s8_po, h_po, ez_gp, eltype(ez_gp));
    #mu = super(int_grid, h_po, M_po, ez_gp)

    hz_interp = LinearInterpolation(int_grid, hz, extrapolation_bc=Line())
    #aiso_interp = LinearInterpolation(int_grid, aiso, extrapolation_bc=Line())
    aap_interp = LinearInterpolation(int_grid, aap, extrapolation_bc=Line())
    fs8_interp = LinearInterpolation(int_grid, fs8, extrapolation_bc=Line())
    #mu_interp = LinearInterpolation(int_grid, mu, extrapolation_bc=Line())

    hdata := hz_interp(fakedatahz.z)
    aisodata := fakedataaiso.data
    aapdata := aap_interp(fakedataaap.z)
    fs8data := fs8_interp(fakedatafs8.z)
    #mudata := mu_interp(fakedatamu.z)
    mudata := fakedatamu.data

    datay = [hdata;aisodata;aapdata;fs8data;mudata]

    y ~ MvNormal(datay, data_cov) 

end
# Out:
# stats_model (generic function with 2 methods)

# %%
chain_gp = sample(stats_model(data_obs), NUTS(5, 0.65), 25)
# Out:
# UndefVarError: `h_dist` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#   [1] stats_model(__model__::DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, __varinfo__::DynamicPPL.UntypedVarInfo{DynamicPPL.Metadata{Dict{AbstractPPL.VarName, Int64}, Vector{Distribution}, Vector{AbstractPPL.VarName}, Vector{Real}, Vector{Set{DynamicPPL.Selector}}}, Float64}, __context__::DynamicPPL.DebugUtils.DebugContext{DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, DynamicPPL.SamplingContext{DynamicPPL.SampleFromPrior, DynamicPPL.DefaultContext, Random.TaskLocalRNG}}, y::Vector{Float64}; int_grid::Vector{Float64}, X::StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, data_x::Vector{Float64}, data_cov::BlockDiagonal{Float64, Matrix{Float64}})
#
#     @ Main ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X50sZmlsZQ==.jl:8
#
#   [2] stats_model
#
#     @ ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X50sZmlsZQ==.jl:1 [inlined]
#
#   [3] _evaluate!!
#
#     @ ~/.julia/packages/DynamicPPL/MjWTB/src/model.jl:973 [inlined]
#
#   [4] evaluate_threadunsafe!!
#
#     @ ~/.julia/packages/DynamicPPL/MjWTB/src/model.jl:946 [inlined]
#
#   [5] check_model_and_trace(rng::Random.TaskLocalRNG, model::DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}; varinfo::DynamicPPL.UntypedVarInfo{DynamicPPL.Metadata{Dict{AbstractPPL.VarName, Int64}, Vector{Distribution}, Vector{AbstractPPL.VarName}, Vector{Real}, Vector{Set{DynamicPPL.Selector}}}, Float64}, context::DynamicPPL.SamplingContext{DynamicPPL.SampleFromPrior, DynamicPPL.DefaultContext, Random.TaskLocalRNG}, error_on_failure::Bool, kwargs::@Kwargs{})
#
#     @ DynamicPPL.DebugUtils ~/.julia/packages/DynamicPPL/MjWTB/src/debug_utils.jl:598
#
#   [6] check_model_and_trace
#
#     @ ~/.julia/packages/DynamicPPL/MjWTB/src/debug_utils.jl:581 [inlined]
#
#   [7] #check_model_and_trace#8
#
#     @ ~/.julia/packages/DynamicPPL/MjWTB/src/debug_utils.jl:579 [inlined]
#
#   [8] check_model_and_trace
#
#     @ ~/.julia/packages/DynamicPPL/MjWTB/src/debug_utils.jl:578 [inlined]
#
#   [9] check_model
#
#     @ ~/.julia/packages/DynamicPPL/MjWTB/src/debug_utils.jl:624 [inlined]
#
#  [10] _check_model
#
#     @ ~/.julia/packages/Turing/QN7BL/src/mcmc/Inference.jl:248 [inlined]
#
#  [11] _check_model
#
#     @ ~/.julia/packages/Turing/QN7BL/src/mcmc/Inference.jl:251 [inlined]
#
#  [12] #sample#4
#
#     @ ~/.julia/packages/Turing/QN7BL/src/mcmc/Inference.jl:275 [inlined]
#
#  [13] sample
#
#     @ ~/.julia/packages/Turing/QN7BL/src/mcmc/Inference.jl:267 [inlined]
#
#  [14] #sample#3
#
#     @ ~/.julia/packages/Turing/QN7BL/src/mcmc/Inference.jl:264 [inlined]
#
#  [15] sample(model::DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, alg::NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}, N::Int64)
#
#     @ Turing.Inference ~/.julia/packages/Turing/QN7BL/src/mcmc/Inference.jl:258
#
#  [16] top-level scope
#
#     @ ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X51sZmlsZQ==.jl:1

# %%
# data posterior gp chains
hdata_p = group(chain_gp, :hdata).value.data[:,:,1];
aisodata_p = group(chain_gp, :aisodata).value.data[:,:,1];
aapdata_p =  group(chain_gp, :aapdata).value.data[:,:,1];
fs8data_p =  group(chain_gp, :fs8data).value.data[:,:,1];
mudata_p =  group(chain_gp, :mudata).value.data[:,:,1];

# parameter chains
v_p = group(chain_gp, :v_po).value.data[:, :, 1];
omegam_p = group(chain_gp, :omegam_po).value.data[:, :, 1];
s8_p = group(chain_gp, :s8_po).value.data[:, :, 1];
# Out:
# UndefVarError: `chain_gp` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X52sZmlsZQ==.jl:1

# %%
# data mean / standard dev.
hpmean, hps = mean(hdata_p, dims=1), std(hdata_p, dims=1);
aisopmean, aisops = mean(aisodata_p, dims=1), std(aisodata_p, dims=1);
aappmean, aapps = mean(aapdata_p, dims=1), std(aapdata_p, dims=1);
fs8pmean, fs8ps = mean(fs8data_p, dims=1), std(fs8data_p, dims=1);
mupmean, mups = mean(mudata_p, dims=1), std(mudata_p, dims=1);
# Out:
# UndefVarError: `hdata_p` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X53sZmlsZQ==.jl:1

# %%
plot(fakedatahz.z, fakedatahz.data, yerr=hz_err, label="Data hz", ms=2, seriestype=:scatter)
plot!(fakedatahz.z, vec(hpmean), label="hz GP mean")
plot!(fakedatahz.z, vec(hpmean .- hps),  fillrange = vec(hpmean .+ hps), fillalpha=0.2, c=4, label="hz standard deviation")
plot!(fakedatahz.z, vec(hz_lcdm_m), label=" H(z) LCDM mean")
plot!(fakedatahz.z, vec(hz_lcdm_m .- hz_lcdm_s),  fillrange = vec(hz_lcdm_m .+ hz_lcdm_s), fillalpha=0.2, c=1, label="H(z) LCDM standard deviation")
# Out:
# UndefVarError: `hpmean` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X54sZmlsZQ==.jl:2

# %%
plot(fakedataaiso.z, fakedataaiso.data, yerr=aiso_err, label="Data a_iso", ms=2, seriestype=:scatter)
plot!(fakedataaiso.z, vec(aisopmean), label="a_iso GP mean")
plot!(fakedataaiso.z, vec(aisopmean .- aisops),  fillrange = vec(aisopmean .+ aisops), fillalpha=0.2, c=1, label="a_iso standard deviation")
# Out:
# UndefVarError: `aisopmean` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X55sZmlsZQ==.jl:2

# %%
plot(fakedataaap.z, fakedataaap.data, yerr=aap_err, label="Data a_ap", ms=2, seriestype=:scatter)
plot!(fakedataaap.z, vec(aappmean), label="a_ap mean")
plot!(fakedataaap.z, vec(aappmean .- aapps),  fillrange = vec(aappmean .+ aapps), fillalpha=0.2, c=1, label="a_ap standard deviation")
# Out:
# UndefVarError: `aappmean` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X56sZmlsZQ==.jl:2

# %%
plot(fakedatafs8.z, fakedatafs8.data, yerr=fs8_err, label="Data fs8", ms=2, seriestype=:scatter)
plot!(fakedatafs8.z, vec(fs8pmean), label="fs8 mean")
plot!(fakedatafs8.z, vec(fs8pmean .- fs8ps),  fillrange = vec(fs8pmean .+ fs8ps), fillalpha=0.2, c=1, label="fs8 standard deviation")
# Out:
# UndefVarError: `fs8pmean` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X60sZmlsZQ==.jl:2

# %%
plot(fakedatafs8.z, fakedatafs8.data, yerr=fs8_err, label="Data fs8", ms=2, seriestype=:scatter)
plot!(fakedatafs8.z, vec(fs8pmean), label="fs8 mean")
plot!(fakedatafs8.z, vec(fs8pmean .- fs8ps),  fillrange = vec(fs8pmean .+ fs8ps), fillalpha=0.2, c=1, label="fs8 gp standard deviation")
plot!(fakedatafs8.z, vec(fs8_lcdm_m), label="fs8 lcdm")
plot!(fakedatafs8.z, vec(fs8_lcdm_m .- fs8_lcdm_s),  fillrange = vec(fs8_lcdm_m .+ fs8_lcdm_s), fillalpha=0.2, c=4, label="fs8 lcdm standard deviation")
# Out:
# UndefVarError: `fs8pmean` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X61sZmlsZQ==.jl:2

# %%
plot(fakedatasup.z, fakedatasup.data, yerr=sup_err, label="Data mu", ms=2, seriestype=:scatter)
plot!(fakedatasup.z, vec(mupmean), label="mu mean")
plot!(fakedatasup.z, vec(mupmean .- mups),  fillrange = vec(mupmean .+ mups), fillalpha=0.2, c=1, label="mu standard deviation")
# Out:
# UndefVarError: `sup_err` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X62sZmlsZQ==.jl:1
