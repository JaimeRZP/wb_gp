# %% [markdown]
# # Setting up a latent function Gaussian Process for H(z)

# %%
# import set 
using Turing
using Distances
using LinearAlgebra
using LimberJack
using Interpolations
using GaussianProcess
using Plots
using QuadGK
using BlockDiagonals

# %% [markdown]
# ### Collate data

# %%
# setting a cosmology for the fake data 
cosmo1 = Cosmology();

# %% [markdown]
# #### Generate fake data

# %%
# hz data
function fakedata_hz()
z  = sort(2.5 .* rand(20)) # random array of 30 z values sorted ascending (0 - 2.5)
data  = cosmo1.cpar.h*100*Ez(cosmo1, z)
err = 0.1 .* data
cov = zeros(length(z), length(z))
    for i in 1:length(z)
        cov[i, i] = err[i]^2
    end
    return (data_name = "fakedata_hz", z = z, data = data, cov = cov)
end

# chi data
function fakedata_dm()
    z = [0.1, 0.23, 0.42, 0.78, 1.5, 2.3]
    data = cosmo1.chi(z)
    err = 0.1 .* data
    cov = zeros(length(z), length(z))
    for i in 1:length(z)
        cov[i, i] = err[i]^2
    end
    return (data_name = "fakedata_dm", z = z, data = data, cov = cov)
end

# fs8 data
function fakedata_fs8()
    z = [0.01, 0.02, 0.07, 0.54, 1.5, 2.4]
    data = fs8(cosmo1, z)
    err = 0.1 .* data
    cov = zeros(length(z), length(z))
    for i in 1:length(z)
        cov[i, i] = err[i]^2
    end
    return(data_name = "fakedata_fs8", z = z, data = data, cov = cov)
end

fakedatahz = fakedata_hz();
fakedatadm = fakedata_dm();
fakedatafs8 = fakedata_fs8();

# %% [markdown]
# #### Putting Hz, Dm and fs8 data together

# %%
# fake data
data_obs  = [fakedatahz.data; fakedatadm.data; fakedatafs8.data];
z_obs = [fakedatahz.z; fakedatadm.z; fakedatafs8.z];
covariance_obs = BlockDiagonal([fakedatahz.cov, fakedatadm.cov, fakedatafs8.cov]);

# errors
hz_err = 0.1 .* fakedatahz.data;
dm_err = 0.1 .* fakedatadm.data;
fs8_err = 0.1 .* fakedatafs8.data;

# %% [markdown]
# ### Functions for hz, chi and fs8

# %%
function hz_from_ez(zarr, h0, ez)
    ez_itp = LinearInterpolation(zarr, ez, extrapolation_bc=Line())
    hz = ez_itp(zarr) .* (h0*100)
    #hzi = linear_interpolation(zarr, hz, extrapolation_bc=Line())
    return hz
end

function dm_from_ez(zarr, h0, ez)
    chis = similar(ez)
    ez_itp = LinearInterpolation(zarr, ez, extrapolation_bc=Line())

    for i in 1:length(zarr)
        zz = zarr[i]
        chis[i] = quadgk(z -> 1.0/ez_itp(z), 0.0, zz, rtol=1E-5)[1]
        chis[i] *= LimberJack.CLIGHT_HMPC / h0
    end
    return chis
end


function fs8_from_ez(zarr, Ωm, σ8, h0, ez, cosmo_type)
    # initialising
    nz = length(zarr)
    z_max = maximum(zarr)
    x = log.(1 .+ zarr)
    a = @.(1/(1+zarr))
    dx = x[2]-x[1]
    
    aa = reverse(a)
    ee = reverse(ez)
    dd = zeros(cosmo_type, nz)
    yy = zeros(cosmo_type, nz)
    dd[1] = aa[1]
    yy[1] = aa[1]^3*ee[end]
    
    for i in 1:(nz-1)
        A0 = -1.5 * Ωm / (aa[i]*ee[i])
        B0 = -1. / (aa[i]^2*ee[i])
        A1 = -1.5 * Ωm / (aa[i+1]*ee[i+1])
        B1 = -1. / (aa[i+1]^2*ee[i+1])
        yy[i+1] = (1+0.5*dx^2*A0*B0)*yy[i] + 0.5*(A0+A1)*dx*dd[i]
        dd[i+1] = 0.5*(B0+B1)*dx*yy[i] + (1+0.5*dx^2*A0*B0)*dd[i]
    end
    
    y = reverse(yy)
    d = reverse(dd)

    fs8zi =  -σ8 .* y./ (a.^2 .*ez.*d[1])
                                
                        
    return fs8zi
end
# Out:
# fs8_from_ez (generic function with 1 method)

# %%
z_integ1 = cosmo1.settings.zs;
ez_test = Ez(cosmo1, z_integ1);

# %%
p1 = plot(fakedatahz.z, fakedatahz.data, yerr=hz_err, seriestype=:scatter,title="h(z)", legend=false)
p2 = plot(fakedatadm.z, fakedatadm.data, yerr=dm_err, seriestype=:scatter, title="Dm(z)", legend=false)
p3 = plot(fakedatafs8.z, fakedatafs8.data, yerr=fs8_err, seriestype=:scatter, title="fs8(z)", legend=false)

plot!(p1, z_integ1, hz_from_ez(z_integ1, cosmo1.cpar.h, ez_test), color=:black)
plot!(p2, z_integ1, dm_from_ez(z_integ1, cosmo1.cpar.h, ez_test), color=:black)
plot!(p3, z_integ1, fs8_from_ez(z_integ1, cosmo1.cpar.Ωm, cosmo1.cpar.σ8, cosmo1.cpar.h, ez_test, eltype(ez_test)), color=:black)

plot(p1, p2, p3, layout=(1,3), size=(900,300))

# %% [markdown]
# ## LCDM analysis

# %%
@model function LCDM_model(data, data_cov)
    # Priors
    omegam_pr ~ Uniform(0.1, 0.5)
    h0_pr ~ Uniform(0.6, 0.8)
    s8_pr ~ Uniform(0.6, 0.9)

    # Create cosmology
    cosmo_pr = LimberJack.Cosmology(Ωm=cosmo1.cpar.Ωm, Ωb=cosmo1.cpar.Ωb, h=cosmo1.cpar.h, σ8=s8_pr);
    
    # Model predictions
    ez_model = Ez(cosmo_pr, z_integ1)
    hz_model := hz_from_ez(z_integ1, h0_pr, ez_model)
    dm_model := dm_from_ez(z_integ1, h0_pr, ez_model)
    fs8_model := fs8_from_ez(z_integ1, omegam_pr, s8_pr, h0_pr, ez_model, eltype(ez_model))

    # Create interpolators
    hz_itp = LinearInterpolation(z_integ1, hz_model, extrapolation_bc=Line())
    dm_itp = LinearInterpolation(z_integ1, dm_model, extrapolation_bc=Line())
    fs8_itp = LinearInterpolation(z_integ1, fs8_model, extrapolation_bc=Line())

    hz_theory := hz_itp(fakedatahz.z)
    dm_theory := dm_itp(fakedatadm.z)
    fs8_theory := fs8_itp(fakedatafs8.z)

    theory = [hz_theory;dm_theory;fs8_theory]

    # Likelihood
    data ~ MvNormal(theory, data_cov)
end
# Out:
# LCDM_model (generic function with 2 methods)

# %%
cond_LCDM_model = LCDM_model(data_obs, covariance_obs)
chain_LCDM = sample(cond_LCDM_model, NUTS(20, 0.65), 100)
# Out:
# Sampling   0%|                                          |  ETA: N/A
# ┌ Info: Found initial step size
# │   ϵ = 0.025
# └ @ Turing.Inference /Users/vis/.julia/packages/Turing/QN7BL/src/mcmc/hmc.jl:212
# Sampling   1%|▍                                         |  ETA: 0:35:14
# Sampling   2%|▊                                         |  ETA: 0:17:32
# Sampling   2%|█                                         |  ETA: 0:11:36
# Sampling   3%|█▍                                        |  ETA: 0:08:39
# Sampling   4%|█▊                                        |  ETA: 0:06:52
# Sampling   5%|██▏                                       |  ETA: 0:05:41
# Sampling   6%|██▌                                       |  ETA: 0:04:50
# Sampling   7%|██▊                                       |  ETA: 0:04:14
# Sampling   8%|███▏                                      |  ETA: 0:03:47
# Sampling   8%|███▌                                      |  ETA: 0:03:25
# Sampling   9%|███▉                                      |  ETA: 0:03:05
# Sampling  10%|████▎                                     |  ETA: 0:02:48
# Sampling  11%|████▌                                     |  ETA: 0:02:34
# Sampling  12%|████▉                                     |  ETA: 0:02:22
# Sampling  12%|█████▎                                    |  ETA: 0:02:12
# Sampling  13%|█████▋                                    |  ETA: 0:02:03
# Sampling  14%|██████                                    |  ETA: 0:01:55
# Sampling  15%|██████▎                                   |  ETA: 0:01:51
# Sampling  16%|██████▋                                   |  ETA: 0:01:46
# Sampling  17%|███████                                   |  ETA: 0:01:39
# Sampling  18%|███████▍                                  |  ETA: 0:01:35
# Sampling  18%|███████▊                                  |  ETA: 0:01:31
# Sampling  19%|████████                                  |  ETA: 0:01:26
# Sampling  20%|████████▍                                 |  ETA: 0:01:22
# Sampling  21%|████████▊                                 |  ETA: 0:01:19
# Sampling  22%|█████████▏                                |  ETA: 0:01:16
# Sampling  22%|█████████▌                                |  ETA: 0:01:13
# Sampling  23%|█████████▊                                |  ETA: 0:01:10
# Sampling  24%|██████████▏                               |  ETA: 0:01:08
# Sampling  25%|██████████▌                               |  ETA: 0:01:05
# Sampling  26%|██████████▉                               |  ETA: 0:01:03
# Sampling  27%|███████████▎                              |  ETA: 0:01:01
# Sampling  28%|███████████▌                              |  ETA: 0:00:59
# Sampling  28%|███████████▉                              |  ETA: 0:00:57
# Sampling  29%|████████████▎                             |  ETA: 0:00:55
# Sampling  30%|████████████▋                             |  ETA: 0:00:54
# Sampling  31%|█████████████                             |  ETA: 0:00:52
# Sampling  32%|█████████████▎                            |  ETA: 0:00:50
# Sampling  32%|█████████████▋                            |  ETA: 0:00:49
# Sampling  33%|██████████████                            |  ETA: 0:00:47
# Sampling  34%|██████████████▍                           |  ETA: 0:00:46
# Sampling  35%|██████████████▊                           |  ETA: 0:00:45
# Sampling  36%|███████████████                           |  ETA: 0:00:44
# Sampling  37%|███████████████▍                          |  ETA: 0:00:42
# Sampling  38%|███████████████▊                          |  ETA: 0:00:41
# Sampling  38%|████████████████▏                         |  ETA: 0:00:40
# Sampling  39%|████████████████▌                         |  ETA: 0:00:39
# Sampling  40%|████████████████▊                         |  ETA: 0:00:38
# Sampling  41%|█████████████████▏                        |  ETA: 0:00:36
# Sampling  42%|█████████████████▌                        |  ETA: 0:00:35
# Sampling  42%|█████████████████▉                        |  ETA: 0:00:35
# Sampling  43%|██████████████████▎                       |  ETA: 0:00:34
# Sampling  44%|██████████████████▌                       |  ETA: 0:00:33
# Sampling  45%|██████████████████▉                       |  ETA: 0:00:32
# Sampling  46%|███████████████████▎                      |  ETA: 0:00:31
# Sampling  47%|███████████████████▋                      |  ETA: 0:00:30
# Sampling  48%|████████████████████                      |  ETA: 0:00:29
# Sampling  48%|████████████████████▎                     |  ETA: 0:00:28
# Sampling  49%|████████████████████▋                     |  ETA: 0:00:28
# Sampling  50%|█████████████████████                     |  ETA: 0:00:27
# Sampling  51%|█████████████████████▍                    |  ETA: 0:00:26
# Sampling  52%|█████████████████████▊                    |  ETA: 0:00:25
# Sampling  52%|██████████████████████                    |  ETA: 0:00:25
# Sampling  53%|██████████████████████▍                   |  ETA: 0:00:24
# Sampling  54%|██████████████████████▊                   |  ETA: 0:00:23
# Sampling  55%|███████████████████████▏                  |  ETA: 0:00:23
# Sampling  56%|███████████████████████▌                  |  ETA: 0:00:22
# Sampling  57%|███████████████████████▊                  |  ETA: 0:00:22
# Sampling  57%|████████████████████████▏                 |  ETA: 0:00:21
# Sampling  58%|████████████████████████▌                 |  ETA: 0:00:21
# Sampling  59%|████████████████████████▉                 |  ETA: 0:00:20
# Sampling  60%|█████████████████████████▎                |  ETA: 0:00:19
# Sampling  61%|█████████████████████████▌                |  ETA: 0:00:19
# Sampling  62%|█████████████████████████▉                |  ETA: 0:00:18
# Sampling  62%|██████████████████████████▎               |  ETA: 0:00:18
# Sampling  63%|██████████████████████████▋               |  ETA: 0:00:17
# Sampling  64%|███████████████████████████               |  ETA: 0:00:17
# Sampling  65%|███████████████████████████▎              |  ETA: 0:00:16
# Sampling  66%|███████████████████████████▋              |  ETA: 0:00:16
# Sampling  67%|████████████████████████████              |  ETA: 0:00:15
# Sampling  68%|████████████████████████████▍             |  ETA: 0:00:15
# Sampling  68%|████████████████████████████▊             |  ETA: 0:00:14
# Sampling  69%|█████████████████████████████             |  ETA: 0:00:14
# Sampling  70%|█████████████████████████████▍            |  ETA: 0:00:13
# Sampling  71%|█████████████████████████████▊            |  ETA: 0:00:13
# Sampling  72%|██████████████████████████████▏           |  ETA: 0:00:13
# Sampling  72%|██████████████████████████████▌           |  ETA: 0:00:12
# Sampling  73%|██████████████████████████████▊           |  ETA: 0:00:12
# Sampling  74%|███████████████████████████████▏          |  ETA: 0:00:11
# Sampling  75%|███████████████████████████████▌          |  ETA: 0:00:11
# Sampling  76%|███████████████████████████████▉          |  ETA: 0:00:10
# Sampling  77%|████████████████████████████████▎         |  ETA: 0:00:10
# Sampling  78%|████████████████████████████████▌         |  ETA: 0:00:10
# Sampling  78%|████████████████████████████████▉         |  ETA: 0:00:09
# Sampling  79%|█████████████████████████████████▎        |  ETA: 0:00:09
# Sampling  80%|█████████████████████████████████▋        |  ETA: 0:00:08
# Sampling  81%|██████████████████████████████████        |  ETA: 0:00:08
# Sampling  82%|██████████████████████████████████▎       |  ETA: 0:00:08
# Sampling  82%|██████████████████████████████████▋       |  ETA: 0:00:07
# Sampling  83%|███████████████████████████████████       |  ETA: 0:00:07
# Sampling  84%|███████████████████████████████████▍      |  ETA: 0:00:07
# Sampling  85%|███████████████████████████████████▊      |  ETA: 0:00:06
# Sampling  86%|████████████████████████████████████      |  ETA: 0:00:06
# Sampling  87%|████████████████████████████████████▍     |  ETA: 0:00:05
# Sampling  88%|████████████████████████████████████▊     |  ETA: 0:00:05
# Sampling  88%|█████████████████████████████████████▏    |  ETA: 0:00:05
# Sampling  89%|█████████████████████████████████████▌    |  ETA: 0:00:04
# Sampling  90%|█████████████████████████████████████▊    |  ETA: 0:00:04
# Sampling  91%|██████████████████████████████████████▏   |  ETA: 0:00:04
# Sampling  92%|██████████████████████████████████████▌   |  ETA: 0:00:03
# Sampling  92%|██████████████████████████████████████▉   |  ETA: 0:00:03
# Sampling  93%|███████████████████████████████████████▎  |  ETA: 0:00:03
# Sampling  94%|███████████████████████████████████████▌  |  ETA: 0:00:02
# Sampling  95%|███████████████████████████████████████▉  |  ETA: 0:00:02
# Sampling  96%|████████████████████████████████████████▎ |  ETA: 0:00:02
# Sampling  97%|████████████████████████████████████████▋ |  ETA: 0:00:01
# Sampling  98%|█████████████████████████████████████████ |  ETA: 0:00:01
# Sampling  98%|█████████████████████████████████████████▎|  ETA: 0:00:01
# Sampling  99%|█████████████████████████████████████████▋|  ETA: 0:00:00
# Sampling 100%|██████████████████████████████████████████| Time: 0:00:38
# Sampling 100%|██████████████████████████████████████████| Time: 0:00:41
# Chains MCMC chain (100×947×1 Array{Float64, 3}):
#
# Iterations        = 21:1:120
# Number of chains  = 1
# Samples per chain = 100
# Wall duration     = 39.17 seconds
# Compute duration  = 39.17 seconds
# parameters        = omegam_pr, h0_pr, s8_pr, hz_model[1], hz_model[2], hz_model[3], hz_model[4], hz_model[5], hz_model[6], hz_model[7], hz_model[8], hz_model[9], hz_model[10], hz_model[11], hz_model[12], hz_model[13], hz_model[14], hz_model[15], hz_model[16], hz_model[17], hz_model[18], hz_model[19], hz_model[20], hz_model[21], hz_model[22], hz_model[23], hz_model[24], hz_model[25], hz_model[26], hz_model[27], hz_model[28], hz_model[29], hz_model[30], hz_model[31], hz_model[32], hz_model[33], hz_model[34], hz_model[35], hz_model[36], hz_model[37], hz_model[38], hz_model[39], hz_model[40], hz_model[41], hz_model[42], hz_model[43], hz_model[44], hz_model[45], hz_model[46], hz_model[47], hz_model[48], hz_model[49], hz_model[50], hz_model[51], hz_model[52], hz_model[53], hz_model[54], hz_model[55], hz_model[56], hz_model[57], hz_model[58], hz_model[59], hz_model[60], hz_model[61], hz_model[62], hz_model[63], hz_model[64], hz_model[65], hz_model[66], hz_model[67], hz_model[68], hz_model[69], hz_model[70], hz_model[71], hz_model[72], hz_model[73], hz_model[74], hz_model[75], hz_model[76], hz_model[77], hz_model[78], hz_model[79], hz_model[80], hz_model[81], hz_model[82], hz_model[83], hz_model[84], hz_model[85], hz_model[86], hz_model[87], hz_model[88], hz_model[89], hz_model[90], hz_model[91], hz_model[92], hz_model[93], hz_model[94], hz_model[95], hz_model[96], hz_model[97], hz_model[98], hz_model[99], hz_model[100], hz_model[101], hz_model[102], hz_model[103], hz_model[104], hz_model[105], hz_model[106], hz_model[107], hz_model[108], hz_model[109], hz_model[110], hz_model[111], hz_model[112], hz_model[113], hz_model[114], hz_model[115], hz_model[116], hz_model[117], hz_model[118], hz_model[119], hz_model[120], hz_model[121], hz_model[122], hz_model[123], hz_model[124], hz_model[125], hz_model[126], hz_model[127], hz_model[128], hz_model[129], hz_model[130], hz_model[131], hz_model[132], hz_model[133], hz_model[134], hz_model[135], hz_model[136], hz_model[137], hz_model[138], hz_model[139], hz_model[140], hz_model[141], hz_model[142], hz_model[143], hz_model[144], hz_model[145], hz_model[146], hz_model[147], hz_model[148], hz_model[149], hz_model[150], hz_model[151], hz_model[152], hz_model[153], hz_model[154], hz_model[155], hz_model[156], hz_model[157], hz_model[158], hz_model[159], hz_model[160], hz_model[161], hz_model[162], hz_model[163], hz_model[164], hz_model[165], hz_model[166], hz_model[167], hz_model[168], hz_model[169], hz_model[170], hz_model[171], hz_model[172], hz_model[173], hz_model[174], hz_model[175], hz_model[176], hz_model[177], hz_model[178], hz_model[179], hz_model[180], hz_model[181], hz_model[182], hz_model[183], hz_model[184], hz_model[185], hz_model[186], hz_model[187], hz_model[188], hz_model[189], hz_model[190], hz_model[191], hz_model[192], hz_model[193], hz_model[194], hz_model[195], hz_model[196], hz_model[197], hz_model[198], hz_model[199], hz_model[200], hz_model[201], hz_model[202], hz_model[203], hz_model[204], hz_model[205], hz_model[206], hz_model[207], hz_model[208], hz_model[209], hz_model[210], hz_model[211], hz_model[212], hz_model[213], hz_model[214], hz_model[215], hz_model[216], hz_model[217], hz_model[218], hz_model[219], hz_model[220], hz_model[221], hz_model[222], hz_model[223], hz_model[224], hz_model[225], hz_model[226], hz_model[227], hz_model[228], hz_model[229], hz_model[230], hz_model[231], hz_model[232], hz_model[233], hz_model[234], hz_model[235], hz_model[236], hz_model[237], hz_model[238], hz_model[239], hz_model[240], hz_model[241], hz_model[242], hz_model[243], hz_model[244], hz_model[245], hz_model[246], hz_model[247], hz_model[248], hz_model[249], hz_model[250], hz_model[251], hz_model[252], hz_model[253], hz_model[254], hz_model[255], hz_model[256], hz_model[257], hz_model[258], hz_model[259], hz_model[260], hz_model[261], hz_model[262], hz_model[263], hz_model[264], hz_model[265], hz_model[266], hz_model[267], hz_model[268], hz_model[269], hz_model[270], hz_model[271] ...
# internals         = lp, n_steps, is_accept, acceptance_rate, log_density, hamiltonian_energy, hamiltonian_energy_error, max_hamiltonian_energy_error, tree_depth, numerical_error, step_size, nom_step_size
#
# Summary Statistics
#     parameters      mean       std      mcse   ess_bulk   ess_tail      rhat   ⋯
#         Symbol   Float64   Float64   Float64    Float64    Float64   Float64   ⋯
#
#      omegam_pr    0.3005    0.0025    0.0004    39.0396    34.3628    1.0096   ⋯
#          h0_pr    0.6675    0.0154    0.0021    53.2733    31.7840    0.9959   ⋯
#          s8_pr    0.8015    0.0380    0.0082    22.6420    21.0246    1.1123   ⋯
#    hz_model[1]   66.7491    1.5369    0.2135    53.2733    31.7840    0.9960   ⋯
#    hz_model[2]   66.8893    1.5401    0.2140    53.2733    31.7840    0.9960   ⋯
#    hz_model[3]   67.0311    1.5434    0.2144    53.2733    31.7840    0.9960   ⋯
#    hz_model[4]   67.1746    1.5467    0.2149    53.2733    31.7840    0.9959   ⋯
#    hz_model[5]   67.3198    1.5500    0.2153    53.2733    31.7840    0.9960   ⋯
#    hz_model[6]   67.4667    1.5534    0.2158    53.2733    31.7840    0.9959   ⋯
#    hz_model[7]   67.6153    1.5568    0.2163    53.2733    31.7840    0.9959   ⋯
#    hz_model[8]   67.7657    1.5603    0.2168    53.2733    31.7840    0.9960   ⋯
#    hz_model[9]   67.9178    1.5638    0.2173    53.2733    31.7840    0.9960   ⋯
#   hz_model[10]   68.0718    1.5673    0.2177    53.2733    31.7840    0.9959   ⋯
#   hz_model[11]   68.2275    1.5709    0.2182    53.2733    31.7840    0.9960   ⋯
#   hz_model[12]   68.3851    1.5746    0.2188    53.2733    31.7840    0.9959   ⋯
#   hz_model[13]   68.5445    1.5782    0.2193    53.2733    31.7840    0.9959   ⋯
#   hz_model[14]   68.7057    1.5819    0.2198    53.2733    31.7840    0.9960   ⋯
#        ⋮            ⋮         ⋮         ⋮         ⋮          ⋮          ⋮      ⋱
#                                                    1 column and 918 rows omitted
#
# Quantiles
#     parameters      2.5%     25.0%     50.0%     75.0%     97.5%
#         Symbol   Float64   Float64   Float64   Float64   Float64
#
#      omegam_pr    0.2950    0.2989    0.3004    0.3024    0.3051
#          h0_pr    0.6359    0.6556    0.6682    0.6782    0.6980
#          s8_pr    0.7298    0.7779    0.8008    0.8246    0.8844
#    hz_model[1]   63.5946   65.5592   66.8243   67.8171   69.7980
#    hz_model[2]   63.7282   65.6969   66.9646   67.9595   69.9445
#    hz_model[3]   63.8633   65.8362   67.1066   68.1036   70.0928
#    hz_model[4]   64.0000   65.9771   67.2502   68.2494   70.2429
#    hz_model[5]   64.1383   66.1197   67.3956   68.3969   70.3947
#    hz_model[6]   64.2783   66.2640   67.5427   68.5462   70.5483
#    hz_model[7]   64.4199   66.4100   67.6915   68.6972   70.7037
#    hz_model[8]   64.5632   66.5577   67.8420   68.8500   70.8610
#    hz_model[9]   64.7082   66.7071   67.9943   69.0046   71.0201
#   hz_model[10]   64.8548   66.8583   68.1485   69.1610   71.1811
#   hz_model[11]   65.0032   67.0113   68.3044   69.3192   71.3439
#   hz_model[12]   65.1533   67.1660   68.4621   69.4793   71.5087
#   hz_model[13]   65.3052   67.3226   68.6217   69.6412   71.6754
#   hz_model[14]   65.4588   67.4810   68.7831   69.8051   71.8440
#        ⋮            ⋮         ⋮         ⋮         ⋮         ⋮
#                                                   918 rows omitted

# %%
# lcdm chains
hdata_lcdm = group(chain_LCDM, :hz_model).value.data[:,:,1];
chidata_lcdm = group(chain_LCDM, :dm_model).value.data[:,:,1];
fs8data_lcdm = group(chain_LCDM, :fs8_model).value.data[:,:,1];

# mean and standard deviation - lcdm
hz_lcdm_m, hz_lcdm_s = mean(hdata_lcdm, dims=1), std(hdata_lcdm, dims=1); 
dm_lcdm_m, dm_lcdm_s = mean(chidata_lcdm, dims=1), std(chidata_lcdm, dims=1); 
fs8_lcdm_m, fs8_lcdm_s = mean(fs8data_lcdm, dims=1), std(fs8data_lcdm, dims=1);

# %%
plot(fakedatahz.z, fakedatahz.data, yerr=hz_err, label="Data H(z)", ms=2, seriestype=:scatter)
plot!(z_integ1, vec(hz_lcdm_m), label=" H(z) LCDM mean")
plot!(z_integ1, vec(hz_lcdm_m .- hz_lcdm_s),  fillrange = vec(hz_lcdm_m .+ hz_lcdm_s), fillalpha=0.2, c=1, label="H(z) LCDM standard deviation")

# %%
plot(fakedatadm.z, fakedatadm.data, yerr=dm_err, label="Data chi", ms=2, seriestype=:scatter)
plot!(z_integ1, vec(dm_lcdm_m), label="Chi LCDM mean")
plot!(z_integ1, vec(dm_lcdm_m .- dm_lcdm_s),  fillrange = vec(dm_lcdm_m .+ dm_lcdm_s), fillalpha=0.2, c=1, label="Chi LCDM standard deviation")

# %%
plot(fakedatafs8.z, fakedatafs8.data, yerr=fs8_err, label="Data fs8", ms=2, seriestype=:scatter)
plot!(z_integ1, vec(fs8_lcdm_m), label="fs8 lcdm")
plot!(z_integ1, vec(fs8_lcdm_m .- fs8_lcdm_s),  fillrange = vec(fs8_lcdm_m .+ fs8_lcdm_s), fillalpha=0.2, c=1, label="fs8 lcdm standard deviation")

# %% [markdown]
# ## GP modelling - priors

# %%
zlat = range(0, 3.0, length=15); # latent variable space
z_integ = cosmo1.settings.zs; # integral variable space

# %%
function model_latent_GP(eta, l, v; omega_m=cosmo1.cpar.Ωm, sigma_8=cosmo1.cpar.σ8, h_0 = cosmo1.cpar.h,
                         x=zlat, z=z_obs, data_cov=covariance_obs)
    # Dimensions of predictors .
    kernel = sqexp_cov_fn(x; eta=eta, l=l)
    cpar = CosmoPar(Ωm=omega_m,  Ωb=cosmo1.cpar.Ωb, h=h_0, σ8=sigma_8)
    mean_ex = Ez(cpar, x)
    # a latent GP is carried out using a Wiener filter
    ex = latent_GP(mean_ex, v, kernel)
    # transforms hx from x space to z space
    ez =  conditional(x, z, ex, sqexp_cov_fn;
                     eta=eta, l=l)
    return ex, ez
end
# Out:
# model_latent_GP (generic function with 1 method)

# %% [markdown]
# hx is the GP realisation of the hubble parameter. hz transforms hx from the latent space to another parameter space (integral or observation).

# %%
N_samples = 100
# data parameter space conditional
exs1=zeros(N_samples, 15) #latent variable chain
ezs1=zeros(N_samples, length(z_obs)) #observed variable chain
# pick 100 random hyperparameter combinations, and compute the GP realisation of them in both latent and conditional space.
for i in 1:N_samples
    v = rand(MvNormal(zeros(length(zlat)), ones(length(zlat))))
    exs1[i, :], ezs1[i, :] = model_latent_GP(0.1, 0.3, v)
end
y_m1, y_s1 = mean(ezs1, dims=1), std(ezs1, dims=1); #observed space
gp_m1, gp_s1 = mean(exs1, dims=1), std(exs1, dims=1); #latent space

# %%
# integral parameter space conditional
exs2=zeros(N_samples, length(zlat))
ezs2=zeros(N_samples, length(z_integ))
hz_pr=zeros(N_samples, length(z_integ))
dm_pr=zeros(N_samples, length(z_integ))
fs8_pr=zeros(N_samples, length(z_integ))

for i in 1:N_samples
    v = rand(MvNormal(zeros(length(zlat)), ones(length(zlat))))
    h_pr = rand(Uniform(0.6, 0.8))
    s8_pr = rand(Uniform(0.7, 0.9))
    omegam_pr = rand(Uniform(0.25,0.35))
    exs2[i, :], ezs2[i, :] = model_latent_GP(0.1, 0.3, v; z=z_integ, sigma_8=s8_pr)
    hz_pr[i, :] = hz_from_ez(z_integ, h_pr, ezs2[i, :])
    dm_pr[i, :] = dm_from_ez(z_integ, h_pr, ezs2[i, :])
    fs8_pr[i, :] = fs8_from_ez(z_integ, omegam_pr, s8_pr, h_pr, ezs2[i, :], eltype(ezs2[i, :]))
end

y_m2, y_s2 = mean(ezs2, dims=1), std(ezs2, dims=1); #integral space
gp_m2, gp_s2 = mean(exs2, dims=1), std(exs2, dims=1); #latent space

hz_m2, hz_s2 = mean(hz_pr, dims=1), std(hz_pr, dims=1); 
chi_m2, chi_s2 = mean(dm_pr, dims=1), std(dm_pr, dims=1);
fs8_m2, fs8_s2 = mean(fs8_pr, dims=1), std(fs8_pr, dims=1);

# %%
# prior model predictions
hz_itp2 = LinearInterpolation(z_integ, vec(hz_m2), extrapolation_bc=Line());
dm_itp2 = LinearInterpolation(z_integ, vec(chi_m2), extrapolation_bc=Line());
fs8_itp2 = LinearInterpolation(z_integ, vec(fs8_m2), extrapolation_bc=Line());

# %%
# integral space hz plot
plot(fakedatahz.z, fakedatahz.data, yerr=hz_err, label="Data hz", ms=2, seriestype=:scatter)
plot!(z_integ, vec(hz_m2), label="hz mean")
plot!(z_integ, vec(hz_m2 .- hz_s2),  fillrange = vec(hz_m2 .+ hz_s2), fillalpha=0.2, c=1, label="hz standard deviation")

# %%
# plotting chi data 
plot(fakedatadm.z, fakedatadm.data, yerr=dm_err, label="Data chi", ms=2, seriestype=:scatter)
plot!(z_integ, vec(chi_m2), label="chi mean")
plot!(z_integ, vec(chi_m2 .- chi_s2),  fillrange = vec(chi_m2 .+ chi_s2), fillalpha=0.2, c=1, label="chi standard deviation")

# %%
# plotting fs8 data 
plot(fakedatafs8.z, fakedatafs8.data, yerr=fs8_err, label="Data fs8", ms=2, seriestype=:scatter)
plot!(z_integ, vec(fs8_m2), label="fs8 mean")
plot!(z_integ, vec(fs8_m2 .- fs8_s2),  fillrange = vec(fs8_m2 .+ fs8_s2), fillalpha=0.2, c=1, label="fs8 standard deviation")

# %%
om_gp = cosmo1.cpar.Ωm
ob_gp = cosmo1.cpar.Ωb
hc_gp = cosmo1.cpar.h
#s8_gp = σ8=s8_po
# Out:
# 0.67

# %% [markdown]
# ## GP modelling - posteriors

# %%
@model function stats_model(y; int_grid=z_integ, X=zlat, data_x=z_obs, data_cov=covariance_obs)
    # Priors, parameters
    eta2 = 20
    l2 = 0.3
    v_po ~ MvNormal(zeros(length(X)), ones(length(X)))
    omegam_po ~ Uniform(0.25, 0.35)
    s8_po ~ Uniform(0.7, 0.9)
    h_po ~ Uniform(0.6, 0.8)

    kernel = sqexp_cov_fn(X, eta=eta2, l=l2)
    cpar = CosmoPar(Ωm=om_gp, Ωb=ob_gp, h=hc_gp)
    mean_ez = Ez(cpar, X)
    ez_latent = latent_GP(mean_ez, v_po, kernel)
    ez_gp = conditional(X, int_grid, ez_latent, sqexp_cov_fn; eta=eta2, l=l2) # converting from latent space to integral space
    
    # sampling over parameters
    hz_pmod := hz_from_ez(int_grid, h_po, ez_gp);
    chi_pmod := dm_from_ez(int_grid, h_po, ez_gp);
    fs8_pmod := fs8_from_ez(int_grid, omegam_po, s8_po, h_po, ez_gp, eltype(ez_gp));

    hz_interp = LinearInterpolation(int_grid, hz_pmod, extrapolation_bc=Line())
    chi_interp = LinearInterpolation(int_grid, chi_pmod, extrapolation_bc=Line())
    fs8_interp = LinearInterpolation(int_grid, fs8_pmod, extrapolation_bc=Line())

    hdata := hz_interp(fakedatahz.z)
    chidata := chi_interp(fakedatadm.z)
    fs8data := fs8_interp(fakedatafs8.z)
    datay = [hdata;chidata;fs8data]

    y ~ MvNormal(datay, data_cov) 

end
# Out:
# stats_model (generic function with 2 methods)

# %%
chain_gp = sample(stats_model(data_obs), NUTS(15, 0.65), 75)
# Out:
# Sampling   0%|                                          |  ETA: N/A
# ┌ Info: Found initial step size
# │   ϵ = 2.602085213965211e-19
# └ @ Turing.Inference /Users/vis/.julia/packages/Turing/QN7BL/src/mcmc/hmc.jl:212
# Sampling   1%|▌                                         |  ETA: 0:04:51
# Sampling   2%|▉                                         |  ETA: 0:02:55
# Sampling   3%|█▍                                        |  ETA: 0:03:47
# Sampling   4%|█▉                                        |  ETA: 0:10:43
# Sampling   6%|██▍                                       |  ETA: 0:21:01
# Sampling   7%|██▊                                       |  ETA: 0:27:51
# Sampling   8%|███▎                                      |  ETA: 0:32:27
# Sampling   9%|███▊                                      |  ETA: 0:35:40
# Sampling  10%|████▎                                     |  ETA: 0:38:03
# Sampling  11%|████▋                                     |  ETA: 0:39:47
# Sampling  12%|█████▏                                    |  ETA: 0:41:06
# Sampling  13%|█████▋                                    |  ETA: 0:42:02
# Sampling  14%|██████▏                                   |  ETA: 0:42:43
# Sampling  16%|██████▌                                   |  ETA: 0:43:13
# Sampling  17%|███████                                   |  ETA: 0:43:30
# Sampling  18%|███████▌                                  |  ETA: 0:43:39
# Sampling  19%|███████▉                                  |  ETA: 0:43:40
# Sampling  20%|████████▍                                 |  ETA: 0:43:37
# Sampling  21%|████████▉                                 |  ETA: 0:43:29
# Sampling  22%|█████████▍                                |  ETA: 0:43:18
# Sampling  23%|█████████▊                                |  ETA: 0:43:03
# Sampling  24%|██████████▎                               |  ETA: 0:42:46
# Sampling  26%|██████████▊                               |  ETA: 0:42:27
# Sampling  27%|███████████▎                              |  ETA: 0:42:06
# Sampling  28%|███████████▋                              |  ETA: 0:41:43
# Sampling  29%|████████████▏                             |  ETA: 0:41:19
# Sampling  30%|████████████▋                             |  ETA: 0:40:53
# Sampling  31%|█████████████▏                            |  ETA: 0:40:26
# Sampling  32%|█████████████▌                            |  ETA: 0:39:58
# Sampling  33%|██████████████                            |  ETA: 0:39:28
# Sampling  34%|██████████████▌                           |  ETA: 0:38:58
# Sampling  36%|██████████████▉                           |  ETA: 0:38:27
# Sampling  37%|███████████████▍                          |  ETA: 0:37:55
# Sampling  38%|███████████████▉                          |  ETA: 0:37:22
# Sampling  39%|████████████████▍                         |  ETA: 0:36:49
# Sampling  40%|████████████████▊                         |  ETA: 0:36:16
# Sampling  41%|█████████████████▎                        |  ETA: 0:35:42
# Sampling  42%|█████████████████▊                        |  ETA: 0:35:07
# Sampling  43%|██████████████████▎                       |  ETA: 0:34:31
# Sampling  44%|██████████████████▋                       |  ETA: 0:33:55
# Sampling  46%|███████████████████▏                      |  ETA: 0:33:20
# Sampling  47%|███████████████████▋                      |  ETA: 0:32:43
# Sampling  48%|████████████████████▏                     |  ETA: 0:32:05
# Sampling  49%|████████████████████▌                     |  ETA: 0:31:28
# Sampling  50%|█████████████████████                     |  ETA: 0:30:50
# Sampling  51%|█████████████████████▌                    |  ETA: 0:30:11
# Sampling  52%|█████████████████████▉                    |  ETA: 0:29:33
# Sampling  53%|██████████████████████▍                   |  ETA: 0:28:54
# Sampling  54%|██████████████████████▉                   |  ETA: 0:28:15
# Sampling  56%|███████████████████████▍                  |  ETA: 0:27:35
# Sampling  57%|███████████████████████▊                  |  ETA: 0:28:08
# Sampling  58%|████████████████████████▎                 |  ETA: 0:27:25
# Sampling  59%|████████████████████████▊                 |  ETA: 0:26:42
# Sampling  60%|█████████████████████████▎                |  ETA: 0:25:59
# Sampling  61%|█████████████████████████▋                |  ETA: 0:25:16
# Sampling  62%|██████████████████████████▏               |  ETA: 0:24:33
# Sampling  63%|██████████████████████████▋               |  ETA: 0:23:50
# Sampling  64%|███████████████████████████▏              |  ETA: 0:23:08
# Sampling  66%|███████████████████████████▌              |  ETA: 0:22:25
# Sampling  67%|████████████████████████████              |  ETA: 0:21:42
# Sampling  68%|████████████████████████████▌             |  ETA: 0:20:59
# Sampling  69%|████████████████████████████▉             |  ETA: 0:20:16
# Sampling  70%|█████████████████████████████▍            |  ETA: 0:19:33
# Sampling  71%|█████████████████████████████▉            |  ETA: 0:18:50
# Sampling  72%|██████████████████████████████▍           |  ETA: 0:18:07
# Sampling  73%|██████████████████████████████▊           |  ETA: 0:17:23
# Sampling  74%|███████████████████████████████▎          |  ETA: 0:16:40
# Sampling  76%|███████████████████████████████▊          |  ETA: 0:15:57
# Sampling  77%|████████████████████████████████▎         |  ETA: 0:27:17
# Sampling 100%|██████████████████████████████████████████| Time: 1:29:59
# InterruptException:
#
#
#
# Stacktrace:
#
#   [1] (::var"#15#16"{Interpolations.Extrapolation{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9}, 1, Interpolations.GriddedInterpolation{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9}, 1, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9}}, Gridded{Linear{Throw{OnGrid}}}, Tuple{Vector{Float64}}}, Gridded{Linear{Throw{OnGrid}}}, Line{Nothing}}})(z::Float64)
#
#     @ Main ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X12sZmlsZQ==.jl:14
#
#   [2] evalrule(f::var"#15#16"{Interpolations.Extrapolation{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9}, 1, Interpolations.GriddedInterpolation{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9}, 1, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9}}, Gridded{Linear{Throw{OnGrid}}}, Tuple{Vector{Float64}}}, Gridded{Linear{Throw{OnGrid}}}, Line{Nothing}}}, a::Float64, b::Float64, x::Vector{Float64}, w::Vector{Float64}, wg::Vector{Float64}, nrm::typeof(norm))
#
#     @ QuadGK ~/.julia/packages/QuadGK/7rND3/src/evalrule.jl:31
#
#   [3] refine(f::var"#15#16"{Interpolations.Extrapolation{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9}, 1, Interpolations.GriddedInterpolation{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9}, 1, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9}}, Gridded{Linear{Throw{OnGrid}}}, Tuple{Vector{Float64}}}, Gridded{Linear{Throw{OnGrid}}}, Line{Nothing}}}, segs::Vector{QuadGK.Segment{Float64, ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9}, ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9}}}, I::ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9}, E::ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9}, numevals::Int64, x::Vector{Float64}, w::Vector{Float64}, wg::Vector{Float64}, n::Int64, atol::ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9}, rtol::Float64, maxevals::Int64, nrm::typeof(norm))
#
#     @ QuadGK ~/.julia/packages/QuadGK/7rND3/src/adapt.jl:115
#
#   [4] adapt
#
#     @ ~/.julia/packages/QuadGK/7rND3/src/adapt.jl:96 [inlined]
#
#   [5] do_quadgk(f::var"#15#16"{Interpolations.Extrapolation{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9}, 1, Interpolations.GriddedInterpolation{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9}, 1, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9}}, Gridded{Linear{Throw{OnGrid}}}, Tuple{Vector{Float64}}}, Gridded{Linear{Throw{OnGrid}}}, Line{Nothing}}}, s::Tuple{Float64, Float64}, n::Int64, atol::Nothing, rtol::Float64, maxevals::Int64, nrm::typeof(norm), _segbuf::Nothing, eval_segbuf::Nothing)
#
#     @ QuadGK ~/.julia/packages/QuadGK/7rND3/src/adapt.jl:87
#
#   [6] #50
#
#     @ ~/.julia/packages/QuadGK/7rND3/src/api.jl:83 [inlined]
#
#   [7] handle_infinities(workfunc::QuadGK.var"#50#51"{Nothing, Float64, Int64, Int64, typeof(norm), Nothing, Nothing}, f::var"#15#16"{Interpolations.Extrapolation{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9}, 1, Interpolations.GriddedInterpolation{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9}, 1, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9}}, Gridded{Linear{Throw{OnGrid}}}, Tuple{Vector{Float64}}}, Gridded{Linear{Throw{OnGrid}}}, Line{Nothing}}}, s::Tuple{Float64, Float64})
#
#     @ QuadGK ~/.julia/packages/QuadGK/7rND3/src/adapt.jl:189
#
#   [8] #quadgk#49
#
#     @ ~/.julia/packages/QuadGK/7rND3/src/api.jl:82 [inlined]
#
#   [9] quadgk
#
#     @ ~/.julia/packages/QuadGK/7rND3/src/api.jl:80 [inlined]
#
#  [10] dm_from_ez(zarr::Vector{Float64}, h0::ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9}, ez::Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9}})
#
#     @ Main ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X12sZmlsZQ==.jl:14
#
#  [11] stats_model(__model__::DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, __varinfo__::DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9}}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9}}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9}}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9}}, Vector{Set{DynamicPPL.Selector}}}}, ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9}}, __context__::DynamicPPL.SamplingContext{DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext, Random.TaskLocalRNG}, y::Vector{Float64}; int_grid::Vector{Float64}, X::StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, data_x::Vector{Float64}, data_cov::BlockDiagonal{Float64, Matrix{Float64}})
#
#     @ Main ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X45sZmlsZQ==.jl:18
#
#  [12] stats_model
#
#     @ ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X45sZmlsZQ==.jl:1 [inlined]
#
#  [13] _evaluate!!
#
#     @ ~/.julia/packages/DynamicPPL/MjWTB/src/model.jl:973 [inlined]
#
#  [14] evaluate_threadunsafe!!
#
#     @ ~/.julia/packages/DynamicPPL/MjWTB/src/model.jl:946 [inlined]
#
#  [15] evaluate!!
#
#     @ ~/.julia/packages/DynamicPPL/MjWTB/src/model.jl:894 [inlined]
#
#  [16] logdensity(f::LogDensityFunction{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, DynamicPPL.SamplingContext{DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext, Random.TaskLocalRNG}}, θ::Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9}})
#
#     @ DynamicPPL ~/.julia/packages/DynamicPPL/MjWTB/src/logdensityfunction.jl:140
#
#  [17] Fix1
#
#     @ ./operators.jl:1127 [inlined]
#
#  [18] chunk_mode_gradient!(result::DiffResults.MutableDiffResult{1, Float64, Tuple{Vector{Float64}}}, f::Base.Fix1{typeof(LogDensityProblems.logdensity), LogDensityFunction{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, DynamicPPL.SamplingContext{DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext, Random.TaskLocalRNG}}}, x::Vector{Float64}, cfg::ForwardDiff.GradientConfig{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9}}})
#
#     @ ForwardDiff ~/.julia/packages/ForwardDiff/X74OO/src/gradient.jl:125
#
#  [19] gradient!
#
#     @ ~/.julia/packages/ForwardDiff/X74OO/src/gradient.jl:41 [inlined]
#
#  [20] gradient!
#
#     @ ~/.julia/packages/ForwardDiff/X74OO/src/gradient.jl:36 [inlined]
#
#  [21] logdensity_and_gradient
#
#     @ ~/.julia/packages/LogDensityProblemsAD/rBlLq/ext/LogDensityProblemsADForwardDiffExt.jl:118 [inlined]
#
#  [22] ∂logπ∂θ
#
#     @ ~/.julia/packages/Turing/QN7BL/src/mcmc/hmc.jl:180 [inlined]
#
#  [23] ∂H∂θ
#
#     @ ~/.julia/packages/AdvancedHMC/9NhHg/src/hamiltonian.jl:38 [inlined]
#
#  [24] step(lf::AdvancedHMC.Leapfrog{Float64}, h::AdvancedHMC.Hamiltonian{AdvancedHMC.DiagEuclideanMetric{Float64, Vector{Float64}}, AdvancedHMC.GaussianKinetic, Base.Fix1{typeof(LogDensityProblems.logdensity), LogDensityProblemsADForwardDiffExt.ForwardDiffLogDensity{LogDensityFunction{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, DynamicPPL.SamplingContext{DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext, Random.TaskLocalRNG}}, ForwardDiff.Chunk{9}, ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, ForwardDiff.GradientConfig{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9}}}}}, Turing.Inference.var"#∂logπ∂θ#32"{LogDensityProblemsADForwardDiffExt.ForwardDiffLogDensity{LogDensityFunction{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, DynamicPPL.SamplingContext{DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext, Random.TaskLocalRNG}}, ForwardDiff.Chunk{9}, ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, ForwardDiff.GradientConfig{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9}}}}}}, z::AdvancedHMC.PhasePoint{Vector{Float64}, AdvancedHMC.DualValue{Float64, Vector{Float64}}}, n_steps::Int64; fwd::Bool, full_trajectory::Val{false})
#
#     @ AdvancedHMC ~/.julia/packages/AdvancedHMC/9NhHg/src/integrator.jl:229
#
#  [25] step
#
#     @ ~/.julia/packages/AdvancedHMC/9NhHg/src/integrator.jl:199 [inlined]
#
#  [26] build_tree(rng::Random.TaskLocalRNG, nt::AdvancedHMC.Trajectory{AdvancedHMC.MultinomialTS, AdvancedHMC.Leapfrog{Float64}, AdvancedHMC.GeneralisedNoUTurn{Float64}}, h::AdvancedHMC.Hamiltonian{AdvancedHMC.DiagEuclideanMetric{Float64, Vector{Float64}}, AdvancedHMC.GaussianKinetic, Base.Fix1{typeof(LogDensityProblems.logdensity), LogDensityProblemsADForwardDiffExt.ForwardDiffLogDensity{LogDensityFunction{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, DynamicPPL.SamplingContext{DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext, Random.TaskLocalRNG}}, ForwardDiff.Chunk{9}, ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, ForwardDiff.GradientConfig{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9}}}}}, Turing.Inference.var"#∂logπ∂θ#32"{LogDensityProblemsADForwardDiffExt.ForwardDiffLogDensity{LogDensityFunction{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, DynamicPPL.SamplingContext{DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext, Random.TaskLocalRNG}}, ForwardDiff.Chunk{9}, ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, ForwardDiff.GradientConfig{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9}}}}}}, z::AdvancedHMC.PhasePoint{Vector{Float64}, AdvancedHMC.DualValue{Float64, Vector{Float64}}}, sampler::AdvancedHMC.MultinomialTS{Float64}, v ...
#
#     @ AdvancedHMC ~/.julia/packages/AdvancedHMC/9NhHg/src/trajectory.jl:639
#
#  [27] build_tree(rng::Random.TaskLocalRNG, nt::AdvancedHMC.Trajectory{AdvancedHMC.MultinomialTS, AdvancedHMC.Leapfrog{Float64}, AdvancedHMC.GeneralisedNoUTurn{Float64}}, h::AdvancedHMC.Hamiltonian{AdvancedHMC.DiagEuclideanMetric{Float64, Vector{Float64}}, AdvancedHMC.GaussianKinetic, Base.Fix1{typeof(LogDensityProblems.logdensity), LogDensityProblemsADForwardDiffExt.ForwardDiffLogDensity{LogDensityFunction{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, DynamicPPL.SamplingContext{DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext, Random.TaskLocalRNG}}, ForwardDiff.Chunk{9}, ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, ForwardDiff.GradientConfig{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9}}}}}, Turing.Inference.var"#∂logπ∂θ#32"{LogDensityProblemsADForwardDiffExt.ForwardDiffLogDensity{LogDensityFunction{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, DynamicPPL.SamplingContext{DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext, Random.TaskLocalRNG}}, ForwardDiff.Chunk{9}, ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, ForwardDiff.GradientConfig{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9}}}}}}, z::AdvancedHMC.PhasePoint{Vector{Float64}, AdvancedHMC.DualValue{Float64, Vector{Float64}}}, sampler::AdvancedHMC.MultinomialTS{Float64}, v ...
#
#     @ AdvancedHMC ~/.julia/packages/AdvancedHMC/9NhHg/src/trajectory.jl:654
#
#  [28] build_tree(rng::Random.TaskLocalRNG, nt::AdvancedHMC.Trajectory{AdvancedHMC.MultinomialTS, AdvancedHMC.Leapfrog{Float64}, AdvancedHMC.GeneralisedNoUTurn{Float64}}, h::AdvancedHMC.Hamiltonian{AdvancedHMC.DiagEuclideanMetric{Float64, Vector{Float64}}, AdvancedHMC.GaussianKinetic, Base.Fix1{typeof(LogDensityProblems.logdensity), LogDensityProblemsADForwardDiffExt.ForwardDiffLogDensity{LogDensityFunction{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, DynamicPPL.SamplingContext{DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext, Random.TaskLocalRNG}}, ForwardDiff.Chunk{9}, ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, ForwardDiff.GradientConfig{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9}}}}}, Turing.Inference.var"#∂logπ∂θ#32"{LogDensityProblemsADForwardDiffExt.ForwardDiffLogDensity{LogDensityFunction{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, DynamicPPL.SamplingContext{DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext, Random.TaskLocalRNG}}, ForwardDiff.Chunk{9}, ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, ForwardDiff.GradientConfig{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9}}}}}}, z::AdvancedHMC.PhasePoint{Vector{Float64}, AdvancedHMC.DualValue{Float64, Vector{Float64}}}, sampler::AdvancedHMC.MultinomialTS{Float64}, v ...
#
#     @ AdvancedHMC ~/.julia/packages/AdvancedHMC/9NhHg/src/trajectory.jl:649
#
# --- the above 2 lines are repeated 1 more time ---
#
#  [31] build_tree(rng::Random.TaskLocalRNG, nt::AdvancedHMC.Trajectory{AdvancedHMC.MultinomialTS, AdvancedHMC.Leapfrog{Float64}, AdvancedHMC.GeneralisedNoUTurn{Float64}}, h::AdvancedHMC.Hamiltonian{AdvancedHMC.DiagEuclideanMetric{Float64, Vector{Float64}}, AdvancedHMC.GaussianKinetic, Base.Fix1{typeof(LogDensityProblems.logdensity), LogDensityProblemsADForwardDiffExt.ForwardDiffLogDensity{LogDensityFunction{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, DynamicPPL.SamplingContext{DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext, Random.TaskLocalRNG}}, ForwardDiff.Chunk{9}, ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, ForwardDiff.GradientConfig{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9}}}}}, Turing.Inference.var"#∂logπ∂θ#32"{LogDensityProblemsADForwardDiffExt.ForwardDiffLogDensity{LogDensityFunction{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, DynamicPPL.SamplingContext{DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext, Random.TaskLocalRNG}}, ForwardDiff.Chunk{9}, ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, ForwardDiff.GradientConfig{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9}}}}}}, z::AdvancedHMC.PhasePoint{Vector{Float64}, AdvancedHMC.DualValue{Float64, Vector{Float64}}}, sampler::AdvancedHMC.MultinomialTS{Float64}, v ...
#
#     @ AdvancedHMC ~/.julia/packages/AdvancedHMC/9NhHg/src/trajectory.jl:654
#
#  [32] transition(rng::Random.TaskLocalRNG, τ::AdvancedHMC.Trajectory{AdvancedHMC.MultinomialTS, AdvancedHMC.Leapfrog{Float64}, AdvancedHMC.GeneralisedNoUTurn{Float64}}, h::AdvancedHMC.Hamiltonian{AdvancedHMC.DiagEuclideanMetric{Float64, Vector{Float64}}, AdvancedHMC.GaussianKinetic, Base.Fix1{typeof(LogDensityProblems.logdensity), LogDensityProblemsADForwardDiffExt.ForwardDiffLogDensity{LogDensityFunction{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, DynamicPPL.SamplingContext{DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext, Random.TaskLocalRNG}}, ForwardDiff.Chunk{9}, ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, ForwardDiff.GradientConfig{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9}}}}}, Turing.Inference.var"#∂logπ∂θ#32"{LogDensityProblemsADForwardDiffExt.ForwardDiffLogDensity{LogDensityFunction{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, DynamicPPL.SamplingContext{DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext, Random.TaskLocalRNG}}, ForwardDiff.Chunk{9}, ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, ForwardDiff.GradientConfig{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9}}}}}}, z0::AdvancedHMC.PhasePoint{Vector{Float64}, AdvancedHMC.DualValue{Float64, Vector{Float64}}})
#
#     @ AdvancedHMC ~/.julia/packages/AdvancedHMC/9NhHg/src/trajectory.jl:703
#
#  [33] transition
#
#     @ ~/.julia/packages/AdvancedHMC/9NhHg/src/sampler.jl:59 [inlined]
#
#  [34] step(rng::Random.TaskLocalRNG, model::DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, spl::DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, state::Turing.Inference.HMCState{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, AdvancedHMC.HMCKernel{AdvancedHMC.FullMomentumRefreshment, AdvancedHMC.Trajectory{AdvancedHMC.MultinomialTS, AdvancedHMC.Leapfrog{Float64}, AdvancedHMC.GeneralisedNoUTurn{Float64}}}, AdvancedHMC.Hamiltonian{AdvancedHMC.DiagEuclideanMetric{Float64, Vector{Float64}}, AdvancedHMC.GaussianKinetic, Base.Fix1{typeof(LogDensityProblems.logdensity), LogDensityProblemsADForwardDiffExt.ForwardDiffLogDensity{LogDensityFunction{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, DynamicPPL.SamplingContext{DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext, Random.TaskLocalRNG}}, ForwardDiff.Chunk{9}, ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, ForwardDiff.GradientConfig{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 9}}}}}, Turing.Inference.var"#∂logπ∂θ#32"{LogDensityProblemsADForwardDiffExt.ForwardDiffLogDensity{LogDensityFunction{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{Abstract ...
#
#     @ Turing.Inference ~/.julia/packages/Turing/QN7BL/src/mcmc/hmc.jl:261
#
#  [35] macro expansion
#
#     @ ~/.julia/packages/AbstractMCMC/1gucv/src/sample.jl:0 [inlined]
#
#  [36] (::AbstractMCMC.var"#29#30"{Nothing, Int64, Int64, Int64, UnionAll, Nothing, @Kwargs{nadapts::Int64}, Random.TaskLocalRNG, DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, Int64, Float64, Int64, Int64})()
#
#     @ AbstractMCMC ~/.julia/packages/AbstractMCMC/1gucv/src/logging.jl:134
#
#  [37] with_logstate(f::AbstractMCMC.var"#29#30"{Nothing, Int64, Int64, Int64, UnionAll, Nothing, @Kwargs{nadapts::Int64}, Random.TaskLocalRNG, DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, Int64, Float64, Int64, Int64}, logstate::Base.CoreLogging.LogState)
#
#     @ Base.CoreLogging ./logging/logging.jl:524
#
#  [38] with_logger(f::Function, logger::LoggingExtras.TeeLogger{Tuple{LoggingExtras.EarlyFilteredLogger{TerminalLoggers.TerminalLogger, AbstractMCMC.var"#1#3"{Module}}, LoggingExtras.EarlyFilteredLogger{Base.CoreLogging.SimpleLogger, AbstractMCMC.var"#2#4"{Module}}}})
#
#     @ Base.CoreLogging ./logging/logging.jl:635
#
#  [39] with_progresslogger(f::Function, _module::Module, logger::Base.CoreLogging.SimpleLogger)
#
#     @ AbstractMCMC ~/.julia/packages/AbstractMCMC/1gucv/src/logging.jl:157
#
#  [40] macro expansion
#
#     @ ~/.julia/packages/AbstractMCMC/1gucv/src/logging.jl:133 [inlined]
#
#  [41] mcmcsample(rng::Random.TaskLocalRNG, model::DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, sampler::DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, N::Int64; progress::Bool, progressname::String, callback::Nothing, num_warmup::Int64, discard_initial::Int64, thinning::Int64, chain_type::Type, initial_state::Nothing, kwargs::@Kwargs{nadapts::Int64})
#
#     @ AbstractMCMC ~/.julia/packages/AbstractMCMC/1gucv/src/sample.jl:168
#
#  [42] sample(rng::Random.TaskLocalRNG, model::DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, sampler::DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, N::Int64; chain_type::Type, resume_from::Nothing, initial_state::Nothing, progress::Bool, nadapts::Int64, discard_adapt::Bool, discard_initial::Int64, kwargs::@Kwargs{})
#
#     @ Turing.Inference ~/.julia/packages/Turing/QN7BL/src/mcmc/hmc.jl:123
#
#  [43] sample
#
#     @ ~/.julia/packages/Turing/QN7BL/src/mcmc/hmc.jl:92 [inlined]
#
#  [44] #sample#4
#
#     @ ~/.julia/packages/Turing/QN7BL/src/mcmc/Inference.jl:276 [inlined]
#
#  [45] sample
#
#     @ ~/.julia/packages/Turing/QN7BL/src/mcmc/Inference.jl:267 [inlined]
#
#  [46] #sample#3
#
#     @ ~/.julia/packages/Turing/QN7BL/src/mcmc/Inference.jl:264 [inlined]
#
#  [47] sample(model::DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, alg::NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}, N::Int64)
#
#     @ Turing.Inference ~/.julia/packages/Turing/QN7BL/src/mcmc/Inference.jl:258
#
#  [48] eval
#
#     @ ./boot.jl:430 [inlined]
#
#  [49] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#
#     @ Base ./loading.jl:2734
#
#  [50] #invokelatest#2
#
#     @ ./essentials.jl:1055 [inlined]
#
#  [51] invokelatest
#
#     @ ./essentials.jl:1052 [inlined]
#
#  [52] (::VSCodeServer.var"#217#218"{VSCodeServer.NotebookRunCellArguments, String})()
#
#     @ VSCodeServer ~/.vscode/extensions/julialang.language-julia-1.158.2/scripts/packages/VSCodeServer/src/serve_notebook.jl:24
#
#  [53] withpath(f::VSCodeServer.var"#217#218"{VSCodeServer.NotebookRunCellArguments, String}, path::String)
#
#     @ VSCodeServer ~/.vscode/extensions/julialang.language-julia-1.158.2/scripts/packages/VSCodeServer/src/repl.jl:278
#
#  [54] notebook_runcell_request(conn::VSCodeServer.JSONRPC.JSONRPCEndpoint{Base.PipeEndpoint, Base.PipeEndpoint, VSCodeServer.JSON.Serializations.StandardSerialization}, params::VSCodeServer.NotebookRunCellArguments, token::VSCodeServer.CancellationTokens.CancellationToken)
#
#     @ VSCodeServer ~/.vscode/extensions/julialang.language-julia-1.158.2/scripts/packages/VSCodeServer/src/serve_notebook.jl:13
#
#  [55] dispatch_msg(x::VSCodeServer.JSONRPC.JSONRPCEndpoint{Base.PipeEndpoint, Base.PipeEndpoint, VSCodeServer.JSON.Serializations.StandardSerialization}, dispatcher::VSCodeServer.JSONRPC.MsgDispatcher, msg::VSCodeServer.JSONRPC.Request)
#
#     @ VSCodeServer.JSONRPC ~/.vscode/extensions/julialang.language-julia-1.158.2/scripts/packages/JSONRPC/src/typed.jl:68
#
#  [56] serve_notebook(pipename::String, debugger_pipename::String, outputchannel_logger::Base.CoreLogging.SimpleLogger; error_handler::var"#9#14"{String})
#
#     @ VSCodeServer ~/.vscode/extensions/julialang.language-julia-1.158.2/scripts/packages/VSCodeServer/src/serve_notebook.jl:147

# %%
hdata_p = group(chain_gp, :hz_pmod).value.data[:,:,1];
chidata_p =  group(chain_gp, :chi_pmod).value.data[:,:,1];
fs8data_p =  group(chain_gp, :fs8_pmod).value.data[:,:,1];

# %%
v_p = group(chain_gp, :v_po).value.data[:, :, 1];
omegam_p = group(chain_gp, :omegam_po).value.data[:, :, 1];
s8_p = group(chain_gp, :s8_po).value.data[:, :, 1];

# %%
hpmean, hps = mean(hdata_p, dims=1), std(hdata_p, dims=1);
chipmean, chips = mean(chidata_p, dims=1), std(chidata_p, dims=1);
fs8pmean, fs8ps = mean(fs8data_p, dims=1), std(fs8data_p, dims=1);

# %%
plot(fakedatahz.z, fakedatahz.data, yerr=hz_err, label="Data hz", ms=2, seriestype=:scatter)
plot!(z_integ, vec(hpmean), label="hz GP mean")
plot!(z_integ, vec(hpmean .- hps),  fillrange = vec(hpmean .+ hps), fillalpha=0.2, c=4, label="GP standard deviation")
plot!(z_integ, vec(hz_lcdm_m), label=" H(z) LCDM mean")
plot!(z_integ, vec(hz_lcdm_m .- hz_lcdm_s),  fillrange = vec(hz_lcdm_m .+ hz_lcdm_s), fillalpha=0.2, c=1, label="H(z) LCDM standard deviation")

# %%
plot(fakedatadm.z, fakedatadm.data, yerr=dm_err, label="Data Chi", ms=2, seriestype=:scatter)
plot!(z_integ, vec(chipmean), label="Chi GP mean")
plot!(z_integ, vec(chipmean .- chips),  fillrange = vec(chipmean .+ chips), fillalpha=0.2, c=4, label="Chi standard deviation")
plot!(z_integ, vec(dm_lcdm_m), label="Chi LCDM mean")
plot!(z_integ, vec(dm_lcdm_m .- dm_lcdm_s),  fillrange = vec(dm_lcdm_m .+ dm_lcdm_s), fillalpha=0.2, c=1, label="Chi LCDM standard deviation")

# %%
plot(fakedatafs8.z, fakedatafs8.data, yerr=fs8_err, label="Data fs8", ms=2, seriestype=:scatter)
plot!(z_integ, vec(fs8pmean), label="fs8 GP mean")
plot!(z_integ, vec(fs8pmean .- fs8ps),  fillrange = vec(fs8pmean .+ fs8ps), fillalpha=0.2, c=4, label="fs8 standard deviation")
plot!(z_integ, vec(fs8_lcdm_m), label="fs8 LCDM mean")
plot!(z_integ, vec(fs8_lcdm_m .- fs8_lcdm_s),  fillrange = vec(fs8_lcdm_m .+ fs8_lcdm_s), fillalpha=0.2, c=1, label="fs8 LCDM standard deviation")
